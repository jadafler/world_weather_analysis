# %% [markdown]
# # Deliverable 1:
# Retrieve Weather Data

# %%
# Import the random module
import pandas as pd
import numpy as np
import requests
import gmaps

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 730

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6d755a1ede82d8c6d8fbbafc342987ae"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6d755a1ede82d8c6d8fbbafc342987ae

# %%
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        city_current_weather = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather": city_current_weather,
                          "Country": city_country,})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | isangel
# Processing Record 2 of Set 1 | mitsamiouli
# Processing Record 3 of Set 1 | lavrentiya
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | hasaki
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | makakilo city
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 1 | kieta
# Processing Record 17 of Set 1 | nouadhibou
# Processing Record 18 of Set 1 | payakumbuh
# Processing Record 19 of Set 1 | lewiston
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | eruwa
# Processing Record 23 of Set 1 | saint george
# Processing Record 24 of Set 1 | mazagao
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | kiruna
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | honiara
# Processing Record 30 of Set 1 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 31 of Set 1 | esperance
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | yeniseysk
# Processing Record 34 of Set 1 | troitskoye
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | laiagam
# City not found. Skipping...
# Processing Record 37 of Set 1 | faanui
# Processing Record 38 of Set 1 | akureyri
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | zhireken
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | georgetown
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | srednekolymsk
# Processing Record 46 of Set 1 | ostrovnoy
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | burgos
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 1 of Set 2 | marsh harbour
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | laguna
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | nova gradiska
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | chunskiy
# Processing Record 8 of Set 2 | oromocto
# Processing Record 9 of Set 2 | chepareria
# Processing Record 10 of Set 2 | korla
# Processing Record 11 of Set 2 | mount gambier
# Processing Record 12 of Set 2 | evensk
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | saint-pierre
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | rikitea
# Processing Record 19 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 2 | tadine
# Processing Record 21 of Set 2 | dudinka
# Processing Record 22 of Set 2 | quesnel
# Processing Record 23 of Set 2 | tecoanapa
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | ancud
# Processing Record 26 of Set 2 | cabimas
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | tiksi
# Processing Record 29 of Set 2 | inhambane
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | norman wells
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | kruisfontein
# Processing Record 34 of Set 2 | halifax
# Processing Record 35 of Set 2 | kushima
# Processing Record 36 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 2 | vyazemskiy
# Processing Record 38 of Set 2 | balakhninskiy
# Processing Record 39 of Set 2 | tuatapere
# Processing Record 40 of Set 2 | russell
# Processing Record 41 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 2 | terenos
# Processing Record 43 of Set 2 | yetkul
# Processing Record 44 of Set 2 | hofn
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | nalut
# Processing Record 47 of Set 2 | cidreira
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | svetlyy
# Processing Record 50 of Set 2 | alice springs
# Processing Record 1 of Set 3 | sao jose da coroa grande
# Processing Record 2 of Set 3 | algeciras
# Processing Record 3 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 3 | smithers
# Processing Record 5 of Set 3 | flinders
# Processing Record 6 of Set 3 | bejar
# Processing Record 7 of Set 3 | gravdal
# Processing Record 8 of Set 3 | suzhou
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | palmer
# Processing Record 11 of Set 3 | constitucion
# Processing Record 12 of Set 3 | kaitangata
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | pevek
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | chapais
# Processing Record 18 of Set 3 | vardo
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | kjopsvik
# Processing Record 21 of Set 3 | aklavik
# Processing Record 22 of Set 3 | sao felix do xingu
# Processing Record 23 of Set 3 | naze
# Processing Record 24 of Set 3 | borzna
# Processing Record 25 of Set 3 | union
# Processing Record 26 of Set 3 | asosa
# Processing Record 27 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 3 | ranong
# Processing Record 29 of Set 3 | yellowknife
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | preobrazheniye
# Processing Record 32 of Set 3 | potsdam
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | bandarbeyla
# Processing Record 35 of Set 3 | baykit
# Processing Record 36 of Set 3 | mogadishu
# Processing Record 37 of Set 3 | kumluca
# Processing Record 38 of Set 3 | thompson
# Processing Record 39 of Set 3 | ust-tsilma
# Processing Record 40 of Set 3 | nchelenge
# Processing Record 41 of Set 3 | torbay
# Processing Record 42 of Set 3 | sur
# Processing Record 43 of Set 3 | iqaluit
# Processing Record 44 of Set 3 | odweyne
# Processing Record 45 of Set 3 | nevelsk
# Processing Record 46 of Set 3 | camabatela
# Processing Record 47 of Set 3 | salmo
# Processing Record 48 of Set 3 | timizart
# Processing Record 49 of Set 3 | uige
# Processing Record 50 of Set 3 | charqueada
# Processing Record 1 of Set 4 | bluff
# Processing Record 2 of Set 4 | simao
# Processing Record 3 of Set 4 | bambanglipuro
# Processing Record 4 of Set 4 | komsomolskiy
# Processing Record 5 of Set 4 | arraial do cabo
# Processing Record 6 of Set 4 | toropets
# Processing Record 7 of Set 4 | kavieng
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | nantucket
# Processing Record 10 of Set 4 | sumbe
# Processing Record 11 of Set 4 | nhulunbuy
# Processing Record 12 of Set 4 | bonthe
# Processing Record 13 of Set 4 | san policarpo
# Processing Record 14 of Set 4 | waddan
# Processing Record 15 of Set 4 | ondjiva
# Processing Record 16 of Set 4 | santarem
# Processing Record 17 of Set 4 | labuhan
# Processing Record 18 of Set 4 | provideniya
# Processing Record 19 of Set 4 | tura
# Processing Record 20 of Set 4 | yarmouth
# Processing Record 21 of Set 4 | sitka
# Processing Record 22 of Set 4 | waingapu
# Processing Record 23 of Set 4 | awjilah
# Processing Record 24 of Set 4 | karratha
# Processing Record 25 of Set 4 | portland
# Processing Record 26 of Set 4 | sept-iles
# Processing Record 27 of Set 4 | tank
# Processing Record 28 of Set 4 | sortavala
# Processing Record 29 of Set 4 | fortuna
# Processing Record 30 of Set 4 | sarny
# Processing Record 31 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 4 | deputatskiy
# Processing Record 33 of Set 4 | derzhavinsk
# Processing Record 34 of Set 4 | qaanaaq
# Processing Record 35 of Set 4 | ariguani
# Processing Record 36 of Set 4 | geraldton
# Processing Record 37 of Set 4 | buala
# Processing Record 38 of Set 4 | tilichiki
# Processing Record 39 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 4 | mastic beach
# Processing Record 41 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 4 | poddorye
# Processing Record 43 of Set 4 | xuzhou
# Processing Record 44 of Set 4 | margate
# Processing Record 45 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 4 | santiago de cuba
# City not found. Skipping...
# Processing Record 47 of Set 4 | yar-sale
# Processing Record 48 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 4 | stekolnyy
# City not found. Skipping...
# Processing Record 50 of Set 4 | abu samrah
# Processing Record 1 of Set 5 | acari
# Processing Record 2 of Set 5 | ndjole
# Processing Record 3 of Set 5 | luanda
# Processing Record 4 of Set 5 | vila franca do campo
# Processing Record 5 of Set 5 | cabo san lucas
# Processing Record 6 of Set 5 | wewak
# Processing Record 7 of Set 5 | san patricio
# Processing Record 8 of Set 5 | naron
# Processing Record 9 of Set 5 | tezu
# Processing Record 10 of Set 5 | kumbhraj
# Processing Record 11 of Set 5 | nanortalik
# Processing Record 12 of Set 5 | marawi
# Processing Record 13 of Set 5 | borba
# Processing Record 14 of Set 5 | vestmannaeyjar
# Processing Record 15 of Set 5 | saint-philippe
# Processing Record 16 of Set 5 | severo-kurilsk
# Processing Record 17 of Set 5 | tocopilla
# Processing Record 18 of Set 5 | manokwari
# Processing Record 19 of Set 5 | shemgang
# Processing Record 20 of Set 5 | cherskiy
# Processing Record 21 of Set 5 | suluq
# Processing Record 22 of Set 5 | kailua
# Processing Record 23 of Set 5 | talnakh
# Processing Record 24 of Set 5 | seymchan
# Processing Record 25 of Set 5 | shache
# Processing Record 26 of Set 5 | xining
# Processing Record 27 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 5 | villazon
# Processing Record 29 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 5 | puerto leguizamo
# Processing Record 31 of Set 5 | eureka
# Processing Record 32 of Set 5 | forrest city
# Processing Record 33 of Set 5 | wencheng
# Processing Record 34 of Set 5 | guerrero negro
# Processing Record 35 of Set 5 | apiai
# Processing Record 36 of Set 5 | half moon bay
# Processing Record 37 of Set 5 | olafsvik
# Processing Record 38 of Set 5 | narsaq
# Processing Record 39 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 5 | leh
# Processing Record 41 of Set 5 | east london
# Processing Record 42 of Set 5 | dongsheng
# Processing Record 43 of Set 5 | rio grande city
# Processing Record 44 of Set 5 | melo
# Processing Record 45 of Set 5 | sayville
# Processing Record 46 of Set 5 | taoudenni
# Processing Record 47 of Set 5 | abu zabad
# Processing Record 48 of Set 5 | los llanos de aridane
# Processing Record 49 of Set 5 | xacmaz
# Processing Record 50 of Set 5 | puerto colombia
# Processing Record 1 of Set 6 | pafos
# Processing Record 2 of Set 6 | lompoc
# Processing Record 3 of Set 6 | tupik
# Processing Record 4 of Set 6 | quelimane
# Processing Record 5 of Set 6 | sunland park
# Processing Record 6 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 6 | adavere
# Processing Record 8 of Set 6 | katsuura
# Processing Record 9 of Set 6 | calabar
# Processing Record 10 of Set 6 | sioux lookout
# Processing Record 11 of Set 6 | yerbogachen
# Processing Record 12 of Set 6 | palmas
# Processing Record 13 of Set 6 | shelburne
# Processing Record 14 of Set 6 | champerico
# Processing Record 15 of Set 6 | kilimatinde
# Processing Record 16 of Set 6 | tual
# Processing Record 17 of Set 6 | shebunino
# Processing Record 18 of Set 6 | wittlich
# Processing Record 19 of Set 6 | vostok
# Processing Record 20 of Set 6 | port blair
# Processing Record 21 of Set 6 | conceicao do mato dentro
# Processing Record 22 of Set 6 | gejiu
# Processing Record 23 of Set 6 | jalu
# Processing Record 24 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 6 | lagoa
# Processing Record 26 of Set 6 | yakeshi
# Processing Record 27 of Set 6 | robertsport
# Processing Record 28 of Set 6 | oriximina
# Processing Record 29 of Set 6 | harper
# Processing Record 30 of Set 6 | adrar
# Processing Record 31 of Set 6 | hurghada
# Processing Record 32 of Set 6 | opelousas
# Processing Record 33 of Set 6 | asopos
# Processing Record 34 of Set 6 | camopi
# Processing Record 35 of Set 6 | uchaly
# Processing Record 36 of Set 6 | longyearbyen
# Processing Record 37 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 38 of Set 6 | hohhot
# Processing Record 39 of Set 6 | takoradi
# Processing Record 40 of Set 6 | poum
# Processing Record 41 of Set 6 | westport
# Processing Record 42 of Set 6 | tombouctou
# Processing Record 43 of Set 6 | mackay
# Processing Record 44 of Set 6 | xinan
# Processing Record 45 of Set 6 | bethel
# Processing Record 46 of Set 6 | la ronge
# Processing Record 47 of Set 6 | la sarre
# Processing Record 48 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 6 | barabinsk
# Processing Record 50 of Set 6 | cerro largo
# Processing Record 1 of Set 7 | nusaybin
# Processing Record 2 of Set 7 | ambilobe
# Processing Record 3 of Set 7 | faya
# Processing Record 4 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 5 of Set 7 | semirom
# Processing Record 6 of Set 7 | kurchum
# Processing Record 7 of Set 7 | vega de alatorre
# Processing Record 8 of Set 7 | show low
# Processing Record 9 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 10 of Set 7 | soyo
# Processing Record 11 of Set 7 | tanout
# Processing Record 12 of Set 7 | ilulissat
# Processing Record 13 of Set 7 | vila velha
# Processing Record 14 of Set 7 | surovikino
# Processing Record 15 of Set 7 | zheleznodorozhnyy
# Processing Record 16 of Set 7 | palembang
# Processing Record 17 of Set 7 | amapa
# Processing Record 18 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 7 | anadyr
# Processing Record 20 of Set 7 | deloraine
# Processing Record 21 of Set 7 | carnarvon
# Processing Record 22 of Set 7 | pisco
# Processing Record 23 of Set 7 | te anau
# Processing Record 24 of Set 7 | sanchazi
# Processing Record 25 of Set 7 | lebork
# Processing Record 26 of Set 7 | novoagansk
# Processing Record 27 of Set 7 | belomorsk
# Processing Record 28 of Set 7 | mbanza-ngungu
# Processing Record 29 of Set 7 | yining
# Processing Record 30 of Set 7 | shahrud
# Processing Record 31 of Set 7 | grindavik
# Processing Record 32 of Set 7 | port moresby
# Processing Record 33 of Set 7 | lalawigan
# Processing Record 34 of Set 7 | sao filipe
# Processing Record 35 of Set 7 | hukuntsi
# Processing Record 36 of Set 7 | lure
# Processing Record 37 of Set 7 | oranjestad
# Processing Record 38 of Set 7 | ziniare
# Processing Record 39 of Set 7 | bojonegoro
# Processing Record 40 of Set 7 | bang saphan
# Processing Record 41 of Set 7 | pochutla
# Processing Record 42 of Set 7 | contai
# Processing Record 43 of Set 7 | salalah
# Processing Record 44 of Set 7 | clyde river
# Processing Record 45 of Set 7 | anastacio
# Processing Record 46 of Set 7 | srandakan
# Processing Record 47 of Set 7 | gat
# Processing Record 48 of Set 7 | hambantota
# Processing Record 49 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 50 of Set 7 | fukue
# Processing Record 1 of Set 8 | padang
# Processing Record 2 of Set 8 | sterling
# Processing Record 3 of Set 8 | buraydah
# Processing Record 4 of Set 8 | santa teresa
# Processing Record 5 of Set 8 | tasiilaq
# Processing Record 6 of Set 8 | fairbanks
# Processing Record 7 of Set 8 | keflavik
# Processing Record 8 of Set 8 | inirida
# Processing Record 9 of Set 8 | birao
# Processing Record 10 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 8 | la palma
# Processing Record 12 of Set 8 | port said
# Processing Record 13 of Set 8 | kamina
# Processing Record 14 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 8 | tatvan
# Processing Record 16 of Set 8 | kozhva
# Processing Record 17 of Set 8 | kawalu
# Processing Record 18 of Set 8 | koslan
# Processing Record 19 of Set 8 | chinsali
# Processing Record 20 of Set 8 | kerema
# Processing Record 21 of Set 8 | hamilton
# Processing Record 22 of Set 8 | kununurra
# Processing Record 23 of Set 8 | zaysan
# Processing Record 24 of Set 8 | asuncion
# Processing Record 25 of Set 8 | kenai
# Processing Record 26 of Set 8 | itarema
# Processing Record 27 of Set 8 | marathon
# Processing Record 28 of Set 8 | hvide sande
# Processing Record 29 of Set 8 | pitimbu
# Processing Record 30 of Set 8 | washougal
# Processing Record 31 of Set 8 | esso
# Processing Record 32 of Set 8 | novotalitsy
# City not found. Skipping...
# Processing Record 33 of Set 8 | magadan
# Processing Record 34 of Set 8 | omsukchan
# Processing Record 35 of Set 8 | baringo
# Processing Record 36 of Set 8 | heishan
# Processing Record 37 of Set 8 | souillac
# Processing Record 38 of Set 8 | zhongxing
# Processing Record 39 of Set 8 | dakar
# Processing Record 40 of Set 8 | shatrovo
# Processing Record 41 of Set 8 | cordoba
# Processing Record 42 of Set 8 | san jose
# Processing Record 43 of Set 8 | plavsk
# Processing Record 44 of Set 8 | cristalina
# Processing Record 45 of Set 8 | puerto quijarro
# Processing Record 46 of Set 8 | ahipara
# Processing Record 47 of Set 8 | lima
# Processing Record 48 of Set 8 | salinopolis
# Processing Record 49 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 50 of Set 8 | zyryanka
# Processing Record 1 of Set 9 | palana
# Processing Record 2 of Set 9 | port hawkesbury
# Processing Record 3 of Set 9 | rocha
# Processing Record 4 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 9 | comodoro rivadavia
# Processing Record 6 of Set 9 | tigzirt
# Processing Record 7 of Set 9 | lakselv
# Processing Record 8 of Set 9 | yakima
# Processing Record 9 of Set 9 | aripuana
# Processing Record 10 of Set 9 | codrington
# Processing Record 11 of Set 9 | talavera de la reina
# Processing Record 12 of Set 9 | sapao
# City not found. Skipping...
# Processing Record 13 of Set 9 | diu
# Processing Record 14 of Set 9 | kalmunai
# Processing Record 15 of Set 9 | hirara
# Processing Record 16 of Set 9 | qaqortoq
# Processing Record 17 of Set 9 | trincomalee
# Processing Record 18 of Set 9 | whitehorse
# Processing Record 19 of Set 9 | tiznit
# Processing Record 20 of Set 9 | grand-santi
# Processing Record 21 of Set 9 | spearfish
# Processing Record 22 of Set 9 | saldanha
# Processing Record 23 of Set 9 | lasa
# Processing Record 24 of Set 9 | hailey
# Processing Record 25 of Set 9 | pangnirtung
# Processing Record 26 of Set 9 | saint-augustin
# Processing Record 27 of Set 9 | paamiut
# Processing Record 28 of Set 9 | baruun-urt
# Processing Record 29 of Set 9 | orlik
# Processing Record 30 of Set 9 | cayenne
# Processing Record 31 of Set 9 | beboto
# Processing Record 32 of Set 9 | sri aman
# Processing Record 33 of Set 9 | pacific grove
# Processing Record 34 of Set 9 | college
# Processing Record 35 of Set 9 | sola
# Processing Record 36 of Set 9 | vung tau
# Processing Record 37 of Set 9 | dubbo
# Processing Record 38 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 39 of Set 9 | havelock
# Processing Record 40 of Set 9 | tessalit
# Processing Record 41 of Set 9 | malindi
# Processing Record 42 of Set 9 | tostamaa
# City not found. Skipping...
# Processing Record 43 of Set 9 | nizwa
# Processing Record 44 of Set 9 | chibombo
# Processing Record 45 of Set 9 | urumqi
# Processing Record 46 of Set 9 | cowra
# Processing Record 47 of Set 9 | hanyang
# Processing Record 48 of Set 9 | tabou
# Processing Record 49 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 50 of Set 9 | houma
# Processing Record 1 of Set 10 | camacha
# Processing Record 2 of Set 10 | uniao dos palmares
# Processing Record 3 of Set 10 | atambua
# Processing Record 4 of Set 10 | walvis bay
# Processing Record 5 of Set 10 | port hardy
# Processing Record 6 of Set 10 | santa vitoria do palmar
# Processing Record 7 of Set 10 | genhe
# Processing Record 8 of Set 10 | manzanillo
# Processing Record 9 of Set 10 | ulladulla
# Processing Record 10 of Set 10 | sorkjosen
# Processing Record 11 of Set 10 | linden
# Processing Record 12 of Set 10 | roma
# Processing Record 13 of Set 10 | maltahohe
# Processing Record 14 of Set 10 | nanchong
# Processing Record 15 of Set 10 | bengkulu
# Processing Record 16 of Set 10 | santa rosa
# Processing Record 17 of Set 10 | aden
# Processing Record 18 of Set 10 | octeville
# Processing Record 19 of Set 10 | bria
# Processing Record 20 of Set 10 | samarai
# Processing Record 21 of Set 10 | lao cai
# Processing Record 22 of Set 10 | gizo
# Processing Record 23 of Set 10 | katobu
# Processing Record 24 of Set 10 | burnie
# Processing Record 25 of Set 10 | antofagasta
# Processing Record 26 of Set 10 | port-gentil
# Processing Record 27 of Set 10 | kamenka
# Processing Record 28 of Set 10 | diamantino
# Processing Record 29 of Set 10 | tsabong
# Processing Record 30 of Set 10 | tabasalu
# Processing Record 31 of Set 10 | ipojuca
# Processing Record 32 of Set 10 | burica
# City not found. Skipping...
# Processing Record 33 of Set 10 | kalengwa
# Processing Record 34 of Set 10 | morris
# Processing Record 35 of Set 10 | haines junction
# Processing Record 36 of Set 10 | coquimbo
# Processing Record 37 of Set 10 | moranbah
# Processing Record 38 of Set 10 | massakory
# Processing Record 39 of Set 10 | fethiye
# Processing Record 40 of Set 10 | abilene
# Processing Record 41 of Set 10 | hedaru
# Processing Record 42 of Set 10 | rawson
# Processing Record 43 of Set 10 | lazaro cardenas
# Processing Record 44 of Set 10 | hanzhong
# Processing Record 45 of Set 10 | foumban
# Processing Record 46 of Set 10 | pouembout
# Processing Record 47 of Set 10 | lundazi
# Processing Record 48 of Set 10 | thyolo
# Processing Record 49 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 50 of Set 10 | laa
# Processing Record 1 of Set 11 | korgen
# Processing Record 2 of Set 11 | plettenberg bay
# Processing Record 3 of Set 11 | bathsheba
# Processing Record 4 of Set 11 | mazurivka
# Processing Record 5 of Set 11 | prata
# Processing Record 6 of Set 11 | manakara
# Processing Record 7 of Set 11 | hobyo
# Processing Record 8 of Set 11 | pandan
# Processing Record 9 of Set 11 | saint-georges
# Processing Record 10 of Set 11 | boa vista
# Processing Record 11 of Set 11 | meulaboh
# Processing Record 12 of Set 11 | porto novo
# Processing Record 13 of Set 11 | verkhnyachka
# Processing Record 14 of Set 11 | santa maria
# Processing Record 15 of Set 11 | coruripe
# Processing Record 16 of Set 11 | kamaishi
# Processing Record 17 of Set 11 | jimo
# Processing Record 18 of Set 11 | grand gaube
# Processing Record 19 of Set 11 | lucapa
# Processing Record 20 of Set 11 | dawson creek
# Processing Record 21 of Set 11 | soma
# Processing Record 22 of Set 11 | negombo
# Processing Record 23 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 11 | tailai
# Processing Record 25 of Set 11 | mwense
# Processing Record 26 of Set 11 | nioro
# Processing Record 27 of Set 11 | broken hill
# Processing Record 28 of Set 11 | tutoia
# Processing Record 29 of Set 11 | kirakira
# Processing Record 30 of Set 11 | batticaloa
# Processing Record 31 of Set 11 | husavik
# Processing Record 32 of Set 11 | vagay
# Processing Record 33 of Set 11 | lander
# Processing Record 34 of Set 11 | kinablangan
# Processing Record 35 of Set 11 | chadiza
# Processing Record 36 of Set 11 | purranque
# Processing Record 37 of Set 11 | turan
# Processing Record 38 of Set 11 | kralupy nad vltavou
# Processing Record 39 of Set 11 | alofi
# Processing Record 40 of Set 11 | eskilstuna
# Processing Record 41 of Set 11 | saint-joseph
# Processing Record 42 of Set 11 | tandil
# Processing Record 43 of Set 11 | balykshi
# Processing Record 44 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 45 of Set 11 | xingcheng
# Processing Record 46 of Set 11 | nome
# Processing Record 47 of Set 11 | birin
# Processing Record 48 of Set 11 | darhan
# Processing Record 49 of Set 11 | ola
# Processing Record 50 of Set 11 | nam som
# Processing Record 1 of Set 12 | moose jaw
# Processing Record 2 of Set 12 | moose factory
# Processing Record 3 of Set 12 | poso
# Processing Record 4 of Set 12 | huaiyin
# Processing Record 5 of Set 12 | aksarka
# Processing Record 6 of Set 12 | sangar
# Processing Record 7 of Set 12 | berlevag
# Processing Record 8 of Set 12 | bubaque
# Processing Record 9 of Set 12 | prince rupert
# Processing Record 10 of Set 12 | luderitz
# Processing Record 11 of Set 12 | najran
# Processing Record 12 of Set 12 | abnub
# Processing Record 13 of Set 12 | bratsk
# Processing Record 14 of Set 12 | sire
# Processing Record 15 of Set 12 | aitape
# Processing Record 16 of Set 12 | verkhnyaya maksakovka
# Processing Record 17 of Set 12 | chalons-en-champagne
# Processing Record 18 of Set 12 | northam
# Processing Record 19 of Set 12 | san juan
# Processing Record 20 of Set 12 | iquique
# Processing Record 21 of Set 12 | nguruka
# Processing Record 22 of Set 12 | yangambi
# Processing Record 23 of Set 12 | chara
# Processing Record 24 of Set 12 | changde
# Processing Record 25 of Set 12 | noumea
# Processing Record 26 of Set 12 | kautokeino
# Processing Record 27 of Set 12 | ginir
# Processing Record 28 of Set 12 | sereflikochisar
# Processing Record 29 of Set 12 | port lincoln
# Processing Record 30 of Set 12 | shimoda
# Processing Record 31 of Set 12 | dingle
# Processing Record 32 of Set 12 | swan hill
# Processing Record 33 of Set 12 | mindelo
# Processing Record 34 of Set 12 | puerto asis
# Processing Record 35 of Set 12 | orocue
# Processing Record 36 of Set 12 | bendigo
# Processing Record 37 of Set 12 | lilongwe
# Processing Record 38 of Set 12 | young
# Processing Record 39 of Set 12 | ayagoz
# Processing Record 40 of Set 12 | tondano
# Processing Record 41 of Set 12 | campina verde
# Processing Record 42 of Set 12 | kahului
# Processing Record 43 of Set 12 | alugan
# Processing Record 44 of Set 12 | valsamata
# Processing Record 45 of Set 12 | mutare
# Processing Record 46 of Set 12 | tefe
# Processing Record 47 of Set 12 | bud
# Processing Record 48 of Set 12 | bharatpur
# Processing Record 49 of Set 12 | talawdi
# City not found. Skipping...
# Processing Record 50 of Set 12 | klaksvik
# Processing Record 1 of Set 13 | chernogolovka
# Processing Record 2 of Set 13 | kongolo
# Processing Record 3 of Set 13 | adelaide
# Processing Record 4 of Set 13 | bontang
# Processing Record 5 of Set 13 | namibe
# Processing Record 6 of Set 13 | atar
# Processing Record 7 of Set 13 | duki
# Processing Record 8 of Set 13 | jieshi
# Processing Record 9 of Set 13 | chanute
# Processing Record 10 of Set 13 | sistranda
# Processing Record 11 of Set 13 | moree
# Processing Record 12 of Set 13 | kokopo
# Processing Record 13 of Set 13 | abha
# Processing Record 14 of Set 13 | pacasmayo
# Processing Record 15 of Set 13 | micheweni
# Processing Record 16 of Set 13 | port hedland
# Processing Record 17 of Set 13 | jiayuguan
# Processing Record 18 of Set 13 | yoichi
# Processing Record 19 of Set 13 | belmonte
# Processing Record 20 of Set 13 | acandi
# Processing Record 21 of Set 13 | denpasar
# Processing Record 22 of Set 13 | madarounfa
# Processing Record 23 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 13 | anchorage
# Processing Record 25 of Set 13 | romans-sur-isere
# Processing Record 26 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 27 of Set 13 | pirapozinho
# Processing Record 28 of Set 13 | hovd
# Processing Record 29 of Set 13 | cariati
# Processing Record 30 of Set 13 | douglas
# Processing Record 31 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 13 | ayacucho
# Processing Record 33 of Set 13 | namatanai
# Processing Record 34 of Set 13 | high rock
# Processing Record 35 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 13 | moerai
# Processing Record 37 of Set 13 | mao
# Processing Record 38 of Set 13 | podor
# Processing Record 39 of Set 13 | siparia
# Processing Record 40 of Set 13 | kavaratti
# Processing Record 41 of Set 13 | baryatino
# Processing Record 42 of Set 13 | oktyabrskoye
# Processing Record 43 of Set 13 | bad munstereifel
# Processing Record 44 of Set 13 | skjaerhollen
# City not found. Skipping...
# Processing Record 45 of Set 13 | port macquarie
# Processing Record 46 of Set 13 | san carlos de bariloche
# Processing Record 47 of Set 13 | itamaraju
# Processing Record 48 of Set 13 | bin qirdan
# Processing Record 49 of Set 13 | bundaberg
# Processing Record 50 of Set 13 | shestakovo
# Processing Record 1 of Set 14 | aykhal
# Processing Record 2 of Set 14 | atherton
# Processing Record 3 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 14 | sao domingos
# Processing Record 5 of Set 14 | ambulu
# Processing Record 6 of Set 14 | slave lake
# Processing Record 7 of Set 14 | gunjur
# Processing Record 8 of Set 14 | kibakwe
# Processing Record 9 of Set 14 | taywarah
# Processing Record 10 of Set 14 | boende
# Processing Record 11 of Set 14 | porto-vecchio
# Processing Record 12 of Set 14 | warah
# Processing Record 13 of Set 14 | yilan
# Processing Record 14 of Set 14 | dagda
# Processing Record 15 of Set 14 | avera
# Processing Record 16 of Set 14 | miri
# Processing Record 17 of Set 14 | litovko
# Processing Record 18 of Set 14 | umm lajj
# Processing Record 19 of Set 14 | pareora
# Processing Record 20 of Set 14 | batemans bay
# Processing Record 21 of Set 14 | puertollano
# Processing Record 22 of Set 14 | tommot
# Processing Record 23 of Set 14 | sobolevo
# Processing Record 24 of Set 14 | erie
# Processing Record 25 of Set 14 | bandarban
# Processing Record 26 of Set 14 | takaka
# Processing Record 27 of Set 14 | santa isabel do rio negro
# Processing Record 28 of Set 14 | kurumkan
# Processing Record 29 of Set 14 | middletown
# Processing Record 30 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 14 | maracacume
# Processing Record 32 of Set 14 | west bay
# Processing Record 33 of Set 14 | ampanihy
# Processing Record 34 of Set 14 | farmington
# Processing Record 35 of Set 14 | tevaitoa
# Processing Record 36 of Set 14 | kaihua
# Processing Record 37 of Set 14 | vallenar
# Processing Record 38 of Set 14 | xai-xai
# Processing Record 39 of Set 14 | vrangel
# Processing Record 40 of Set 14 | maldonado
# Processing Record 41 of Set 14 | brae
# Processing Record 42 of Set 14 | pitangui
# Processing Record 43 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 44 of Set 14 | skibbereen
# Processing Record 45 of Set 14 | bima
# Processing Record 46 of Set 14 | shushenskoye
# Processing Record 47 of Set 14 | pikermion
# City not found. Skipping...
# Processing Record 48 of Set 14 | vikhorevka
# Processing Record 49 of Set 14 | cairns
# Processing Record 50 of Set 14 | grass valley
# Processing Record 1 of Set 15 | gao
# Processing Record 2 of Set 15 | lata
# Processing Record 3 of Set 15 | dunedin
# Processing Record 4 of Set 15 | mezhdurechensk
# Processing Record 5 of Set 15 | kudahuvadhoo
# Processing Record 6 of Set 15 | hayden
# Processing Record 7 of Set 15 | krasnoselkup
# Processing Record 8 of Set 15 | leningradskiy
# Processing Record 9 of Set 15 | acarau
# Processing Record 10 of Set 15 | fort nelson
# Processing Record 11 of Set 15 | hue
# Processing Record 12 of Set 15 | hervey bay
# Processing Record 13 of Set 15 | bilibino
# Processing Record 14 of Set 15 | binika
# Processing Record 15 of Set 15 | touho
# Processing Record 16 of Set 15 | sa kaeo
# Processing Record 17 of Set 15 | santa rita do passa quatro
# Processing Record 18 of Set 15 | igrim
# Processing Record 19 of Set 15 | chumikan
# Processing Record 20 of Set 15 | opochka
# Processing Record 21 of Set 15 | matveyevka
# Processing Record 22 of Set 15 | yeppoon
# Processing Record 23 of Set 15 | duluth
# Processing Record 24 of Set 15 | casian
# Processing Record 25 of Set 15 | durazno
# Processing Record 26 of Set 15 | les cayes
# Processing Record 27 of Set 15 | ketchikan
# Processing Record 28 of Set 15 | jacareacanga
# Processing Record 29 of Set 15 | creel
# Processing Record 30 of Set 15 | formoso do araguaia
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 730

# %%
city_data
# Out:
# [{'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.27,
#   'Max Temp': 74.52,
#   'Humidity': 82,
#   'Cloudiness': 14,
#   'Wind Speed': 9.48,
#   'Current Weather': 'few clouds',
#   'Country': 'VU'},
#  {'City': 'Mitsamiouli',
#   'Lat': -11.38,
#   'Lng': 43.28,
#   'Max Temp': 79.02,
#   'Humidity': 73,
#   'Cloudiness': 2,
#   'Wind Speed': 4.74,
#   'Current Weather': 'clear sky',
#   'Country': 'KM'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 19.72,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 7.94,
#   'Current Weather': 'scattered clouds',
#   'Country': 'RU'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 62.6,
#   'Humidity': 59,
#   'Cloudiness': 48,
#   'Wind Speed': 6.93,
#   'Current Weather': 'scattered clouds',
#   'Country': 'ZA'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 77,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Weather': 'scattered clouds',
#   'Country': 'EC'},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 46,
#   'Humidity': 59,
#   'Cloudiness': 83,
#   'Wind Speed': 3,
#   'Current Weather': 'broken clouds',
#   'Country': 'US'},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 55,
#   'Humidity': 91,
#   'Cloudiness': 64,
#   'Wind Speed': 1.1,
#   'Current Weather': 'light rain',
#   'Country': 'AU'},
#  {'City': 'Hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 55.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Weather': 'moderate rain',
#   'Country': 'AU'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 48.99,
#   'Humidity': 96,
#   'Cloudiness': 26,
#   'Wind Speed': 5.99,
#   'Current Weather': 'scattered clouds',
#   'Country': 'AU'},
#  {'City': 'Hasaki',
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 1.12,
#   'Current Weather': 'broken clouds',
#   'Country': 'JP'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 64.4,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ZA'},
#  {'City': 'Makakilo City',
#   'Lat': 21.35,
#   'Lng': -158.09,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 73.4,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Weather': 'broken clouds',
#   'Country': 'MU'},
#  {'City': 'Kieta',
#   'Lat': -6.22,
#   'Lng': 155.63,
#   'Max Temp': 79.36,
#   'Humidity': 77,
#   'Cloudiness': 97,
#   'Wind Speed': 6.17,
#   'Current Weather': 'moderate rain',
#   'Country': 'PG'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.93,
#   'Lng': -17.03,
#   'Max Temp': 80.6,
#   'Humidity': 39,
#   'Cloudiness': 100,
#   'Wind Speed': 9.17,
#   'Current Weather': 'overcast clouds',
#   'Country': 'MR'},
#  {'City': 'Payakumbuh',
#   'Lat': -0.22,
#   'Lng': 100.63,
#   'Max Temp': 71.78,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ID'},
#  {'City': 'Lewiston',
#   'Lat': 44.1,
#   'Lng': -70.21,
#   'Max Temp': 42.8,
#   'Humidity': 48,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Weather': 'broken clouds',
#   'Country': 'US'},
#  {'City': 'Upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 18.48,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 18.63,
#   'Current Weather': 'overcast clouds',
#   'Country': 'GL'},
#  {'City': 'Eruwa',
#   'Lat': 7.53,
#   'Lng': 3.42,
#   'Max Temp': 89.6,
#   'Humidity': 59,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Weather': 'scattered clouds',
#   'Country': 'NG'},
#  {'City': 'Saint George',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 42.8,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 2.8,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Mazagao',
#   'Lat': -0.12,
#   'Lng': -51.29,
#   'Max Temp': 93.2,
#   'Humidity': 59,
#   'Cloudiness': 40,
#   'Wind Speed': 17.22,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BR'},
#  {'City': 'Airai',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 61.07,
#   'Humidity': 90,
#   'Cloudiness': 47,
#   'Wind Speed': 2.01,
#   'Current Weather': 'scattered clouds',
#   'Country': 'TL'},
#  {'City': 'Kiruna',
#   'Lat': 67.86,
#   'Lng': 20.23,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 17.22,
#   'Current Weather': 'overcast clouds',
#   'Country': 'SE'},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 61,
#   'Humidity': 69,
#   'Cloudiness': 10,
#   'Wind Speed': 9.06,
#   'Current Weather': 'clear sky',
#   'Country': 'ZA'},
#  {'City': 'Victoria',
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 73,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 10.2,
#   'Current Weather': 'overcast clouds',
#   'Country': 'HK'},
#  {'City': 'Honiara',
#   'Lat': -9.43,
#   'Lng': 159.95,
#   'Max Temp': 79.45,
#   'Humidity': 79,
#   'Cloudiness': 36,
#   'Wind Speed': 3.98,
#   'Current Weather': 'scattered clouds',
#   'Country': 'SB'},
#  {'City': 'Esperance',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 50,
#   'Humidity': 100,
#   'Cloudiness': 11,
#   'Wind Speed': 5.82,
#   'Current Weather': 'few clouds',
#   'Country': 'AU'},
#  {'City': 'Saskylakh',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': -1.44,
#   'Humidity': 92,
#   'Cloudiness': 80,
#   'Wind Speed': 6.33,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Yeniseysk',
#   'Lat': 58.45,
#   'Lng': 92.17,
#   'Max Temp': 10.53,
#   'Humidity': 95,
#   'Cloudiness': 1,
#   'Wind Speed': 1.19,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Troitskoye',
#   'Lat': 52.98,
#   'Lng': 84.68,
#   'Max Temp': 29.01,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 7.54,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Faanui',
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 79.63,
#   'Humidity': 78,
#   'Cloudiness': 15,
#   'Wind Speed': 10.69,
#   'Current Weather': 'few clouds',
#   'Country': 'PF'},
#  {'City': 'Akureyri',
#   'Lat': 65.68,
#   'Lng': -18.09,
#   'Max Temp': 32,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Current Weather': 'overcast clouds',
#   'Country': 'IS'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 8.5,
#   'Current Weather': 'mist',
#   'Country': 'TO'},
#  {'City': 'Zhireken',
#   'Lat': 52.82,
#   'Lng': 117.31,
#   'Max Temp': 12.4,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 2.15,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 77.97,
#   'Humidity': 71,
#   'Cloudiness': 17,
#   'Wind Speed': 16.64,
#   'Current Weather': 'few clouds',
#   'Country': 'PF'},
#  {'City': 'Georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Current Weather': 'few clouds',
#   'Country': 'MY'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 33.8,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 13.87,
#   'Current Weather': 'few clouds',
#   'Country': 'US'},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 65.48,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 9.44,
#   'Current Weather': 'light rain',
#   'Country': 'ZA'},
#  {'City': 'Srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.68,
#   'Max Temp': -13,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.75,
#   'Current Weather': 'light snow',
#   'Country': 'RU'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 31.8,
#   'Humidity': 95,
#   'Cloudiness': 49,
#   'Wind Speed': 29.82,
#   'Current Weather': 'scattered clouds',
#   'Country': 'RU'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 55.4,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 33.33,
#   'Current Weather': 'clear sky',
#   'Country': 'CL'},
#  {'City': 'Lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 57.25,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 19.62,
#   'Current Weather': 'clear sky',
#   'Country': 'CL'},
#  {'City': 'Burgos',
#   'Lat': 42.34,
#   'Lng': -3.71,
#   'Max Temp': 57.2,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Current Weather': 'broken clouds',
#   'Country': 'ES'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 32,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 6.71,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Marsh Harbour',
#   'Lat': 26.54,
#   'Lng': -77.06,
#   'Max Temp': 80.08,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 8.16,
#   'Current Weather': 'clear sky',
#   'Country': 'BS'},
#  {'City': 'Barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 21.2,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Weather': 'light snow',
#   'Country': 'US'},
#  {'City': 'Laguna',
#   'Lat': 38.42,
#   'Lng': -121.42,
#   'Max Temp': 55.99,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 51.8,
#   'Humidity': 32,
#   'Cloudiness': 75,
#   'Wind Speed': 34.45,
#   'Current Weather': 'broken clouds',
#   'Country': 'AR'},
#  {'City': 'Nova Gradiska',
#   'Lat': 45.26,
#   'Lng': 17.38,
#   'Max Temp': 48.2,
#   'Humidity': 93,
#   'Cloudiness': 41,
#   'Wind Speed': 2.24,
#   'Current Weather': 'mist',
#   'Country': 'HR'},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 73.71,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 13.65,
#   'Current Weather': 'overcast clouds',
#   'Country': 'UY'},
#  {'City': 'Chunskiy',
#   'Lat': 56.08,
#   'Lng': 99.63,
#   'Max Temp': 16.32,
#   'Humidity': 96,
#   'Cloudiness': 0,
#   'Wind Speed': 2.46,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Oromocto',
#   'Lat': 45.84,
#   'Lng': -66.48,
#   'Max Temp': 37.99,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Current Weather': 'clear sky',
#   'Country': 'CA'},
#  {'City': 'Chepareria',
#   'Lat': 1.31,
#   'Lng': 35.2,
#   'Max Temp': 64.72,
#   'Humidity': 67,
#   'Cloudiness': 98,
#   'Wind Speed': 4.59,
#   'Current Weather': 'overcast clouds',
#   'Country': 'KE'},
#  {'City': 'Korla',
#   'Lat': 41.76,
#   'Lng': 86.15,
#   'Max Temp': 39.99,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 11.99,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CN'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 59,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 18.34,
#   'Current Weather': 'broken clouds',
#   'Country': 'AU'},
#  {'City': 'Evensk',
#   'Lat': 61.95,
#   'Lng': 159.23,
#   'Max Temp': 23.7,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 10.51,
#   'Current Weather': 'light snow',
#   'Country': 'RU'},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 71.6,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.34,
#   'Lng': 55.48,
#   'Max Temp': 73.4,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Weather': 'broken clouds',
#   'Country': 'RE'},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 51.01,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 27.51,
#   'Current Weather': 'light rain',
#   'Country': 'US'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 12.2,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 21.92,
#   'Current Weather': 'light snow',
#   'Country': 'CA'},
#  {'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 75.65,
#   'Humidity': 80,
#   'Cloudiness': 94,
#   'Wind Speed': 9.66,
#   'Current Weather': 'light rain',
#   'Country': 'PF'},
#  {'City': 'Tadine',
#   'Lat': -21.55,
#   'Lng': 167.88,
#   'Max Temp': 73.45,
#   'Humidity': 81,
#   'Cloudiness': 35,
#   'Wind Speed': 8.84,
#   'Current Weather': 'scattered clouds',
#   'Country': 'NC'},
#  {'City': 'Dudinka',
#   'Lat': 69.41,
#   'Lng': 86.18,
#   'Max Temp': 10.4,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Current Weather': 'snow',
#   'Country': 'RU'},
#  {'City': 'Quesnel',
#   'Lat': 53,
#   'Lng': -122.5,
#   'Max Temp': 32,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CA'},
#  {'City': 'Tecoanapa',
#   'Lat': 16.52,
#   'Lng': -98.75,
#   'Max Temp': 84.97,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 7.49,
#   'Current Weather': 'clear sky',
#   'Country': 'MX'},
#  {'City': 'Cape Town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 64,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 19.46,
#   'Current Weather': 'few clouds',
#   'Country': 'ZA'},
#  {'City': 'Ancud',
#   'Lat': -41.87,
#   'Lng': -73.82,
#   'Max Temp': 59,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Weather': 'few clouds',
#   'Country': 'CL'},
#  {'City': 'Cabimas',
#   'Lat': 10.39,
#   'Lng': -71.44,
#   'Max Temp': 81.79,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 2.17,
#   'Current Weather': 'overcast clouds',
#   'Country': 'VE'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 60.8,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Weather': 'broken clouds',
#   'Country': 'AR'},
#  {'City': 'Tiksi',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': -7.29,
#   'Humidity': 90,
#   'Cloudiness': 97,
#   'Wind Speed': 6.38,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Inhambane',
#   'Lat': -23.86,
#   'Lng': 35.38,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Weather': 'scattered clouds',
#   'Country': 'MZ'},
#  {'City': 'Castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 83.19,
#   'Humidity': 48,
#   'Cloudiness': 12,
#   'Wind Speed': 8.21,
#   'Current Weather': 'moderate rain',
#   'Country': 'BR'},
#  {'City': 'Norman Wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': -4,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 4.23,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CA'},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 53.01,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 8.01,
#   'Current Weather': 'moderate rain',
#   'Country': 'NZ'},
#  {'City': 'Kruisfontein',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 63,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 1.01,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ZA'},
#  {'City': 'Halifax',
#   'Lat': 44.65,
#   'Lng': -63.57,
#   'Max Temp': 41,
#   'Humidity': 51,
#   'Cloudiness': 52,
#   'Wind Speed': 7,
#   'Current Weather': 'broken clouds',
#   'Country': 'CA'},
#  {'City': 'Kushima',
#   'Lat': 31.46,
#   'Lng': 131.23,
#   'Max Temp': 62.01,
#   'Humidity': 88,
#   'Cloudiness': 23,
#   'Wind Speed': 3,
#   'Current Weather': 'few clouds',
#   'Country': 'JP'},
#  {'City': 'Vyazemskiy',
#   'Lat': 47.54,
#   'Lng': 134.75,
#   'Max Temp': 25.66,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 12.24,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Balakhninskiy',
#   'Lat': 58.01,
#   'Lng': 114.28,
#   'Max Temp': 10.06,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Tuatapere',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 53.01,
#   'Humidity': 96,
#   'Cloudiness': 95,
#   'Wind Speed': 8.01,
#   'Current Weather': 'light rain',
#   'Country': 'NZ'},
#  {'City': 'Russell',
#   'Lat': 32.35,
#   'Lng': -85.2,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Weather': 'broken clouds',
#   'Country': 'US'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.05,
#   'Lng': 158.65,
#   'Max Temp': 28.4,
#   'Humidity': 74,
#   'Cloudiness': 11,
#   'Wind Speed': 8.95,
#   'Current Weather': 'few clouds',
#   'Country': 'RU'},
#  {'City': 'Terenos',
#   'Lat': -20.44,
#   'Lng': -54.86,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 19.46,
#   'Current Weather': 'thunderstorm',
#   'Country': 'BR'},
#  {'City': 'Yetkul',
#   'Lat': 54.82,
#   'Lng': 61.59,
#   'Max Temp': 5,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Hofn',
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 39.2,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Current Weather': 'broken clouds',
#   'Country': 'IS'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 66.2,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Weather': 'scattered clouds',
#   'Country': 'PT'},
#  {'City': 'Nalut',
#   'Lat': 30.33,
#   'Lng': 10.85,
#   'Max Temp': 61.21,
#   'Humidity': 37,
#   'Cloudiness': 95,
#   'Wind Speed': 4.76,
#   'Current Weather': 'overcast clouds',
#   'Country': 'LY'},
#  {'City': 'Cidreira',
#   'Lat': -30.18,
#   'Lng': -50.21,
#   'Max Temp': 79.75,
#   'Humidity': 65,
#   'Cloudiness': 99,
#   'Wind Speed': 8.72,
#   'Current Weather': 'overcast clouds',
#   'Country': 'BR'},
#  {'City': 'Dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 16.43,
#   'Humidity': 98,
#   'Cloudiness': 74,
#   'Wind Speed': 12.93,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Svetlyy',
#   'Lat': 54.67,
#   'Lng': 20.13,
#   'Max Temp': 50,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.95,
#   'Current Weather': 'light rain',
#   'Country': 'RU'},
#  {'City': 'Alice Springs',
#   'Lat': -23.7,
#   'Lng': 133.88,
#   'Max Temp': 80.6,
#   'Humidity': 47,
#   'Cloudiness': 100,
#   'Wind Speed': 11.41,
#   'Current Weather': 'overcast clouds',
#   'Country': 'AU'},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Lat': -8.9,
#   'Lng': -35.15,
#   'Max Temp': 82.04,
#   'Humidity': 72,
#   'Cloudiness': 68,
#   'Wind Speed': 11.34,
#   'Current Weather': 'broken clouds',
#   'Country': 'BR'},
#  {'City': 'Algeciras',
#   'Lat': 36.13,
#   'Lng': -5.45,
#   'Max Temp': 68,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Weather': 'clear sky',
#   'Country': 'ES'},
#  {'City': 'Smithers',
#   'Lat': 54.78,
#   'Lng': -127.17,
#   'Max Temp': 26.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Weather': 'light snow',
#   'Country': 'CA'},
#  {'City': 'Flinders',
#   'Lat': -34.58,
#   'Lng': 150.86,
#   'Max Temp': 72,
#   'Humidity': 86,
#   'Cloudiness': 47,
#   'Wind Speed': 1.01,
#   'Current Weather': 'scattered clouds',
#   'Country': 'AU'},
#  {'City': 'Bejar',
#   'Lat': 40.39,
#   'Lng': -5.76,
#   'Max Temp': 57,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.53,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ES'},
#  {'City': 'Gravdal',
#   'Lat': 68.12,
#   'Lng': 13.5,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Weather': 'scattered clouds',
#   'Country': 'NO'},
#  {'City': 'Suzhou',
#   'Lat': 31.31,
#   'Lng': 120.62,
#   'Max Temp': 61,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 5.93,
#   'Current Weather': 'few clouds',
#   'Country': 'CN'},
#  {'City': 'Khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 2.21,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 10.47,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Palmer',
#   'Lat': 42.16,
#   'Lng': -72.33,
#   'Max Temp': 46.99,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 10.63,
#   'Current Weather': 'broken clouds',
#   'Country': 'US'},
#  {'City': 'Constitucion',
#   'Lat': -35.33,
#   'Lng': -72.42,
#   'Max Temp': 62.91,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 11.74,
#   'Current Weather': 'clear sky',
#   'Country': 'CL'},
#  {'City': 'Kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 57,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 4.65,
#   'Current Weather': 'overcast clouds',
#   'Country': 'NZ'},
#  {'City': 'Avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 26,
#   'Wind Speed': 11.41,
#   'Current Weather': 'light rain',
#   'Country': 'CK'},
#  {'City': 'Pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 15.08,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 8.93,
#   'Current Weather': 'light snow',
#   'Country': 'RU'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': -27.44,
#   'Humidity': 87,
#   'Cloudiness': 54,
#   'Wind Speed': 1.43,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 73.4,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Weather': 'broken clouds',
#   'Country': 'MU'},
#  {'City': 'Chapais',
#   'Lat': 49.78,
#   'Lng': -74.85,
#   'Max Temp': 26.6,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Current Weather': 'broken clouds',
#   'Country': 'CA'},
#  {'City': 'Vardo',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 41,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 43.62,
#   'Current Weather': 'light intensity drizzle',
#   'Country': 'NO'},
#  {'City': 'Kjopsvik',
#   'Lat': 68.1,
#   'Lng': 16.37,
#   'Max Temp': 42.01,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 12.75,
#   'Current Weather': 'clear sky',
#   'Country': 'NO'},
#  {'City': 'Aklavik',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 17.6,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Current Weather': 'light snow',
#   'Country': 'CA'},
#  {'City': 'Sao Felix Do Xingu',
#   'Lat': -6.64,
#   'Lng': -51.99,
#   'Max Temp': 93.54,
#   'Humidity': 45,
#   'Cloudiness': 66,
#   'Wind Speed': 3.22,
#   'Current Weather': 'broken clouds',
#   'Country': 'BR'},
#  {'City': 'Naze',
#   'Lat': 28.37,
#   'Lng': 129.48,
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Weather': 'scattered clouds',
#   'Country': 'JP'},
#  {'City': 'Borzna',
#   'Lat': 51.25,
#   'Lng': 32.43,
#   'Max Temp': 36.63,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 9.44,
#   'Current Weather': 'overcast clouds',
#   'Country': 'UA'},
#  {'City': 'Union',
#   'Lat': 40.63,
#   'Lng': -74.27,
#   'Max Temp': 57.2,
#   'Humidity': 54,
#   'Cloudiness': 90,
#   'Wind Speed': 13.87,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Asosa',
#   'Lat': 10.07,
#   'Lng': 34.53,
#   'Max Temp': 68.36,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 4.23,
#   'Current Weather': 'clear sky',
#   'Country': 'ET'},
#  {'City': 'Ranong',
#   'Lat': 9.97,
#   'Lng': 98.63,
#   'Max Temp': 75.4,
#   'Humidity': 84,
#   'Cloudiness': 70,
#   'Wind Speed': 4.94,
#   'Current Weather': 'broken clouds',
#   'Country': 'TH'},
#  {'City': 'Yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 0,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CA'},
#  {'City': 'Butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 80.73,
#   'Humidity': 72,
#   'Cloudiness': 17,
#   'Wind Speed': 11.9,
#   'Current Weather': 'few clouds',
#   'Country': 'KI'},
#  {'City': 'Preobrazheniye',
#   'Lat': 42.9,
#   'Lng': 133.91,
#   'Max Temp': 42.6,
#   'Humidity': 78,
#   'Cloudiness': 18,
#   'Wind Speed': 10.51,
#   'Current Weather': 'few clouds',
#   'Country': 'RU'},
#  {'City': 'Potsdam',
#   'Lat': 52.4,
#   'Lng': 13.07,
#   'Max Temp': 48.99,
#   'Humidity': 79,
#   'Cloudiness': 77,
#   'Wind Speed': 3,
#   'Current Weather': 'broken clouds',
#   'Country': 'DE'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 69.8,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Current Weather': 'broken clouds',
#   'Country': 'PT'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.49,
#   'Lng': 50.81,
#   'Max Temp': 77,
#   'Humidity': 75,
#   'Cloudiness': 15,
#   'Wind Speed': 19.93,
#   'Current Weather': 'few clouds',
#   'Country': 'SO'},
#  {'City': 'Baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': -4.02,
#   'Humidity': 88,
#   'Cloudiness': 61,
#   'Wind Speed': 2.3,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Mogadishu',
#   'Lat': 2.04,
#   'Lng': 45.34,
#   'Max Temp': 80.26,
#   'Humidity': 78,
#   'Cloudiness': 9,
#   'Wind Speed': 11.45,
#   'Current Weather': 'clear sky',
#   'Country': 'SO'},
#  {'City': 'Kumluca',
#   'Lat': 36.37,
#   'Lng': 30.29,
#   'Max Temp': 64.4,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 4.59,
#   'Current Weather': 'clear sky',
#   'Country': 'TR'},
#  {'City': 'Thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 5,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Weather': 'light snow',
#   'Country': 'CA'},
#  {'City': 'Ust-Tsilma',
#   'Lat': 65.44,
#   'Lng': 52.15,
#   'Max Temp': 30,
#   'Humidity': 98,
#   'Cloudiness': 99,
#   'Wind Speed': 5.14,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Nchelenge',
#   'Lat': -9.35,
#   'Lng': 28.73,
#   'Max Temp': 68.92,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.67,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ZM'},
#  {'City': 'Torbay',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 35.01,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 17.22,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CA'},
#  {'City': 'Sur',
#   'Lat': 22.57,
#   'Lng': 59.53,
#   'Max Temp': 73.22,
#   'Humidity': 71,
#   'Cloudiness': 30,
#   'Wind Speed': 3.04,
#   'Current Weather': 'scattered clouds',
#   'Country': 'OM'},
#  {'City': 'Iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 26.6,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Weather': 'broken clouds',
#   'Country': 'CA'},
#  {'City': 'Odweyne',
#   'Lat': 9.41,
#   'Lng': 45.06,
#   'Max Temp': 69.71,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 15.46,
#   'Current Weather': 'clear sky',
#   'Country': 'SO'},
#  {'City': 'Nevelsk',
#   'Lat': 46.67,
#   'Lng': 141.86,
#   'Max Temp': 28.4,
#   'Humidity': 92,
#   'Cloudiness': 28,
#   'Wind Speed': 11.05,
#   'Current Weather': 'smoke',
#   'Country': 'RU'},
#  {'City': 'Camabatela',
#   'Lat': -8.19,
#   'Lng': 15.38,
#   'Max Temp': 64.85,
#   'Humidity': 100,
#   'Cloudiness': 38,
#   'Wind Speed': 3.49,
#   'Current Weather': 'light rain',
#   'Country': 'AO'},
#  {'City': 'Salmo',
#   'Lat': 49.2,
#   'Lng': -117.27,
#   'Max Temp': 37.4,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CA'},
#  {'City': 'Timizart',
#   'Lat': 36.8,
#   'Lng': 4.27,
#   'Max Temp': 59.72,
#   'Humidity': 90,
#   'Cloudiness': 43,
#   'Wind Speed': 3.62,
#   'Current Weather': 'scattered clouds',
#   'Country': 'DZ'},
#  {'City': 'Uige',
#   'Lat': -7.61,
#   'Lng': 15.06,
#   'Max Temp': 69.26,
#   'Humidity': 93,
#   'Cloudiness': 69,
#   'Wind Speed': 2.06,
#   'Current Weather': 'light rain',
#   'Country': 'AO'},
#  {'City': 'Charqueada',
#   'Lat': -22.51,
#   'Lng': -47.78,
#   'Max Temp': 87.84,
#   'Humidity': 45,
#   'Cloudiness': 34,
#   'Wind Speed': 5.75,
#   'Current Weather': 'heavy intensity rain',
#   'Country': 'BR'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 53.01,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Current Weather': 'moderate rain',
#   'Country': 'NZ'},
#  {'City': 'Simao',
#   'Lat': 22.79,
#   'Lng': 100.97,
#   'Max Temp': 58.51,
#   'Humidity': 82,
#   'Cloudiness': 22,
#   'Wind Speed': 1.5,
#   'Current Weather': 'few clouds',
#   'Country': 'CN'},
#  {'City': 'Bambanglipuro',
#   'Lat': -7.95,
#   'Lng': 110.28,
#   'Max Temp': 78.94,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 7.76,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ID'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.43,
#   'Lng': 71.72,
#   'Max Temp': 37.4,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'UZ'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Current Weather': 'few clouds',
#   'Country': 'BR'},
#  {'City': 'Toropets',
#   'Lat': 56.5,
#   'Lng': 31.64,
#   'Max Temp': 30.9,
#   'Humidity': 95,
#   'Cloudiness': 98,
#   'Wind Speed': 7.29,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Kavieng',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 82.8,
#   'Humidity': 77,
#   'Cloudiness': 94,
#   'Wind Speed': 12.39,
#   'Current Weather': 'moderate rain',
#   'Country': 'PG'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 83.03,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 20.2,
#   'Current Weather': 'moderate rain',
#   'Country': 'MV'},
#  {'City': 'Nantucket',
#   'Lat': 41.28,
#   'Lng': -70.1,
#   'Max Temp': 50,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Sumbe',
#   'Lat': -11.21,
#   'Lng': 13.84,
#   'Max Temp': 77.81,
#   'Humidity': 78,
#   'Cloudiness': 34,
#   'Wind Speed': 8.57,
#   'Current Weather': 'scattered clouds',
#   'Country': 'AO'},
#  {'City': 'Nhulunbuy',
#   'Lat': -12.23,
#   'Lng': 136.77,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 32,
#   'Wind Speed': 6.89,
#   'Current Weather': 'scattered clouds',
#   'Country': 'AU'},
#  {'City': 'Bonthe',
#   'Lat': 7.53,
#   'Lng': -12.51,
#   'Max Temp': 83.1,
#   'Humidity': 72,
#   'Cloudiness': 9,
#   'Wind Speed': 7.85,
#   'Current Weather': 'clear sky',
#   'Country': 'SL'},
#  {'City': 'San Policarpo',
#   'Lat': 12.18,
#   'Lng': 125.51,
#   'Max Temp': 81.54,
#   'Humidity': 86,
#   'Cloudiness': 66,
#   'Wind Speed': 8.97,
#   'Current Weather': 'broken clouds',
#   'Country': 'PH'},
#  {'City': 'Waddan',
#   'Lat': 29.16,
#   'Lng': 16.14,
#   'Max Temp': 65.98,
#   'Humidity': 47,
#   'Cloudiness': 81,
#   'Wind Speed': 4,
#   'Current Weather': 'broken clouds',
#   'Country': 'LY'},
#  {'City': 'Ondjiva',
#   'Lat': -17.07,
#   'Lng': 15.73,
#   'Max Temp': 78.8,
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 7.23,
#   'Current Weather': 'light rain',
#   'Country': 'AO'},
#  {'City': 'Santarem',
#   'Lat': -2.44,
#   'Lng': -54.71,
#   'Max Temp': 89.6,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BR'},
#  {'City': 'Labuhan',
#   'Lat': -6.88,
#   'Lng': 112.21,
#   'Max Temp': 81.27,
#   'Humidity': 79,
#   'Cloudiness': 54,
#   'Wind Speed': 5.59,
#   'Current Weather': 'broken clouds',
#   'Country': 'ID'},
#  {'City': 'Provideniya',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 24.87,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.87,
#   'Current Weather': 'light snow',
#   'Country': 'RU'},
#  {'City': 'Tura',
#   'Lat': 25.52,
#   'Lng': 90.22,
#   'Max Temp': 66.24,
#   'Humidity': 82,
#   'Cloudiness': 5,
#   'Wind Speed': 4.05,
#   'Current Weather': 'clear sky',
#   'Country': 'IN'},
#  {'City': 'Yarmouth',
#   'Lat': 41.71,
#   'Lng': -70.23,
#   'Max Temp': 51.01,
#   'Humidity': 49,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Sitka',
#   'Lat': 57.05,
#   'Lng': -135.33,
#   'Max Temp': 30.2,
#   'Humidity': 92,
#   'Cloudiness': 40,
#   'Wind Speed': 3.02,
#   'Current Weather': 'scattered clouds',
#   'Country': 'US'},
#  {'City': 'Waingapu',
#   'Lat': -9.66,
#   'Lng': 120.26,
#   'Max Temp': 80.87,
#   'Humidity': 66,
#   'Cloudiness': 77,
#   'Wind Speed': 3.71,
#   'Current Weather': 'broken clouds',
#   'Country': 'ID'},
#  {'City': 'Awjilah',
#   'Lat': 29.11,
#   'Lng': 21.29,
#   'Max Temp': 61.93,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 4.34,
#   'Current Weather': 'clear sky',
#   'Country': 'LY'},
#  {'City': 'Karratha',
#   'Lat': -20.74,
#   'Lng': 116.85,
#   'Max Temp': 74.48,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 9.26,
#   'Current Weather': 'clear sky',
#   'Country': 'AU'},
#  {'City': 'Portland',
#   'Lat': 45.52,
#   'Lng': -122.68,
#   'Max Temp': 53.01,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Weather': 'scattered clouds',
#   'Country': 'US'},
#  {'City': 'Sept-Iles',
#   'Lat': 50.2,
#   'Lng': -66.38,
#   'Max Temp': 33.01,
#   'Humidity': 87,
#   'Cloudiness': 34,
#   'Wind Speed': 2.24,
#   'Current Weather': 'scattered clouds',
#   'Country': 'CA'},
#  {'City': 'Tank',
#   'Lat': 32.22,
#   'Lng': 70.38,
#   'Max Temp': 60.58,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 8.84,
#   'Current Weather': 'clear sky',
#   'Country': 'PK'},
#  {'City': 'Sortavala',
#   'Lat': 61.71,
#   'Lng': 30.69,
#   'Max Temp': 35.58,
#   'Humidity': 85,
#   'Cloudiness': 95,
#   'Wind Speed': 12.3,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Fortuna',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 60.01,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Sarny',
#   'Lat': 51.34,
#   'Lng': 26.6,
#   'Max Temp': 44.42,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 3.51,
#   'Current Weather': 'overcast clouds',
#   'Country': 'UA'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -9.13,
#   'Humidity': 91,
#   'Cloudiness': 79,
#   'Wind Speed': 4.38,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Derzhavinsk',
#   'Lat': 51.1,
#   'Lng': 66.32,
#   'Max Temp': 14.68,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 11.59,
#   'Current Weather': 'overcast clouds',
#   'Country': 'KZ'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 14.27,
#   'Humidity': 87,
#   'Cloudiness': 97,
#   'Wind Speed': 16.06,
#   'Current Weather': 'overcast clouds',
#   'Country': 'GL'},
#  {'City': 'Ariguani',
#   'Lat': 10.25,
#   'Lng': -74,
#   'Max Temp': 86,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CO'},
#  {'City': 'Geraldton',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 53.6,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Weather': 'clear sky',
#   'Country': 'AU'},
#  {'City': 'Buala',
#   'Lat': -8.14,
#   'Lng': 159.59,
#   'Max Temp': 81.73,
#   'Humidity': 77,
#   'Cloudiness': 96,
#   'Wind Speed': 6.35,
#   'Current Weather': 'overcast clouds',
#   'Country': 'SB'},
#  {'City': 'Tilichiki',
#   'Lat': 60.47,
#   'Lng': 166.1,
#   'Max Temp': 33.58,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 8.03,
#   'Current Weather': 'moderate rain',
#   'Country': 'RU'},
#  {'City': 'Mastic Beach',
#   'Lat': 40.77,
#   'Lng': -72.85,
#   'Max Temp': 55.99,
#   'Humidity': 73,
#   'Cloudiness': 37,
#   'Wind Speed': 5.99,
#   'Current Weather': 'scattered clouds',
#   'Country': 'US'},
#  {'City': 'Poddorye',
#   'Lat': 57.47,
#   'Lng': 31.12,
#   'Max Temp': 28.26,
#   'Humidity': 97,
#   'Cloudiness': 7,
#   'Wind Speed': 5.32,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Xuzhou',
#   'Lat': 34.18,
#   'Lng': 117.16,
#   'Max Temp': 54.3,
#   'Humidity': 82,
#   'Cloudiness': 3,
#   'Wind Speed': 7.87,
#   'Current Weather': 'clear sky',
#   'Country': 'CN'},
#  {'City': 'Margate',
#   'Lat': 51.38,
#   'Lng': 1.39,
#   'Max Temp': 51.01,
#   'Humidity': 84,
#   'Cloudiness': 47,
#   'Wind Speed': 5.01,
#   'Current Weather': 'heavy intensity rain',
#   'Country': 'GB'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.83,
#   'Lng': 70.83,
#   'Max Temp': 6.58,
#   'Humidity': 93,
#   'Cloudiness': 73,
#   'Wind Speed': 9.26,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Abu Samrah',
#   'Lat': 35.3,
#   'Lng': 37.18,
#   'Max Temp': 55,
#   'Humidity': 82,
#   'Cloudiness': 72,
#   'Wind Speed': 4.05,
#   'Current Weather': 'broken clouds',
#   'Country': 'SY'},
#  {'City': 'Acari',
#   'Lat': -15.43,
#   'Lng': -74.62,
#   'Max Temp': 78.01,
#   'Humidity': 41,
#   'Cloudiness': 53,
#   'Wind Speed': 12.15,
#   'Current Weather': 'broken clouds',
#   'Country': 'PE'},
#  {'City': 'Ndjole',
#   'Lat': -0.18,
#   'Lng': 10.76,
#   'Max Temp': 76.66,
#   'Humidity': 91,
#   'Cloudiness': 24,
#   'Wind Speed': 2.39,
#   'Current Weather': 'light rain',
#   'Country': 'GA'},
#  {'City': 'Luanda',
#   'Lat': -8.84,
#   'Lng': 13.23,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Weather': 'scattered clouds',
#   'Country': 'AO'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.72,
#   'Lng': -25.43,
#   'Max Temp': 64.4,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Weather': 'broken clouds',
#   'Country': 'PT'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 82,
#   'Humidity': 57,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Current Weather': 'few clouds',
#   'Country': 'MX'},
#  {'City': 'Wewak',
#   'Lat': -3.55,
#   'Lng': 143.63,
#   'Max Temp': 79.59,
#   'Humidity': 84,
#   'Cloudiness': 94,
#   'Wind Speed': 7.56,
#   'Current Weather': 'light rain',
#   'Country': 'PG'},
#  {'City': 'San Patricio',
#   'Lat': 28.02,
#   'Lng': -97.52,
#   'Max Temp': 77,
#   'Humidity': 36,
#   'Cloudiness': 1,
#   'Wind Speed': 19.46,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Naron',
#   'Lat': 43.52,
#   'Lng': -8.15,
#   'Max Temp': 59,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ES'},
#  {'City': 'Tezu',
#   'Lat': 27.92,
#   'Lng': 96.17,
#   'Max Temp': 67.78,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 4.09,
#   'Current Weather': 'clear sky',
#   'Country': 'IN'},
#  {'City': 'Kumbhraj',
#   'Lat': 24.37,
#   'Lng': 77.05,
#   'Max Temp': 75.7,
#   'Humidity': 46,
#   'Cloudiness': 73,
#   'Wind Speed': 2.37,
#   'Current Weather': 'broken clouds',
#   'Country': 'IN'},
#  {'City': 'Nanortalik',
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 26.69,
#   'Humidity': 87,
#   'Cloudiness': 65,
#   'Wind Speed': 9.01,
#   'Current Weather': 'broken clouds',
#   'Country': 'GL'},
#  {'City': 'Marawi',
#   'Lat': 8,
#   'Lng': 124.29,
#   'Max Temp': 77,
#   'Humidity': 91,
#   'Cloudiness': 96,
#   'Wind Speed': 5.01,
#   'Current Weather': 'overcast clouds',
#   'Country': 'PH'},
#  {'City': 'Borba',
#   'Lat': -4.39,
#   'Lng': -59.59,
#   'Max Temp': 97.88,
#   'Humidity': 39,
#   'Cloudiness': 14,
#   'Wind Speed': 4.29,
#   'Current Weather': 'few clouds',
#   'Country': 'BR'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 39.2,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Weather': 'broken clouds',
#   'Country': 'IS'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 73.4,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Weather': 'broken clouds',
#   'Country': 'RE'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 36.14,
#   'Humidity': 83,
#   'Cloudiness': 62,
#   'Wind Speed': 9.04,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Tocopilla',
#   'Lat': -22.09,
#   'Lng': -70.2,
#   'Max Temp': 66.99,
#   'Humidity': 51,
#   'Cloudiness': 12,
#   'Wind Speed': 7.07,
#   'Current Weather': 'few clouds',
#   'Country': 'CL'},
#  {'City': 'Manokwari',
#   'Lat': -0.87,
#   'Lng': 134.08,
#   'Max Temp': 79.68,
#   'Humidity': 75,
#   'Cloudiness': 74,
#   'Wind Speed': 5.5,
#   'Current Weather': 'broken clouds',
#   'Country': 'ID'},
#  {'City': 'Shemgang',
#   'Lat': 27.22,
#   'Lng': 90.66,
#   'Max Temp': 50.79,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 5.68,
#   'Current Weather': 'clear sky',
#   'Country': 'BT'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 4.42,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.68,
#   'Current Weather': 'light snow',
#   'Country': 'RU'},
#  {'City': 'Suluq',
#   'Lat': 31.67,
#   'Lng': 20.25,
#   'Max Temp': 64.69,
#   'Humidity': 70,
#   'Cloudiness': 37,
#   'Wind Speed': 8.57,
#   'Current Weather': 'scattered clouds',
#   'Country': 'LY'},
#  {'City': 'Kailua',
#   'Lat': 21.4,
#   'Lng': -157.74,
#   'Max Temp': 75,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Current Weather': 'few clouds',
#   'Country': 'US'},
#  {'City': 'Talnakh',
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Max Temp': 10.4,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Current Weather': 'snow',
#   'Country': 'RU'},
#  {'City': 'Seymchan',
#   'Lat': 62.88,
#   'Lng': 152.43,
#   'Max Temp': -5.49,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Current Weather': 'light snow',
#   'Country': 'RU'},
#  {'City': 'Shache',
#   'Lat': 38.42,
#   'Lng': 77.24,
#   'Max Temp': 42.73,
#   'Humidity': 54,
#   'Cloudiness': 97,
#   'Wind Speed': 6.49,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CN'},
#  {'City': 'Xining',
#   'Lat': 36.62,
#   'Lng': 101.77,
#   'Max Temp': 43.52,
#   'Humidity': 51,
#   'Cloudiness': 11,
#   'Wind Speed': 1.95,
#   'Current Weather': 'few clouds',
#   'Country': 'CN'},
#  {'City': 'Villazon',
#   'Lat': -22.09,
#   'Lng': -65.59,
#   'Max Temp': 73.08,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 26.22,
#   'Current Weather': 'clear sky',
#   'Country': 'BO'},
#  {'City': 'Puerto Leguizamo',
#   'Lat': -0.19,
#   'Lng': -74.78,
#   'Max Temp': 82.26,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CO'},
#  {'City': 'Eureka',
#   'Lat': 40.8,
#   'Lng': -124.16,
#   'Max Temp': 60.01,
#   'Humidity': 47,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Forrest City',
#   'Lat': 35.01,
#   'Lng': -90.79,
#   'Max Temp': 60.8,
#   'Humidity': 35,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Wencheng',
#   'Lat': 33.06,
#   'Lng': 113.8,
#   'Max Temp': 54.03,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 2.1,
#   'Current Weather': 'clear sky',
#   'Country': 'CN'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.98,
#   'Lng': -114.06,
#   'Max Temp': 75.16,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 2.1,
#   'Current Weather': 'clear sky',
#   'Country': 'MX'},
#  {'City': 'Apiai',
#   'Lat': -24.51,
#   'Lng': -48.84,
#   'Max Temp': 86.13,
#   'Humidity': 39,
#   'Cloudiness': 10,
#   'Wind Speed': 4.61,
#   'Current Weather': 'clear sky',
#   'Country': 'BR'},
#  {'City': 'Half Moon Bay',
#   'Lat': 37.46,
#   'Lng': -122.43,
#   'Max Temp': 60.8,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Olafsvik',
#   'Lat': 64.89,
#   'Lng': -23.71,
#   'Max Temp': 35.67,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 16.33,
#   'Current Weather': 'overcast clouds',
#   'Country': 'IS'},
#  {'City': 'Narsaq',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 16.95,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 6.06,
#   'Current Weather': 'clear sky',
#   'Country': 'GL'},
#  {'City': 'Leh',
#   'Lat': 34.17,
#   'Lng': 77.58,
#   'Max Temp': 28.56,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 4.47,
#   'Current Weather': 'overcast clouds',
#   'Country': 'IN'},
#  {'City': 'East London',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Current Weather': 'few clouds',
#   'Country': 'ZA'},
#  {'City': 'Dongsheng',
#   'Lat': 39.82,
#   'Lng': 109.98,
#   'Max Temp': 44.4,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 11.68,
#   'Current Weather': 'clear sky',
#   'Country': 'CN'},
#  {'City': 'Rio Grande City',
#   'Lat': 26.38,
#   'Lng': -98.82,
#   'Max Temp': 82.99,
#   'Humidity': 71,
#   'Cloudiness': 33,
#   'Wind Speed': 11.01,
#   'Current Weather': 'scattered clouds',
#   'Country': 'US'},
#  {'City': 'Melo',
#   'Lat': -32.37,
#   'Lng': -54.18,
#   'Max Temp': 78.17,
#   'Humidity': 71,
#   'Cloudiness': 99,
#   'Wind Speed': 9.15,
#   'Current Weather': 'light rain',
#   'Country': 'UY'},
#  {'City': 'Sayville',
#   'Lat': 40.74,
#   'Lng': -73.08,
#   'Max Temp': 57.2,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 20.8,
#   'Current Weather': 'broken clouds',
#   'Country': 'US'},
#  {'City': 'Taoudenni',
#   'Lat': 22.68,
#   'Lng': -3.98,
#   'Max Temp': 80.78,
#   'Humidity': 18,
#   'Cloudiness': 40,
#   'Wind Speed': 11.7,
#   'Current Weather': 'scattered clouds',
#   'Country': 'ML'},
#  {'City': 'Abu Zabad',
#   'Lat': 12.35,
#   'Lng': 29.25,
#   'Max Temp': 77.29,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 11.48,
#   'Current Weather': 'clear sky',
#   'Country': 'SD'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.66,
#   'Lng': -17.92,
#   'Max Temp': 77,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Weather': 'few clouds',
#   'Country': 'ES'},
#  {'City': 'Xacmaz',
#   'Lat': 41.46,
#   'Lng': 48.81,
#   'Max Temp': 51.76,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 12.53,
#   'Current Weather': 'light rain',
#   'Country': 'AZ'},
#  {'City': 'Puerto Colombia',
#   'Lat': 10.99,
#   'Lng': -74.95,
#   'Max Temp': 84.2,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CO'},
#  {'City': 'Pafos',
#   'Lat': 34.77,
#   'Lng': 32.42,
#   'Max Temp': 60.8,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Weather': 'few clouds',
#   'Country': 'CY'},
#  {'City': 'Lompoc',
#   'Lat': 34.64,
#   'Lng': -120.46,
#   'Max Temp': 62.6,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Tupik',
#   'Lat': 54.43,
#   'Lng': 119.93,
#   'Max Temp': 4.66,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 1.88,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Quelimane',
#   'Lat': -17.88,
#   'Lng': 36.89,
#   'Max Temp': 77,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Weather': 'clear sky',
#   'Country': 'MZ'},
#  {'City': 'Sunland Park',
#   'Lat': 31.8,
#   'Lng': -106.58,
#   'Max Temp': 62.01,
#   'Humidity': 12,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Adavere',
#   'Lat': 58.71,
#   'Lng': 25.9,
#   'Max Temp': 35.01,
#   'Humidity': 86,
#   'Cloudiness': 91,
#   'Wind Speed': 8.05,
#   'Current Weather': 'overcast clouds',
#   'Country': 'EE'},
#  {'City': 'Katsuura',
#   'Lat': 35.13,
#   'Lng': 140.3,
#   'Max Temp': 66.99,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Weather': 'broken clouds',
#   'Country': 'JP'},
#  {'City': 'Calabar',
#   'Lat': 4.95,
#   'Lng': 8.32,
#   'Max Temp': 77.76,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 4.74,
#   'Current Weather': 'overcast clouds',
#   'Country': 'NG'},
#  {'City': 'Sioux Lookout',
#   'Lat': 50.1,
#   'Lng': -91.92,
#   'Max Temp': 30.2,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 13.87,
#   'Current Weather': 'mist',
#   'Country': 'CA'},
#  {'City': 'Yerbogachen',
#   'Lat': 61.28,
#   'Lng': 108.01,
#   'Max Temp': -0.96,
#   'Humidity': 92,
#   'Cloudiness': 61,
#   'Wind Speed': 7.63,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Palmas',
#   'Lat': -10.21,
#   'Lng': -48.36,
#   'Max Temp': 93.2,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BR'},
#  {'City': 'Shelburne',
#   'Lat': 44.08,
#   'Lng': -80.2,
#   'Max Temp': 48.99,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 24.43,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CA'},
#  {'City': 'Champerico',
#   'Lat': 14.3,
#   'Lng': -91.92,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'GT'},
#  {'City': 'Kilimatinde',
#   'Lat': -5.85,
#   'Lng': 34.95,
#   'Max Temp': 75.74,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Current Weather': 'light rain',
#   'Country': 'TZ'},
#  {'City': 'Tual',
#   'Lat': -5.67,
#   'Lng': 132.75,
#   'Max Temp': 83.52,
#   'Humidity': 78,
#   'Cloudiness': 68,
#   'Wind Speed': 13.8,
#   'Current Weather': 'light rain',
#   'Country': 'ID'},
#  {'City': 'Shebunino',
#   'Lat': 46.43,
#   'Lng': 141.86,
#   'Max Temp': 41.52,
#   'Humidity': 73,
#   'Cloudiness': 25,
#   'Wind Speed': 10.96,
#   'Current Weather': 'scattered clouds',
#   'Country': 'RU'},
#  {'City': 'Wittlich',
#   'Lat': 49.98,
#   'Lng': 6.88,
#   'Max Temp': 57,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 17.22,
#   'Current Weather': 'light rain',
#   'Country': 'DE'},
#  {'City': 'Vostok',
#   'Lat': 46.49,
#   'Lng': 135.88,
#   'Max Temp': 20.95,
#   'Humidity': 96,
#   'Cloudiness': 49,
#   'Wind Speed': 7.34,
#   'Current Weather': 'scattered clouds',
#   'Country': 'RU'},
#  {'City': 'Port Blair',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 79.9,
#   'Humidity': 79,
#   'Cloudiness': 34,
#   'Wind Speed': 9.98,
#   'Current Weather': 'scattered clouds',
#   'Country': 'IN'},
#  {'City': 'Conceicao Do Mato Dentro',
#   'Lat': -19.04,
#   'Lng': -43.42,
#   'Max Temp': 80.26,
#   'Humidity': 68,
#   'Cloudiness': 88,
#   'Wind Speed': 3.76,
#   'Current Weather': 'moderate rain',
#   'Country': 'BR'},
# ...
#   'Lng': 44.74,
#   'Max Temp': 37.4,
#   'Humidity': 100,
#   'Cloudiness': 98,
#   'Wind Speed': 1.32,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Bad Munstereifel',
#   'Lat': 50.55,
#   'Lng': 6.77,
#   'Max Temp': 60.01,
#   'Humidity': 85,
#   'Cloudiness': 96,
#   'Wind Speed': 14,
#   'Current Weather': 'light rain',
#   'Country': 'DE'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.43,
#   'Lng': 152.92,
#   'Max Temp': 66.2,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Weather': 'scattered clouds',
#   'Country': 'AU'},
#  {'City': 'San Carlos De Bariloche',
#   'Lat': -41.15,
#   'Lng': -71.31,
#   'Max Temp': 70,
#   'Humidity': 25,
#   'Cloudiness': 40,
#   'Wind Speed': 17.22,
#   'Current Weather': 'scattered clouds',
#   'Country': 'AR'},
#  {'City': 'Itamaraju',
#   'Lat': -17.04,
#   'Lng': -39.53,
#   'Max Temp': 87.58,
#   'Humidity': 57,
#   'Cloudiness': 94,
#   'Wind Speed': 4.56,
#   'Current Weather': 'heavy intensity rain',
#   'Country': 'BR'},
#  {'City': 'Bin Qirdan',
#   'Lat': 33.14,
#   'Lng': 11.22,
#   'Max Temp': 71.26,
#   'Humidity': 37,
#   'Cloudiness': 99,
#   'Wind Speed': 5.93,
#   'Current Weather': 'overcast clouds',
#   'Country': 'TN'},
#  {'City': 'Bundaberg',
#   'Lat': -24.85,
#   'Lng': 152.35,
#   'Max Temp': 75.99,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Weather': 'scattered clouds',
#   'Country': 'AU'},
#  {'City': 'Shestakovo',
#   'Lat': 56.49,
#   'Lng': 103.96,
#   'Max Temp': 11.59,
#   'Humidity': 94,
#   'Cloudiness': 51,
#   'Wind Speed': 1.61,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': -4,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Atherton',
#   'Lat': 53.52,
#   'Lng': -2.49,
#   'Max Temp': 46.99,
#   'Humidity': 81,
#   'Cloudiness': 63,
#   'Wind Speed': 5.01,
#   'Current Weather': 'moderate rain',
#   'Country': 'GB'},
#  {'City': 'Sao Domingos',
#   'Lat': -13.4,
#   'Lng': -46.32,
#   'Max Temp': 86.68,
#   'Humidity': 48,
#   'Cloudiness': 97,
#   'Wind Speed': 3.91,
#   'Current Weather': 'light rain',
#   'Country': 'BR'},
#  {'City': 'Ambulu',
#   'Lat': -8.35,
#   'Lng': 113.61,
#   'Max Temp': 76.71,
#   'Humidity': 86,
#   'Cloudiness': 70,
#   'Wind Speed': 3.67,
#   'Current Weather': 'broken clouds',
#   'Country': 'ID'},
#  {'City': 'Slave Lake',
#   'Lat': 55.28,
#   'Lng': -114.77,
#   'Max Temp': 12.2,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Weather': 'broken clouds',
#   'Country': 'CA'},
#  {'City': 'Gunjur',
#   'Lat': 13.2,
#   'Lng': -16.73,
#   'Max Temp': 91.4,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Weather': 'clear sky',
#   'Country': 'GM'},
#  {'City': 'Kibakwe',
#   'Lat': -6.72,
#   'Lng': 36.37,
#   'Max Temp': 70.93,
#   'Humidity': 74,
#   'Cloudiness': 82,
#   'Wind Speed': 4.92,
#   'Current Weather': 'broken clouds',
#   'Country': 'TZ'},
#  {'City': 'Taywarah',
#   'Lat': 33.35,
#   'Lng': 64.42,
#   'Max Temp': 26.1,
#   'Humidity': 71,
#   'Cloudiness': 15,
#   'Wind Speed': 0.81,
#   'Current Weather': 'few clouds',
#   'Country': 'AF'},
#  {'City': 'Boende',
#   'Lat': -0.22,
#   'Lng': 20.87,
#   'Max Temp': 73.58,
#   'Humidity': 83,
#   'Cloudiness': 74,
#   'Wind Speed': 0.74,
#   'Current Weather': 'broken clouds',
#   'Country': 'CD'},
#  {'City': 'Porto-Vecchio',
#   'Lat': 41.59,
#   'Lng': 9.28,
#   'Max Temp': 62.6,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Current Weather': 'overcast clouds',
#   'Country': 'FR'},
#  {'City': 'Warah',
#   'Lat': 27.45,
#   'Lng': 67.8,
#   'Max Temp': 65.55,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 5.03,
#   'Current Weather': 'clear sky',
#   'Country': 'PK'},
#  {'City': 'Yilan',
#   'Lat': 24.76,
#   'Lng': 121.75,
#   'Max Temp': 75,
#   'Humidity': 99,
#   'Cloudiness': 5,
#   'Wind Speed': 3.53,
#   'Current Weather': 'clear sky',
#   'Country': 'TW'},
#  {'City': 'Dagda',
#   'Lat': 56.1,
#   'Lng': 27.54,
#   'Max Temp': 34.38,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.81,
#   'Current Weather': 'overcast clouds',
#   'Country': 'LV'},
#  {'City': 'Avera',
#   'Lat': 33.19,
#   'Lng': -82.53,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 14.99,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Miri',
#   'Lat': 4.41,
#   'Lng': 114.01,
#   'Max Temp': 78.8,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Current Weather': 'scattered clouds',
#   'Country': 'MY'},
#  {'City': 'Litovko',
#   'Lat': 49.24,
#   'Lng': 135.17,
#   'Max Temp': 25.07,
#   'Humidity': 97,
#   'Cloudiness': 65,
#   'Wind Speed': 8.88,
#   'Current Weather': 'light snow',
#   'Country': 'RU'},
#  {'City': 'Umm Lajj',
#   'Lat': 25.02,
#   'Lng': 37.27,
#   'Max Temp': 75.74,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 9.13,
#   'Current Weather': 'clear sky',
#   'Country': 'SA'},
#  {'City': 'Pareora',
#   'Lat': -44.49,
#   'Lng': 171.21,
#   'Max Temp': 57,
#   'Humidity': 95,
#   'Cloudiness': 95,
#   'Wind Speed': 4.83,
#   'Current Weather': 'overcast clouds',
#   'Country': 'NZ'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.72,
#   'Lng': 150.18,
#   'Max Temp': 62.01,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.06,
#   'Current Weather': 'overcast clouds',
#   'Country': 'AU'},
#  {'City': 'Puertollano',
#   'Lat': 38.69,
#   'Lng': -4.11,
#   'Max Temp': 64,
#   'Humidity': 80,
#   'Cloudiness': 81,
#   'Wind Speed': 3.2,
#   'Current Weather': 'broken clouds',
#   'Country': 'ES'},
#  {'City': 'Tommot',
#   'Lat': 58.96,
#   'Lng': 126.29,
#   'Max Temp': 9.19,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 10.27,
#   'Current Weather': 'light snow',
#   'Country': 'RU'},
#  {'City': 'Sobolevo',
#   'Lat': 54.43,
#   'Lng': 31.9,
#   'Max Temp': 32.76,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.84,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Erie',
#   'Lat': 42.77,
#   'Lng': -78.67,
#   'Max Temp': 55,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 20.8,
#   'Current Weather': 'light rain',
#   'Country': 'US'},
#  {'City': 'Bandarban',
#   'Lat': 22.2,
#   'Lng': 92.23,
#   'Max Temp': 69.64,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 1.59,
#   'Current Weather': 'clear sky',
#   'Country': 'BD'},
#  {'City': 'Takaka',
#   'Lat': -40.85,
#   'Lng': 172.8,
#   'Max Temp': 59,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Current Weather': 'overcast clouds',
#   'Country': 'NZ'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Lat': -0.41,
#   'Lng': -65.02,
#   'Max Temp': 84.92,
#   'Humidity': 72,
#   'Cloudiness': 25,
#   'Wind Speed': 5.39,
#   'Current Weather': 'moderate rain',
#   'Country': 'BR'},
#  {'City': 'Kurumkan',
#   'Lat': 54.3,
#   'Lng': 110.3,
#   'Max Temp': 12.69,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 2.84,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Middletown',
#   'Lat': 39.52,
#   'Lng': -84.4,
#   'Max Temp': 53.6,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 25.28,
#   'Current Weather': 'broken clouds',
#   'Country': 'US'},
#  {'City': 'Maracacume',
#   'Lat': -2.04,
#   'Lng': -45.96,
#   'Max Temp': 87.51,
#   'Humidity': 65,
#   'Cloudiness': 94,
#   'Wind Speed': 6.91,
#   'Current Weather': 'overcast clouds',
#   'Country': 'BR'},
#  {'City': 'West Bay',
#   'Lat': 19.37,
#   'Lng': -81.42,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Current Weather': 'scattered clouds',
#   'Country': 'KY'},
#  {'City': 'Ampanihy',
#   'Lat': -24.7,
#   'Lng': 44.75,
#   'Max Temp': 68.59,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 14.25,
#   'Current Weather': 'clear sky',
#   'Country': 'MG'},
#  {'City': 'Farmington',
#   'Lat': 36.73,
#   'Lng': -108.22,
#   'Max Temp': 35.6,
#   'Humidity': 40,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Tevaitoa',
#   'Lat': -16.78,
#   'Lng': -151.5,
#   'Max Temp': 80.35,
#   'Humidity': 77,
#   'Cloudiness': 36,
#   'Wind Speed': 11.77,
#   'Current Weather': 'scattered clouds',
#   'Country': 'PF'},
#  {'City': 'Kaihua',
#   'Lat': 23.37,
#   'Lng': 104.28,
#   'Max Temp': 55.99,
#   'Humidity': 90,
#   'Cloudiness': 57,
#   'Wind Speed': 1.88,
#   'Current Weather': 'broken clouds',
#   'Country': 'CN'},
#  {'City': 'Vallenar',
#   'Lat': -28.57,
#   'Lng': -70.76,
#   'Max Temp': 78.85,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 12.53,
#   'Current Weather': 'clear sky',
#   'Country': 'CL'},
#  {'City': 'Xai-Xai',
#   'Lat': -25.05,
#   'Lng': 33.64,
#   'Max Temp': 71.85,
#   'Humidity': 73,
#   'Cloudiness': 2,
#   'Wind Speed': 12.19,
#   'Current Weather': 'clear sky',
#   'Country': 'MZ'},
#  {'City': 'Vrangel',
#   'Lat': 42.73,
#   'Lng': 133.08,
#   'Max Temp': 44.92,
#   'Humidity': 76,
#   'Cloudiness': 27,
#   'Wind Speed': 12.97,
#   'Current Weather': 'scattered clouds',
#   'Country': 'RU'},
#  {'City': 'Maldonado',
#   'Lat': -34.67,
#   'Lng': -54.92,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 17.22,
#   'Current Weather': 'scattered clouds',
#   'Country': 'UY'},
#  {'City': 'Brae',
#   'Lat': 60.4,
#   'Lng': -1.35,
#   'Max Temp': 50,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Weather': 'broken clouds',
#   'Country': 'GB'},
#  {'City': 'Pitangui',
#   'Lat': -19.68,
#   'Lng': -44.89,
#   'Max Temp': 86.43,
#   'Humidity': 45,
#   'Cloudiness': 94,
#   'Wind Speed': 3.47,
#   'Current Weather': 'overcast clouds',
#   'Country': 'BR'},
#  {'City': 'Skibbereen',
#   'Lat': 51.55,
#   'Lng': -9.27,
#   'Max Temp': 48.2,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Current Weather': 'broken clouds',
#   'Country': 'IE'},
#  {'City': 'Bima',
#   'Lat': -8.47,
#   'Lng': 118.72,
#   'Max Temp': 78.58,
#   'Humidity': 79,
#   'Cloudiness': 96,
#   'Wind Speed': 3.49,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ID'},
#  {'City': 'Shushenskoye',
#   'Lat': 53.33,
#   'Lng': 91.94,
#   'Max Temp': 12.2,
#   'Humidity': 85,
#   'Cloudiness': 82,
#   'Wind Speed': 0.54,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Vikhorevka',
#   'Lat': 56.12,
#   'Lng': 101.16,
#   'Max Temp': 12,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Cairns',
#   'Lat': -16.92,
#   'Lng': 145.77,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 50,
#   'Wind Speed': 8.05,
#   'Current Weather': 'scattered clouds',
#   'Country': 'AU'},
#  {'City': 'Grass Valley',
#   'Lat': 39.22,
#   'Lng': -121.06,
#   'Max Temp': 57.2,
#   'Humidity': 26,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Gao',
#   'Lat': 16.64,
#   'Lng': 1.64,
#   'Max Temp': 82.26,
#   'Humidity': 17,
#   'Cloudiness': 5,
#   'Wind Speed': 9.4,
#   'Current Weather': 'clear sky',
#   'Country': 'ML'},
#  {'City': 'Lata',
#   'Lat': 40.16,
#   'Lng': -8.33,
#   'Max Temp': 66,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Weather': 'overcast clouds',
#   'Country': 'PT'},
#  {'City': 'Dunedin',
#   'Lat': -45.87,
#   'Lng': 170.5,
#   'Max Temp': 57,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 8.68,
#   'Current Weather': 'overcast clouds',
#   'Country': 'NZ'},
#  {'City': 'Mezhdurechensk',
#   'Lat': 53.69,
#   'Lng': 88.06,
#   'Max Temp': 23.92,
#   'Humidity': 87,
#   'Cloudiness': 78,
#   'Wind Speed': 3.42,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Kudahuvadhoo',
#   'Lat': 2.67,
#   'Lng': 72.89,
#   'Max Temp': 83.07,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Current Weather': 'light rain',
#   'Country': 'MV'},
#  {'City': 'Hayden',
#   'Lat': 47.77,
#   'Lng': -116.79,
#   'Max Temp': 42.8,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 17.22,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.47,
#   'Max Temp': 1.65,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': 21.33,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 10.58,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Acarau',
#   'Lat': -2.89,
#   'Lng': -40.12,
#   'Max Temp': 87.89,
#   'Humidity': 55,
#   'Cloudiness': 36,
#   'Wind Speed': 20.89,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BR'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.81,
#   'Lng': -122.7,
#   'Max Temp': 10.4,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Weather': 'light snow',
#   'Country': 'CA'},
#  {'City': 'Hue',
#   'Lat': 16.47,
#   'Lng': 107.6,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Weather': 'light rain',
#   'Country': 'VN'},
#  {'City': 'Hervey Bay',
#   'Lat': -25.3,
#   'Lng': 152.85,
#   'Max Temp': 75,
#   'Humidity': 87,
#   'Cloudiness': 2,
#   'Wind Speed': 1.01,
#   'Current Weather': 'clear sky',
#   'Country': 'AU'},
#  {'City': 'Bilibino',
#   'Lat': 68.05,
#   'Lng': 166.44,
#   'Max Temp': 9.54,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.94,
#   'Current Weather': 'snow',
#   'Country': 'RU'},
#  {'City': 'Binika',
#   'Lat': 21.03,
#   'Lng': 83.8,
#   'Max Temp': 73.26,
#   'Humidity': 68,
#   'Cloudiness': 17,
#   'Wind Speed': 2.66,
#   'Current Weather': 'few clouds',
#   'Country': 'IN'},
#  {'City': 'Touho',
#   'Lat': -20.78,
#   'Lng': 165.23,
#   'Max Temp': 76.01,
#   'Humidity': 84,
#   'Cloudiness': 23,
#   'Wind Speed': 10.98,
#   'Current Weather': 'few clouds',
#   'Country': 'NC'},
#  {'City': 'Sa Kaeo',
#   'Lat': 13.75,
#   'Lng': 102.33,
#   'Max Temp': 71.19,
#   'Humidity': 83,
#   'Cloudiness': 85,
#   'Wind Speed': 4.79,
#   'Current Weather': 'overcast clouds',
#   'Country': 'TH'},
#  {'City': 'Santa Rita Do Passa Quatro',
#   'Lat': -21.71,
#   'Lng': -47.48,
#   'Max Temp': 85.8,
#   'Humidity': 47,
#   'Cloudiness': 39,
#   'Wind Speed': 6.85,
#   'Current Weather': 'light rain',
#   'Country': 'BR'},
#  {'City': 'Igrim',
#   'Lat': 63.19,
#   'Lng': 64.42,
#   'Max Temp': 14.79,
#   'Humidity': 89,
#   'Cloudiness': 95,
#   'Wind Speed': 6.29,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Chumikan',
#   'Lat': 54.72,
#   'Lng': 135.31,
#   'Max Temp': 12,
#   'Humidity': 92,
#   'Cloudiness': 28,
#   'Wind Speed': 15.66,
#   'Current Weather': 'scattered clouds',
#   'Country': 'RU'},
#  {'City': 'Opochka',
#   'Lat': 56.71,
#   'Lng': 28.66,
#   'Max Temp': 34.39,
#   'Humidity': 88,
#   'Cloudiness': 77,
#   'Wind Speed': 8.5,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Matveyevka',
#   'Lat': 52.15,
#   'Lng': 56.18,
#   'Max Temp': 8.6,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Yeppoon',
#   'Lat': -23.13,
#   'Lng': 150.73,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Current Weather': 'clear sky',
#   'Country': 'AU'},
#  {'City': 'Duluth',
#   'Lat': 46.78,
#   'Lng': -92.11,
#   'Max Temp': 33.8,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 28.86,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Casian',
#   'Lat': 11.04,
#   'Lng': 119.71,
#   'Max Temp': 83.12,
#   'Humidity': 81,
#   'Cloudiness': 56,
#   'Wind Speed': 21.54,
#   'Current Weather': 'broken clouds',
#   'Country': 'PH'},
#  {'City': 'Durazno',
#   'Lat': -33.41,
#   'Lng': -56.5,
#   'Max Temp': 78.8,
#   'Humidity': 47,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Weather': 'broken clouds',
#   'Country': 'UY'},
#  {'City': 'Les Cayes',
#   'Lat': 18.2,
#   'Lng': -73.75,
#   'Max Temp': 82.36,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 6.58,
#   'Current Weather': 'overcast clouds',
#   'Country': 'HT'},
#  {'City': 'Ketchikan',
#   'Lat': 55.34,
#   'Lng': -131.65,
#   'Max Temp': 39.2,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 17.22,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Jacareacanga',
#   'Lat': -6.22,
#   'Lng': -57.75,
#   'Max Temp': 98.78,
#   'Humidity': 35,
#   'Cloudiness': 40,
#   'Wind Speed': 4.18,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BR'},
#  {'City': 'Creel',
#   'Lat': 27.75,
#   'Lng': -107.63,
#   'Max Temp': 60.13,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 13.27,
#   'Current Weather': 'clear sky',
#   'Country': 'MX'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Isangel -19.55  169.27     74.52        82          14        9.48
# 1   Mitsamiouli -11.38   43.28     79.02        73           2        4.74
# 2    Lavrentiya  65.58 -171.00     19.72        88          40        7.94
# 3    Bredasdorp -34.53   20.04     62.60        59          48        6.93
# 4  Puerto Ayora  -0.74  -90.35     77.00        73          40        9.17
# 5        Albany  42.60  -73.97     46.00        59          83        3.00
# 6   New Norfolk -42.78  147.06     55.00        91          64        1.10
# 7        Hobart -42.88  147.33     55.40        93          90        8.05
# 8     Busselton -33.65  115.33     48.99        96          26        5.99
# 9        Hasaki  35.73  140.83     51.80        81          75        1.12
#
#     Current Weather Country
# 0        few clouds      VU
# 1         clear sky      KM
# 2  scattered clouds      RU
# 3  scattered clouds      ZA
# 4  scattered clouds      EC
# 5     broken clouds      US
# 6        light rain      AU
# 7     moderate rain      AU
# 8  scattered clouds      AU
# 9     broken clouds      JP

# %%
column_names = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Weather"]
city_data_df = city_data_df.reindex(columns=column_names)

# %%
city_data_df
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Isangel      VU -19.55  169.27     74.52        82          14
# 1     Mitsamiouli      KM -11.38   43.28     79.02        73           2
# 2      Lavrentiya      RU  65.58 -171.00     19.72        88          40
# 3      Bredasdorp      ZA -34.53   20.04     62.60        59          48
# 4    Puerto Ayora      EC  -0.74  -90.35     77.00        73          40
# ..            ...     ...    ...     ...       ...       ...         ...
# 672       Durazno      UY -33.41  -56.50     78.80        47          75
# 673     Les Cayes      HT  18.20  -73.75     82.36        71         100
# 674     Ketchikan      US  55.34 -131.65     39.20        69           1
# 675  Jacareacanga      BR  -6.22  -57.75     98.78        35          40
# 676         Creel      MX  27.75 -107.63     60.13        33           0
#
#      Wind Speed   Current Weather
# 0          9.48        few clouds
# 1          4.74         clear sky
# 2          7.94  scattered clouds
# 3          6.93  scattered clouds
# 4          9.17  scattered clouds
# ..          ...               ...
# 672       13.87     broken clouds
# 673        6.58   overcast clouds
# 674       17.22         clear sky
# 675        4.18  scattered clouds
# 676       13.27         clear sky
#
# [677 rows x 9 columns]

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
