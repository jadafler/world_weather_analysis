# %% [markdown]
# # Deliverable 1:
# Retrieve Weather Data

# %%
# Import the random module
import pandas as pd
import numpy as np
import requests
import gmaps

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 798

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6d755a1ede82d8c6d8fbbafc342987ae"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6d755a1ede82d8c6d8fbbafc342987ae

# %%
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        city_current_weather = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather": city_current_weather,
                          "Country": city_country,})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | frome
# Processing Record 3 of Set 1 | isla mujeres
# Processing Record 4 of Set 1 | lopatino
# Processing Record 5 of Set 1 | sisimiut
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | okhotsk
# Processing Record 9 of Set 1 | esperance
# Processing Record 10 of Set 1 | kade
# Processing Record 11 of Set 1 | roald
# Processing Record 12 of Set 1 | metro
# Processing Record 13 of Set 1 | ancud
# Processing Record 14 of Set 1 | conroe
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | northam
# Processing Record 17 of Set 1 | broome
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | goulburn
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | saint george
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | merauke
# Processing Record 26 of Set 1 | cabo san lucas
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | uthal
# Processing Record 29 of Set 1 | norman wells
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | calvinia
# Processing Record 32 of Set 1 | suntar
# Processing Record 33 of Set 1 | pisco
# Processing Record 34 of Set 1 | clyde river
# Processing Record 35 of Set 1 | huarmey
# Processing Record 36 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | belmonte
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | cherskiy
# Processing Record 41 of Set 1 | faanui
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 44 of Set 1 | noyabrsk
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | ferme-neuve
# Processing Record 48 of Set 1 | nusaybin
# Processing Record 49 of Set 1 | san quintin
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | vilhena
# Processing Record 2 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 2 | dongsheng
# Processing Record 4 of Set 2 | victoria
# Processing Record 5 of Set 2 | springbok
# Processing Record 6 of Set 2 | college
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 2 | babati
# Processing Record 10 of Set 2 | linxia
# Processing Record 11 of Set 2 | tessalit
# Processing Record 12 of Set 2 | acapulco
# Processing Record 13 of Set 2 | torbay
# Processing Record 14 of Set 2 | geraldton
# Processing Record 15 of Set 2 | santa isabel do rio negro
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 2 | grootfontein
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | pevek
# Processing Record 21 of Set 2 | wajir
# Processing Record 22 of Set 2 | rikitea
# Processing Record 23 of Set 2 | new norfolk
# Processing Record 24 of Set 2 | dawson creek
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | ucluelet
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | veraval
# Processing Record 29 of Set 2 | addi ugri
# City not found. Skipping...
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | soanierana ivongo
# Processing Record 32 of Set 2 | aktash
# Processing Record 33 of Set 2 | dingle
# Processing Record 34 of Set 2 | provideniya
# Processing Record 35 of Set 2 | iqaluit
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | solnechnyy
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | ginda
# Processing Record 41 of Set 2 | corinto
# Processing Record 42 of Set 2 | lingao
# Processing Record 43 of Set 2 | santiago
# Processing Record 44 of Set 2 | makrikhorion
# City not found. Skipping...
# Processing Record 45 of Set 2 | meulaboh
# Processing Record 46 of Set 2 | great yarmouth
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | khatanga
# Processing Record 49 of Set 2 | aklavik
# Processing Record 50 of Set 2 | bijie
# Processing Record 1 of Set 3 | batagay-alyta
# Processing Record 2 of Set 3 | olafsvik
# Processing Record 3 of Set 3 | sol-iletsk
# Processing Record 4 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 3 | kamaishi
# Processing Record 6 of Set 3 | albany
# Processing Record 7 of Set 3 | moron
# Processing Record 8 of Set 3 | upernavik
# Processing Record 9 of Set 3 | busselton
# Processing Record 10 of Set 3 | gloucester
# Processing Record 11 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | bodden town
# Processing Record 14 of Set 3 | thinadhoo
# Processing Record 15 of Set 3 | vanimo
# Processing Record 16 of Set 3 | mahebourg
# Processing Record 17 of Set 3 | rochefort
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | port moresby
# Processing Record 20 of Set 3 | nemuro
# Processing Record 21 of Set 3 | vardo
# Processing Record 22 of Set 3 | gillette
# Processing Record 23 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 3 | ahipara
# Processing Record 25 of Set 3 | lebu
# Processing Record 26 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 3 | sakakah
# Processing Record 28 of Set 3 | severo-kurilsk
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | cockburn town
# Processing Record 31 of Set 3 | yellowknife
# Processing Record 32 of Set 3 | mattru
# Processing Record 33 of Set 3 | coquimbo
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | rio grande
# Processing Record 37 of Set 3 | hobyo
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | marrakesh
# Processing Record 40 of Set 3 | santa rosa
# Processing Record 41 of Set 3 | seoul
# Processing Record 42 of Set 3 | isla vista
# Processing Record 43 of Set 3 | povenets
# Processing Record 44 of Set 3 | ayer itam
# City not found. Skipping...
# Processing Record 45 of Set 3 | malkangiri
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | kalmunai
# Processing Record 48 of Set 3 | chuy
# Processing Record 49 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 3 | atuona
# Processing Record 1 of Set 4 | jarjis
# City not found. Skipping...
# Processing Record 2 of Set 4 | quatre cocos
# Processing Record 3 of Set 4 | fairbanks
# Processing Record 4 of Set 4 | walvis bay
# Processing Record 5 of Set 4 | goundam
# Processing Record 6 of Set 4 | fallon
# Processing Record 7 of Set 4 | gornopravdinsk
# Processing Record 8 of Set 4 | bemidji
# Processing Record 9 of Set 4 | saint-pierre
# Processing Record 10 of Set 4 | rajgarh
# Processing Record 11 of Set 4 | paraiso
# Processing Record 12 of Set 4 | prainha
# Processing Record 13 of Set 4 | morgan city
# Processing Record 14 of Set 4 | nuuk
# Processing Record 15 of Set 4 | ulaanbaatar
# Processing Record 16 of Set 4 | sao filipe
# Processing Record 17 of Set 4 | skibbereen
# Processing Record 18 of Set 4 | karpogory
# Processing Record 19 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 4 | ust-kalmanka
# Processing Record 21 of Set 4 | kalevala
# Processing Record 22 of Set 4 | fort nelson
# Processing Record 23 of Set 4 | le port
# Processing Record 24 of Set 4 | salalah
# Processing Record 25 of Set 4 | anderson
# Processing Record 26 of Set 4 | mezen
# Processing Record 27 of Set 4 | imeni zhelyabova
# Processing Record 28 of Set 4 | barra do garcas
# Processing Record 29 of Set 4 | ca mau
# Processing Record 30 of Set 4 | port-cartier
# Processing Record 31 of Set 4 | saint-georges
# Processing Record 32 of Set 4 | bengkulu
# Processing Record 33 of Set 4 | lavrentiya
# Processing Record 34 of Set 4 | yulara
# Processing Record 35 of Set 4 | dengzhou
# Processing Record 36 of Set 4 | carora
# Processing Record 37 of Set 4 | petropavlovka
# Processing Record 38 of Set 4 | jujuy
# City not found. Skipping...
# Processing Record 39 of Set 4 | vaini
# Processing Record 40 of Set 4 | ejby
# Processing Record 41 of Set 4 | beian
# Processing Record 42 of Set 4 | baykit
# Processing Record 43 of Set 4 | boyabat
# Processing Record 44 of Set 4 | nanortalik
# Processing Record 45 of Set 4 | bathsheba
# Processing Record 46 of Set 4 | shingu
# Processing Record 47 of Set 4 | evensk
# Processing Record 48 of Set 4 | sherbakul
# Processing Record 49 of Set 4 | puerto del rosario
# Processing Record 50 of Set 4 | hirara
# Processing Record 1 of Set 5 | danjiangkou
# Processing Record 2 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 5 | ixtapa
# Processing Record 4 of Set 5 | port blair
# Processing Record 5 of Set 5 | la tuque
# Processing Record 6 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 5 | ambilobe
# Processing Record 8 of Set 5 | thurso
# Processing Record 9 of Set 5 | natchitoches
# Processing Record 10 of Set 5 | port hardy
# Processing Record 11 of Set 5 | hilo
# Processing Record 12 of Set 5 | grants
# Processing Record 13 of Set 5 | gijon
# Processing Record 14 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 5 | la uribe
# City not found. Skipping...
# Processing Record 16 of Set 5 | castro
# Processing Record 17 of Set 5 | bintulu
# Processing Record 18 of Set 5 | ahuimanu
# Processing Record 19 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 5 | miranda
# Processing Record 21 of Set 5 | chitungwiza
# Processing Record 22 of Set 5 | praia da vitoria
# Processing Record 23 of Set 5 | bethel
# Processing Record 24 of Set 5 | abu samrah
# Processing Record 25 of Set 5 | samarai
# Processing Record 26 of Set 5 | vestmannaeyjar
# Processing Record 27 of Set 5 | fortuna
# Processing Record 28 of Set 5 | qasigiannguit
# Processing Record 29 of Set 5 | talnakh
# Processing Record 30 of Set 5 | caravelas
# Processing Record 31 of Set 5 | sabzevar
# Processing Record 32 of Set 5 | banda aceh
# Processing Record 33 of Set 5 | oranjestad
# Processing Record 34 of Set 5 | kutum
# Processing Record 35 of Set 5 | tasiilaq
# Processing Record 36 of Set 5 | zemio
# Processing Record 37 of Set 5 | teguldet
# Processing Record 38 of Set 5 | charters towers
# Processing Record 39 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 5 | lompoc
# Processing Record 42 of Set 5 | kahramanmaras
# Processing Record 43 of Set 5 | chapais
# Processing Record 44 of Set 5 | necochea
# Processing Record 45 of Set 5 | poum
# Processing Record 46 of Set 5 | san patricio
# Processing Record 47 of Set 5 | varadero
# Processing Record 48 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 49 of Set 5 | kavaratti
# Processing Record 50 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 6 | makakilo city
# Processing Record 2 of Set 6 | vorukh
# Processing Record 3 of Set 6 | kangalassy
# Processing Record 4 of Set 6 | puerto palomas
# Processing Record 5 of Set 6 | darby
# Processing Record 6 of Set 6 | ostrovnoy
# Processing Record 7 of Set 6 | asau
# Processing Record 8 of Set 6 | san joaquin
# Processing Record 9 of Set 6 | meadow lake
# Processing Record 10 of Set 6 | rovaniemi
# Processing Record 11 of Set 6 | longyearbyen
# Processing Record 12 of Set 6 | saldanha
# Processing Record 13 of Set 6 | tuatapere
# Processing Record 14 of Set 6 | meiganga
# Processing Record 15 of Set 6 | banga
# Processing Record 16 of Set 6 | kununurra
# Processing Record 17 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 6 | burnie
# Processing Record 19 of Set 6 | thongwa
# Processing Record 20 of Set 6 | majene
# Processing Record 21 of Set 6 | husavik
# Processing Record 22 of Set 6 | son la
# Processing Record 23 of Set 6 | kaitangata
# Processing Record 24 of Set 6 | grindavik
# Processing Record 25 of Set 6 | biak
# Processing Record 26 of Set 6 | gorontalo
# Processing Record 27 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 6 | ulladulla
# Processing Record 29 of Set 6 | sao mateus
# Processing Record 30 of Set 6 | aberystwyth
# Processing Record 31 of Set 6 | leh
# Processing Record 32 of Set 6 | sapa
# Processing Record 33 of Set 6 | urupes
# Processing Record 34 of Set 6 | osoyoos
# Processing Record 35 of Set 6 | whithorn
# Processing Record 36 of Set 6 | souillac
# Processing Record 37 of Set 6 | lasa
# Processing Record 38 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 39 of Set 6 | naze
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | chazuta
# Processing Record 42 of Set 6 | marovoay
# Processing Record 43 of Set 6 | bundaberg
# Processing Record 44 of Set 6 | port elizabeth
# Processing Record 45 of Set 6 | mogadishu
# Processing Record 46 of Set 6 | amalapuram
# Processing Record 47 of Set 6 | lorengau
# Processing Record 48 of Set 6 | ilulissat
# Processing Record 49 of Set 6 | goleniow
# Processing Record 50 of Set 6 | mitu
# Processing Record 1 of Set 7 | san cristobal
# Processing Record 2 of Set 7 | xai-xai
# Processing Record 3 of Set 7 | boende
# Processing Record 4 of Set 7 | tezu
# Processing Record 5 of Set 7 | kerema
# Processing Record 6 of Set 7 | sinegorye
# Processing Record 7 of Set 7 | sao joao da barra
# Processing Record 8 of Set 7 | yar-sale
# Processing Record 9 of Set 7 | beloha
# Processing Record 10 of Set 7 | turbat
# Processing Record 11 of Set 7 | konstantinovka
# Processing Record 12 of Set 7 | longhua
# Processing Record 13 of Set 7 | pinega
# Processing Record 14 of Set 7 | lata
# Processing Record 15 of Set 7 | iracoubo
# Processing Record 16 of Set 7 | nelson bay
# Processing Record 17 of Set 7 | vila velha
# Processing Record 18 of Set 7 | tabarqah
# City not found. Skipping...
# Processing Record 19 of Set 7 | xichang
# Processing Record 20 of Set 7 | kitui
# Processing Record 21 of Set 7 | steamboat springs
# Processing Record 22 of Set 7 | kahului
# Processing Record 23 of Set 7 | pudozh
# Processing Record 24 of Set 7 | sabang
# Processing Record 25 of Set 7 | kyabe
# Processing Record 26 of Set 7 | yuci
# Processing Record 27 of Set 7 | marolambo
# Processing Record 28 of Set 7 | bandarbeyla
# Processing Record 29 of Set 7 | pangnirtung
# Processing Record 30 of Set 7 | la crosse
# Processing Record 31 of Set 7 | komsomolskiy
# Processing Record 32 of Set 7 | jacqueville
# Processing Record 33 of Set 7 | airai
# Processing Record 34 of Set 7 | queenstown
# Processing Record 35 of Set 7 | saskylakh
# Processing Record 36 of Set 7 | palayan
# Processing Record 37 of Set 7 | coihaique
# Processing Record 38 of Set 7 | aragarcas
# Processing Record 39 of Set 7 | fukue
# Processing Record 40 of Set 7 | kloulklubed
# Processing Record 41 of Set 7 | ouro preto do oeste
# Processing Record 42 of Set 7 | ramhormoz
# Processing Record 43 of Set 7 | sofiysk
# City not found. Skipping...
# Processing Record 44 of Set 7 | manzhouli
# Processing Record 45 of Set 7 | faya
# Processing Record 46 of Set 7 | ballina
# Processing Record 47 of Set 7 | sunrise manor
# Processing Record 48 of Set 7 | sitka
# Processing Record 49 of Set 7 | tetelzingo
# Processing Record 50 of Set 7 | borger
# Processing Record 1 of Set 8 | woodward
# Processing Record 2 of Set 8 | afsin
# Processing Record 3 of Set 8 | itarema
# Processing Record 4 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 8 | kathu
# Processing Record 6 of Set 8 | harper
# Processing Record 7 of Set 8 | sobolevo
# Processing Record 8 of Set 8 | rawson
# Processing Record 9 of Set 8 | santa ana
# Processing Record 10 of Set 8 | ketchenery
# City not found. Skipping...
# Processing Record 11 of Set 8 | mar del plata
# Processing Record 12 of Set 8 | aleksandrov gay
# Processing Record 13 of Set 8 | tura
# Processing Record 14 of Set 8 | acarau
# Processing Record 15 of Set 8 | port-gentil
# Processing Record 16 of Set 8 | alofi
# Processing Record 17 of Set 8 | pyshchug
# Processing Record 18 of Set 8 | izhma
# Processing Record 19 of Set 8 | tallahassee
# Processing Record 20 of Set 8 | corning
# Processing Record 21 of Set 8 | el terrero
# Processing Record 22 of Set 8 | stryn
# Processing Record 23 of Set 8 | jasper
# Processing Record 24 of Set 8 | mehamn
# Processing Record 25 of Set 8 | adrar
# Processing Record 26 of Set 8 | mugumu
# Processing Record 27 of Set 8 | san isidro
# Processing Record 28 of Set 8 | morant bay
# Processing Record 29 of Set 8 | norsup
# Processing Record 30 of Set 8 | champerico
# Processing Record 31 of Set 8 | kastamonu
# Processing Record 32 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 8 | laureles
# Processing Record 34 of Set 8 | kaeo
# Processing Record 35 of Set 8 | ardahan
# Processing Record 36 of Set 8 | atar
# Processing Record 37 of Set 8 | kodiak
# Processing Record 38 of Set 8 | qaqortoq
# Processing Record 39 of Set 8 | lovozero
# Processing Record 40 of Set 8 | shestakovo
# Processing Record 41 of Set 8 | fougamou
# Processing Record 42 of Set 8 | luena
# Processing Record 43 of Set 8 | djibo
# Processing Record 44 of Set 8 | halifax
# Processing Record 45 of Set 8 | masingbi
# Processing Record 46 of Set 8 | hamilton
# Processing Record 47 of Set 8 | dalaba
# Processing Record 48 of Set 8 | egvekinot
# Processing Record 49 of Set 8 | pafos
# Processing Record 50 of Set 8 | nabire
# Processing Record 1 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 2 of Set 9 | podosinovets
# Processing Record 3 of Set 9 | guanica
# Processing Record 4 of Set 9 | isangel
# Processing Record 5 of Set 9 | chokurdakh
# Processing Record 6 of Set 9 | klaksvik
# Processing Record 7 of Set 9 | namibe
# Processing Record 8 of Set 9 | labuan
# Processing Record 9 of Set 9 | portland
# Processing Record 10 of Set 9 | tabuk
# Processing Record 11 of Set 9 | bakhmach
# Processing Record 12 of Set 9 | alexandria
# Processing Record 13 of Set 9 | jakar
# Processing Record 14 of Set 9 | paamiut
# Processing Record 15 of Set 9 | tiksi
# Processing Record 16 of Set 9 | jacareacanga
# Processing Record 17 of Set 9 | haines junction
# Processing Record 18 of Set 9 | jalu
# Processing Record 19 of Set 9 | dawei
# Processing Record 20 of Set 9 | yichun
# Processing Record 21 of Set 9 | dukat
# Processing Record 22 of Set 9 | akyab
# Processing Record 23 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 24 of Set 9 | piranhas
# Processing Record 25 of Set 9 | gushi
# Processing Record 26 of Set 9 | takoradi
# Processing Record 27 of Set 9 | broken hill
# Processing Record 28 of Set 9 | suyapa de lean
# City not found. Skipping...
# Processing Record 29 of Set 9 | winnemucca
# Processing Record 30 of Set 9 | kalengwa
# Processing Record 31 of Set 9 | mantua
# Processing Record 32 of Set 9 | salinopolis
# Processing Record 33 of Set 9 | kruisfontein
# Processing Record 34 of Set 9 | negara
# Processing Record 35 of Set 9 | hay river
# Processing Record 36 of Set 9 | aviles
# Processing Record 37 of Set 9 | keti bandar
# Processing Record 38 of Set 9 | finschhafen
# Processing Record 39 of Set 9 | bandundu
# Processing Record 40 of Set 9 | hachinohe
# Processing Record 41 of Set 9 | namatanai
# Processing Record 42 of Set 9 | atlantic city
# Processing Record 43 of Set 9 | sibu
# Processing Record 44 of Set 9 | sao joao batista
# Processing Record 45 of Set 9 | manhattan
# Processing Record 46 of Set 9 | vilyuysk
# Processing Record 47 of Set 9 | manicore
# Processing Record 48 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 9 | kidal
# Processing Record 50 of Set 9 | nouadhibou
# Processing Record 1 of Set 10 | san vicente
# Processing Record 2 of Set 10 | manyana
# Processing Record 3 of Set 10 | tsentralnyy
# City not found. Skipping...
# Processing Record 4 of Set 10 | puerto suarez
# Processing Record 5 of Set 10 | mayumba
# Processing Record 6 of Set 10 | bakchar
# Processing Record 7 of Set 10 | sabha
# Processing Record 8 of Set 10 | ust-koksa
# Processing Record 9 of Set 10 | karratha
# Processing Record 10 of Set 10 | alangudi
# Processing Record 11 of Set 10 | tekari
# Processing Record 12 of Set 10 | markova
# Processing Record 13 of Set 10 | srivardhan
# Processing Record 14 of Set 10 | panalingaan
# Processing Record 15 of Set 10 | tignere
# Processing Record 16 of Set 10 | axim
# Processing Record 17 of Set 10 | tuy hoa
# Processing Record 18 of Set 10 | constitucion
# Processing Record 19 of Set 10 | nong khai
# Processing Record 20 of Set 10 | marigot
# Processing Record 21 of Set 10 | draguignan
# Processing Record 22 of Set 10 | puerto escondido
# Processing Record 23 of Set 10 | acari
# Processing Record 24 of Set 10 | banganapalle
# Processing Record 25 of Set 10 | svetlogorsk
# Processing Record 26 of Set 10 | cap malheureux
# Processing Record 27 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 29 of Set 10 | ribeira brava
# Processing Record 30 of Set 10 | turukhansk
# Processing Record 31 of Set 10 | san policarpo
# Processing Record 32 of Set 10 | guaira
# Processing Record 33 of Set 10 | veseloyarsk
# Processing Record 34 of Set 10 | wattegama
# Processing Record 35 of Set 10 | abu dhabi
# Processing Record 36 of Set 10 | birobidzhan
# Processing Record 37 of Set 10 | ekhabi
# Processing Record 38 of Set 10 | aldan
# Processing Record 39 of Set 10 | qiryat gat
# Processing Record 40 of Set 10 | bagdarin
# Processing Record 41 of Set 10 | kavieng
# Processing Record 42 of Set 10 | sao geraldo do araguaia
# Processing Record 43 of Set 10 | yangliuqing
# Processing Record 44 of Set 10 | mindyak
# Processing Record 45 of Set 10 | saint-denis
# Processing Record 46 of Set 10 | trelew
# Processing Record 47 of Set 10 | te anau
# Processing Record 48 of Set 10 | caramay
# Processing Record 49 of Set 10 | ipixuna
# Processing Record 50 of Set 10 | shaowu
# Processing Record 1 of Set 11 | zhanakorgan
# Processing Record 2 of Set 11 | hambantota
# Processing Record 3 of Set 11 | kamenka
# Processing Record 4 of Set 11 | vredendal
# Processing Record 5 of Set 11 | leshan
# Processing Record 6 of Set 11 | kudahuvadhoo
# Processing Record 7 of Set 11 | bulawayo
# Processing Record 8 of Set 11 | taree
# Processing Record 9 of Set 11 | bonavista
# Processing Record 10 of Set 11 | mount gambier
# Processing Record 11 of Set 11 | tadine
# Processing Record 12 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 14 of Set 11 | fort-shevchenko
# Processing Record 15 of Set 11 | kifri
# Processing Record 16 of Set 11 | dikson
# Processing Record 17 of Set 11 | namuac
# Processing Record 18 of Set 11 | eldorado
# Processing Record 19 of Set 11 | jieshi
# Processing Record 20 of Set 11 | tilichiki
# Processing Record 21 of Set 11 | bubaque
# Processing Record 22 of Set 11 | hayden
# Processing Record 23 of Set 11 | bilma
# Processing Record 24 of Set 11 | voyvozh
# Processing Record 25 of Set 11 | kundgol
# Processing Record 26 of Set 11 | kodinsk
# Processing Record 27 of Set 11 | det udom
# Processing Record 28 of Set 11 | jauja
# Processing Record 29 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 30 of Set 11 | chingirlau
# Processing Record 31 of Set 11 | zhireken
# Processing Record 32 of Set 11 | dakar
# Processing Record 33 of Set 11 | rypefjord
# Processing Record 34 of Set 11 | abashiri
# Processing Record 35 of Set 11 | maamba
# Processing Record 36 of Set 11 | saint-joseph
# Processing Record 37 of Set 11 | autun
# Processing Record 38 of Set 11 | west odessa
# Processing Record 39 of Set 11 | machali
# Processing Record 40 of Set 11 | yairipok
# Processing Record 41 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 42 of Set 11 | bardiyah
# Processing Record 43 of Set 11 | suwannaphum
# Processing Record 44 of Set 11 | lukulu
# Processing Record 45 of Set 11 | bowen
# Processing Record 46 of Set 11 | pahrump
# Processing Record 47 of Set 11 | rosetta
# Processing Record 48 of Set 11 | la baule-escoublac
# Processing Record 49 of Set 11 | teya
# Processing Record 50 of Set 11 | magdalena
# Processing Record 1 of Set 12 | calabozo
# Processing Record 2 of Set 12 | vestmanna
# Processing Record 3 of Set 12 | shahr-e babak
# Processing Record 4 of Set 12 | inhambane
# Processing Record 5 of Set 12 | orange cove
# Processing Record 6 of Set 12 | san luis
# Processing Record 7 of Set 12 | sal rei
# Processing Record 8 of Set 12 | kielce
# Processing Record 9 of Set 12 | tsagan aman
# Processing Record 10 of Set 12 | vytegra
# Processing Record 11 of Set 12 | saint anthony
# Processing Record 12 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 12 | nola
# Processing Record 14 of Set 12 | yoichi
# Processing Record 15 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 12 | leeton
# Processing Record 17 of Set 12 | havre-saint-pierre
# Processing Record 18 of Set 12 | tatarka
# Processing Record 19 of Set 12 | fortuna foothills
# Processing Record 20 of Set 12 | pizarro
# Processing Record 21 of Set 12 | kapuskasing
# Processing Record 22 of Set 12 | corner brook
# Processing Record 23 of Set 12 | narsaq
# Processing Record 24 of Set 12 | apac
# Processing Record 25 of Set 12 | igarape-acu
# City not found. Skipping...
# Processing Record 26 of Set 12 | warwick
# Processing Record 27 of Set 12 | yei
# Processing Record 28 of Set 12 | kenai
# Processing Record 29 of Set 12 | kamarion
# Processing Record 30 of Set 12 | zwedru
# Processing Record 31 of Set 12 | aswan
# Processing Record 32 of Set 12 | newberry
# Processing Record 33 of Set 12 | mangan
# Processing Record 34 of Set 12 | pemba
# Processing Record 35 of Set 12 | eyrarbakki
# Processing Record 36 of Set 12 | wilmington
# Processing Record 37 of Set 12 | midland
# Processing Record 38 of Set 12 | cayenne
# Processing Record 39 of Set 12 | dubbo
# Processing Record 40 of Set 12 | arrecife
# Processing Record 41 of Set 12 | binga
# Processing Record 42 of Set 12 | sukhumi
# Processing Record 43 of Set 12 | bulgan
# Processing Record 44 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 12 | shelburne
# Processing Record 46 of Set 12 | vallenar
# Processing Record 47 of Set 12 | inongo
# Processing Record 48 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 12 | kushima
# Processing Record 50 of Set 12 | alyangula
# Processing Record 1 of Set 13 | muros
# Processing Record 2 of Set 13 | mezhdurechensk
# Processing Record 3 of Set 13 | kaele
# Processing Record 4 of Set 13 | guadalupe y calvo
# Processing Record 5 of Set 13 | mandera
# Processing Record 6 of Set 13 | tursunzoda
# Processing Record 7 of Set 13 | los llanos de aridane
# Processing Record 8 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 9 of Set 13 | bad salzuflen
# Processing Record 10 of Set 13 | cervo
# Processing Record 11 of Set 13 | mayor pablo lagerenza
# Processing Record 12 of Set 13 | san jeronimo
# Processing Record 13 of Set 13 | ust-kut
# Processing Record 14 of Set 13 | mahanoro
# Processing Record 15 of Set 13 | hofn
# Processing Record 16 of Set 13 | luohe
# Processing Record 17 of Set 13 | leningradskiy
# Processing Record 18 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 19 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 13 | golyshmanovo
# Processing Record 21 of Set 13 | pochutla
# Processing Record 22 of Set 13 | leticia
# Processing Record 23 of Set 13 | caceres
# Processing Record 24 of Set 13 | dunyapur
# Processing Record 25 of Set 13 | mao
# Processing Record 26 of Set 13 | houma
# Processing Record 27 of Set 13 | castanos
# Processing Record 28 of Set 13 | kupang
# Processing Record 29 of Set 13 | seymchan
# Processing Record 30 of Set 13 | abdanan
# Processing Record 31 of Set 13 | bull savanna
# Processing Record 32 of Set 13 | sioux lookout
# Processing Record 33 of Set 13 | iranshahr
# Processing Record 34 of Set 13 | henties bay
# Processing Record 35 of Set 13 | bulqize
# Processing Record 36 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 37 of Set 13 | hammerfest
# Processing Record 38 of Set 13 | liwale
# Processing Record 39 of Set 13 | sidi ali
# Processing Record 40 of Set 13 | beringovskiy
# Processing Record 41 of Set 13 | limay
# Processing Record 42 of Set 13 | porto novo
# Processing Record 43 of Set 13 | bonthe
# Processing Record 44 of Set 13 | port macquarie
# Processing Record 45 of Set 13 | achi
# Processing Record 46 of Set 13 | rivadavia
# Processing Record 47 of Set 13 | hami
# Processing Record 48 of Set 13 | varkaus
# Processing Record 49 of Set 13 | kargil
# Processing Record 50 of Set 13 | lazi
# Processing Record 1 of Set 14 | derzhavinsk
# Processing Record 2 of Set 14 | celestun
# Processing Record 3 of Set 14 | mackenzie
# Processing Record 4 of Set 14 | alice springs
# Processing Record 5 of Set 14 | raudeberg
# Processing Record 6 of Set 14 | usak
# Processing Record 7 of Set 14 | outlook
# Processing Record 8 of Set 14 | wanning
# Processing Record 9 of Set 14 | ulaangom
# Processing Record 10 of Set 14 | lagoa
# Processing Record 11 of Set 14 | margate
# Processing Record 12 of Set 14 | quelimane
# Processing Record 13 of Set 14 | trinidad
# Processing Record 14 of Set 14 | fowa
# Processing Record 15 of Set 14 | ambovombe
# Processing Record 16 of Set 14 | anadyr
# Processing Record 17 of Set 14 | treinta y tres
# Processing Record 18 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 14 | saurimo
# Processing Record 20 of Set 14 | ojinaga
# Processing Record 21 of Set 14 | road town
# Processing Record 22 of Set 14 | abu kamal
# Processing Record 23 of Set 14 | sampit
# Processing Record 24 of Set 14 | nicoya
# Processing Record 25 of Set 14 | ikalamavony
# Processing Record 26 of Set 14 | san carlos de bariloche
# Processing Record 27 of Set 14 | palmer
# Processing Record 28 of Set 14 | saint-pacome
# City not found. Skipping...
# Processing Record 29 of Set 14 | olga
# Processing Record 30 of Set 14 | ouegoa
# Processing Record 31 of Set 14 | nyurba
# Processing Record 32 of Set 14 | high level
# Processing Record 33 of Set 14 | chaozhou
# Processing Record 34 of Set 14 | kichera
# Processing Record 35 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 14 | tonj
# Processing Record 37 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 14 | ambanja
# Processing Record 39 of Set 14 | sola
# Processing Record 40 of Set 14 | terre haute
# Processing Record 41 of Set 14 | peniche
# Processing Record 42 of Set 14 | kadoma
# Processing Record 43 of Set 14 | grand gaube
# Processing Record 44 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 14 | belozerskoye
# Processing Record 46 of Set 14 | novaya igirma
# Processing Record 47 of Set 14 | tornio
# Processing Record 48 of Set 14 | mudyuga
# City not found. Skipping...
# Processing Record 49 of Set 14 | nenjiang
# Processing Record 50 of Set 14 | kushiro
# Processing Record 1 of Set 15 | san diego
# Processing Record 2 of Set 15 | malakal
# Processing Record 3 of Set 15 | lacey
# Processing Record 4 of Set 15 | marysville
# Processing Record 5 of Set 15 | erenhot
# Processing Record 6 of Set 15 | syedove
# Processing Record 7 of Set 15 | le tampon
# Processing Record 8 of Set 15 | sokolo
# Processing Record 9 of Set 15 | san pedro del parana
# Processing Record 10 of Set 15 | xining
# Processing Record 11 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 15 | male
# Processing Record 13 of Set 15 | sharjah
# Processing Record 14 of Set 15 | dunmore town
# Processing Record 15 of Set 15 | black river
# Processing Record 16 of Set 15 | altamira
# Processing Record 17 of Set 15 | ruza
# Processing Record 18 of Set 15 | ketchikan
# Processing Record 19 of Set 15 | dudinka
# Processing Record 20 of Set 15 | george
# Processing Record 21 of Set 15 | buraydah
# Processing Record 22 of Set 15 | burica
# City not found. Skipping...
# Processing Record 23 of Set 15 | dolinsk
# Processing Record 24 of Set 15 | saint-francois
# Processing Record 25 of Set 15 | camana
# Processing Record 26 of Set 15 | andenes
# Processing Record 27 of Set 15 | kerrville
# Processing Record 28 of Set 15 | kasempa
# Processing Record 29 of Set 15 | cururupu
# Processing Record 30 of Set 15 | mari
# Processing Record 31 of Set 15 | lima
# Processing Record 32 of Set 15 | lazaro cardenas
# Processing Record 33 of Set 15 | tabou
# Processing Record 34 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 15 | avera
# Processing Record 36 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 15 | redmond
# Processing Record 38 of Set 15 | innisfail
# Processing Record 39 of Set 15 | talas
# Processing Record 40 of Set 15 | thomaston
# Processing Record 41 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 42 of Set 15 | talcahuano
# Processing Record 43 of Set 15 | kirovsk
# Processing Record 44 of Set 15 | tahe
# Processing Record 45 of Set 15 | mandalgovi
# Processing Record 46 of Set 15 | slonim
# Processing Record 47 of Set 15 | durango
# Processing Record 48 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 49 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 15 | kempsey
# Processing Record 1 of Set 16 | nanchong
# Processing Record 2 of Set 16 | buala
# Processing Record 3 of Set 16 | bam
# Processing Record 4 of Set 16 | nadym
# Processing Record 5 of Set 16 | la ronge
# Processing Record 6 of Set 16 | shimoda
# Processing Record 7 of Set 16 | miandrivazo
# Processing Record 8 of Set 16 | petresti
# Processing Record 9 of Set 16 | san juan
# Processing Record 10 of Set 16 | elhovo
# Processing Record 11 of Set 16 | mentok
# City not found. Skipping...
# Processing Record 12 of Set 16 | lixourion
# Processing Record 13 of Set 16 | troitsko-pechorsk
# Processing Record 14 of Set 16 | mastic beach
# Processing Record 15 of Set 16 | omboue
# Processing Record 16 of Set 16 | nador
# Processing Record 17 of Set 16 | mecca
# Processing Record 18 of Set 16 | mtsensk
# Processing Record 19 of Set 16 | kangaba
# Processing Record 20 of Set 16 | mad
# Processing Record 21 of Set 16 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 16 | baiyin
# Processing Record 24 of Set 16 | katsuura
# Processing Record 25 of Set 16 | entre rios
# Processing Record 26 of Set 16 | payo
# Processing Record 27 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 16 | waipawa
# Processing Record 29 of Set 16 | ordynskoye
# Processing Record 30 of Set 16 | touros
# Processing Record 31 of Set 16 | mutoko
# Processing Record 32 of Set 16 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 16 | kouroussa
# Processing Record 34 of Set 16 | popondetta
# Processing Record 35 of Set 16 | yumen
# Processing Record 36 of Set 16 | phek
# Processing Record 37 of Set 16 | itoman
# Processing Record 38 of Set 16 | ossora
# Processing Record 39 of Set 16 | doka
# Processing Record 40 of Set 16 | verkhoyansk
# Processing Record 41 of Set 16 | fuerte olimpo
# Processing Record 42 of Set 16 | plouzane
# Processing Record 43 of Set 16 | abapo
# Processing Record 44 of Set 16 | puerto leguizamo
# Processing Record 45 of Set 16 | gambo
# Processing Record 46 of Set 16 | sao felix do xingu
# Processing Record 47 of Set 16 | conceicao do araguaia
# Processing Record 48 of Set 16 | kargasok
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 798

# %%
city_data
# Out:
# [{'City': 'Georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 84.2,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Weather': 'few clouds',
#   'Country': 'MY'},
#  {'City': 'Frome',
#   'Lat': 51.23,
#   'Lng': -2.32,
#   'Max Temp': 51.01,
#   'Humidity': 91,
#   'Cloudiness': 25,
#   'Wind Speed': 3,
#   'Current Weather': 'scattered clouds',
#   'Country': 'GB'},
#  {'City': 'Isla Mujeres',
#   'Lat': 21.23,
#   'Lng': -86.73,
#   'Max Temp': 81,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Weather': 'light rain',
#   'Country': 'MX'},
#  {'City': 'Lopatino',
#   'Lat': 52.62,
#   'Lng': 45.81,
#   'Max Temp': 30.45,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 10.16,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Sisimiut',
#   'Lat': 66.94,
#   'Lng': -53.67,
#   'Max Temp': 18.63,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 21.61,
#   'Current Weather': 'overcast clouds',
#   'Country': 'GL'},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 63,
#   'Humidity': 59,
#   'Cloudiness': 85,
#   'Wind Speed': 7,
#   'Current Weather': 'overcast clouds',
#   'Country': 'NZ'},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 36,
#   'Humidity': 64,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Okhotsk',
#   'Lat': 59.38,
#   'Lng': 143.3,
#   'Max Temp': 0.72,
#   'Humidity': 85,
#   'Cloudiness': 23,
#   'Wind Speed': 18.34,
#   'Current Weather': 'few clouds',
#   'Country': 'RU'},
#  {'City': 'Esperance',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 96.8,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 18.34,
#   'Current Weather': 'clear sky',
#   'Country': 'AU'},
#  {'City': 'Kade',
#   'Lat': 52.38,
#   'Lng': 12.27,
#   'Max Temp': 37,
#   'Humidity': 83,
#   'Cloudiness': 69,
#   'Wind Speed': 1.01,
#   'Current Weather': 'broken clouds',
#   'Country': 'DE'},
#  {'City': 'Roald',
#   'Lat': 62.58,
#   'Lng': 6.13,
#   'Max Temp': 46.4,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Weather': 'broken clouds',
#   'Country': 'NO'},
#  {'City': 'Metro',
#   'Lat': -5.11,
#   'Lng': 105.31,
#   'Max Temp': 89.42,
#   'Humidity': 56,
#   'Cloudiness': 49,
#   'Wind Speed': 6.22,
#   'Current Weather': 'scattered clouds',
#   'Country': 'ID'},
#  {'City': 'Ancud',
#   'Lat': -41.87,
#   'Lng': -73.82,
#   'Max Temp': 46.99,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 1.12,
#   'Current Weather': 'few clouds',
#   'Country': 'CL'},
#  {'City': 'Conroe',
#   'Lat': 30.31,
#   'Lng': -95.46,
#   'Max Temp': 57.99,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 7.02,
#   'Current Weather': 'mist',
#   'Country': 'US'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 8.08,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.91,
#   'Current Weather': 'light snow',
#   'Country': 'GL'},
#  {'City': 'Northam',
#   'Lat': 51.03,
#   'Lng': -4.22,
#   'Max Temp': 52,
#   'Humidity': 93,
#   'Cloudiness': 68,
#   'Wind Speed': 7,
#   'Current Weather': 'broken clouds',
#   'Country': 'GB'},
#  {'City': 'Broome',
#   'Lat': 42.25,
#   'Lng': -75.83,
#   'Max Temp': 39,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 41,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Weather': 'few clouds',
#   'Country': 'AR'},
#  {'City': 'Hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 73,
#   'Humidity': 40,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Weather': 'broken clouds',
#   'Country': 'AU'},
#  {'City': 'Goulburn',
#   'Lat': -34.75,
#   'Lng': 149.72,
#   'Max Temp': 73.99,
#   'Humidity': 67,
#   'Cloudiness': 67,
#   'Wind Speed': 5.01,
#   'Current Weather': 'broken clouds',
#   'Country': 'AU'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 59,
#   'Humidity': 67,
#   'Cloudiness': 8,
#   'Wind Speed': 10.29,
#   'Current Weather': 'clear sky',
#   'Country': 'ZA'},
#  {'City': 'Saint George',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 51.8,
#   'Humidity': 37,
#   'Cloudiness': 20,
#   'Wind Speed': 4.41,
#   'Current Weather': 'few clouds',
#   'Country': 'US'},
#  {'City': 'Merauke',
#   'Lat': -8.47,
#   'Lng': 140.33,
#   'Max Temp': 84.97,
#   'Humidity': 76,
#   'Cloudiness': 89,
#   'Wind Speed': 12.75,
#   'Current Weather': 'moderate rain',
#   'Country': 'ID'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 73.99,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Weather': 'scattered clouds',
#   'Country': 'MX'},
#  {'City': 'Avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 89,
#   'Wind Speed': 2.24,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CK'},
#  {'City': 'Uthal',
#   'Lat': 25.81,
#   'Lng': 66.62,
#   'Max Temp': 75.79,
#   'Humidity': 25,
#   'Cloudiness': 100,
#   'Wind Speed': 4.81,
#   'Current Weather': 'overcast clouds',
#   'Country': 'PK'},
#  {'City': 'Norman Wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 3.2,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Weather': 'few clouds',
#   'Country': 'CA'},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Current Weather': 'broken clouds',
#   'Country': 'US'},
#  {'City': 'Calvinia',
#   'Lat': -31.47,
#   'Lng': 19.78,
#   'Max Temp': 48.2,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ZA'},
#  {'City': 'Suntar',
#   'Lat': 62.14,
#   'Lng': 117.63,
#   'Max Temp': 3.13,
#   'Humidity': 92,
#   'Cloudiness': 10,
#   'Wind Speed': 6.89,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 63,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Weather': 'clear sky',
#   'Country': 'PE'},
#  {'City': 'Clyde River',
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Max Temp': 6.8,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 21.92,
#   'Current Weather': 'light snow',
#   'Country': 'CA'},
#  {'City': 'Huarmey',
#   'Lat': -10.07,
#   'Lng': -78.15,
#   'Max Temp': 62.65,
#   'Humidity': 88,
#   'Cloudiness': 57,
#   'Wind Speed': 6.49,
#   'Current Weather': 'broken clouds',
#   'Country': 'PE'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 62.6,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Weather': 'few clouds',
#   'Country': 'PT'},
#  {'City': 'Belmonte',
#   'Lat': -15.86,
#   'Lng': -38.88,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Weather': 'broken clouds',
#   'Country': 'BR'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 8.6,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Weather': 'broken clouds',
#   'Country': 'CA'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -1.91,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.98,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Faanui',
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 82.18,
#   'Humidity': 76,
#   'Cloudiness': 76,
#   'Wind Speed': 9.98,
#   'Current Weather': 'broken clouds',
#   'Country': 'PF'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 41,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 17.22,
#   'Current Weather': 'scattered clouds',
#   'Country': 'CL'},
#  {'City': 'Noyabrsk',
#   'Lat': 63.2,
#   'Lng': 75.45,
#   'Max Temp': 15.1,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 15.3,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 69.53,
#   'Humidity': 79,
#   'Cloudiness': 85,
#   'Wind Speed': 7.92,
#   'Current Weather': 'overcast clouds',
#   'Country': 'EC'},
#  {'City': 'Barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 14,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 18.34,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Ferme-Neuve',
#   'Lat': 46.7,
#   'Lng': -75.45,
#   'Max Temp': 28.4,
#   'Humidity': 74,
#   'Cloudiness': 71,
#   'Wind Speed': 9.17,
#   'Current Weather': 'broken clouds',
#   'Country': 'CA'},
#  {'City': 'Nusaybin',
#   'Lat': 37.08,
#   'Lng': 41.22,
#   'Max Temp': 53.6,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Weather': 'clear sky',
#   'Country': 'TR'},
#  {'City': 'San Quintin',
#   'Lat': 30.48,
#   'Lng': -115.95,
#   'Max Temp': 59.56,
#   'Humidity': 82,
#   'Cloudiness': 3,
#   'Wind Speed': 9.19,
#   'Current Weather': 'clear sky',
#   'Country': 'MX'},
#  {'City': 'Butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 82.45,
#   'Humidity': 76,
#   'Cloudiness': 19,
#   'Wind Speed': 13.62,
#   'Current Weather': 'few clouds',
#   'Country': 'KI'},
#  {'City': 'Vilhena',
#   'Lat': -12.74,
#   'Lng': -60.15,
#   'Max Temp': 73.13,
#   'Humidity': 81,
#   'Cloudiness': 64,
#   'Wind Speed': 3.02,
#   'Current Weather': 'broken clouds',
#   'Country': 'BR'},
#  {'City': 'Dongsheng',
#   'Lat': 39.82,
#   'Lng': 109.98,
#   'Max Temp': 24.53,
#   'Humidity': 80,
#   'Cloudiness': 58,
#   'Wind Speed': 5.23,
#   'Current Weather': 'broken clouds',
#   'Country': 'CN'},
#  {'City': 'Victoria',
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 77,
#   'Humidity': 73,
#   'Cloudiness': 82,
#   'Wind Speed': 1.01,
#   'Current Weather': 'broken clouds',
#   'Country': 'HK'},
#  {'City': 'Springbok',
#   'Lat': -29.66,
#   'Lng': 17.89,
#   'Max Temp': 48.72,
#   'Humidity': 77,
#   'Cloudiness': 79,
#   'Wind Speed': 6.91,
#   'Current Weather': 'broken clouds',
#   'Country': 'ZA'},
#  {'City': 'College',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': 8.01,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Weather': 'broken clouds',
#   'Country': 'US'},
#  {'City': 'Cape Town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 61,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Weather': 'broken clouds',
#   'Country': 'ZA'},
#  {'City': 'Babati',
#   'Lat': -4.22,
#   'Lng': 35.75,
#   'Max Temp': 68.41,
#   'Humidity': 79,
#   'Cloudiness': 56,
#   'Wind Speed': 3.85,
#   'Current Weather': 'broken clouds',
#   'Country': 'TZ'},
#  {'City': 'Linxia',
#   'Lat': 35.6,
#   'Lng': 103.21,
#   'Max Temp': 33.3,
#   'Humidity': 84,
#   'Cloudiness': 37,
#   'Wind Speed': 2.59,
#   'Current Weather': 'scattered clouds',
#   'Country': 'CN'},
#  {'City': 'Tessalit',
#   'Lat': 20.2,
#   'Lng': 1.01,
#   'Max Temp': 49.93,
#   'Humidity': 44,
#   'Cloudiness': 8,
#   'Wind Speed': 9.19,
#   'Current Weather': 'clear sky',
#   'Country': 'ML'},
#  {'City': 'Acapulco',
#   'Lat': 16.86,
#   'Lng': -99.89,
#   'Max Temp': 77.72,
#   'Humidity': 73,
#   'Cloudiness': 14,
#   'Wind Speed': 3.89,
#   'Current Weather': 'few clouds',
#   'Country': 'MX'},
#  {'City': 'Torbay',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 39.99,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 27.51,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CA'},
#  {'City': 'Geraldton',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 87.8,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Weather': 'clear sky',
#   'Country': 'AU'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Lat': -0.41,
#   'Lng': -65.02,
#   'Max Temp': 73.78,
#   'Humidity': 98,
#   'Cloudiness': 89,
#   'Wind Speed': 1.12,
#   'Current Weather': 'overcast clouds',
#   'Country': 'BR'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 36,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 11.18,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Grootfontein',
#   'Lat': -19.57,
#   'Lng': 18.12,
#   'Max Temp': 72.63,
#   'Humidity': 26,
#   'Cloudiness': 7,
#   'Wind Speed': 7.25,
#   'Current Weather': 'clear sky',
#   'Country': 'NA'},
#  {'City': 'Pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 14.09,
#   'Humidity': 95,
#   'Cloudiness': 86,
#   'Wind Speed': 3.02,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Wajir',
#   'Lat': 1.75,
#   'Lng': 40.06,
#   'Max Temp': 79.63,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 11.21,
#   'Current Weather': 'clear sky',
#   'Country': 'KE'},
#  {'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 73.99,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 4.05,
#   'Current Weather': 'overcast clouds',
#   'Country': 'PF'},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 72,
#   'Humidity': 48,
#   'Cloudiness': 92,
#   'Wind Speed': 3,
#   'Current Weather': 'overcast clouds',
#   'Country': 'AU'},
#  {'City': 'Dawson Creek',
#   'Lat': 55.77,
#   'Lng': -120.24,
#   'Max Temp': 26.6,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Weather': 'clear sky',
#   'Country': 'CA'},
#  {'City': 'Carnarvon',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Weather': 'clear sky',
#   'Country': 'AU'},
#  {'City': 'Ucluelet',
#   'Lat': 48.93,
#   'Lng': -125.55,
#   'Max Temp': 46,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.97,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CA'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 63,
#   'Humidity': 59,
#   'Cloudiness': 67,
#   'Wind Speed': 7,
#   'Current Weather': 'broken clouds',
#   'Country': 'NZ'},
#  {'City': 'Veraval',
#   'Lat': 20.9,
#   'Lng': 70.37,
#   'Max Temp': 79,
#   'Humidity': 29,
#   'Cloudiness': 37,
#   'Wind Speed': 5.64,
#   'Current Weather': 'scattered clouds',
#   'Country': 'IN'},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 64.26,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 15.21,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ZA'},
#  {'City': 'Soanierana Ivongo',
#   'Lat': -16.92,
#   'Lng': 49.58,
#   'Max Temp': 79.36,
#   'Humidity': 67,
#   'Cloudiness': 89,
#   'Wind Speed': 2.91,
#   'Current Weather': 'overcast clouds',
#   'Country': 'MG'},
#  {'City': 'Aktash',
#   'Lat': 50.3,
#   'Lng': 87.73,
#   'Max Temp': 9.81,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 2.66,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Dingle',
#   'Lat': 11,
#   'Lng': 122.67,
#   'Max Temp': 82.49,
#   'Humidity': 81,
#   'Cloudiness': 98,
#   'Wind Speed': 15.3,
#   'Current Weather': 'overcast clouds',
#   'Country': 'PH'},
#  {'City': 'Provideniya',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 32,
#   'Humidity': 95,
#   'Cloudiness': 75,
#   'Wind Speed': 17.9,
#   'Current Weather': 'heavy snow',
#   'Country': 'RU'},
#  {'City': 'Iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': -4,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Current Weather': 'light snow',
#   'Country': 'CA'},
#  {'City': 'Luderitz',
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 59,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Weather': 'clear sky',
#   'Country': 'NA'},
#  {'City': 'Solnechnyy',
#   'Lat': 50.72,
#   'Lng': 136.63,
#   'Max Temp': 23.49,
#   'Humidity': 81,
#   'Cloudiness': 6,
#   'Wind Speed': 4.38,
#   'Current Weather': 'clear sky',
#   'Country': 'RU'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 82.29,
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 10.18,
#   'Current Weather': 'overcast clouds',
#   'Country': 'MV'},
#  {'City': 'Ginda',
#   'Lat': 30.69,
#   'Lng': 78.49,
#   'Max Temp': 60.48,
#   'Humidity': 32,
#   'Cloudiness': 91,
#   'Wind Speed': 0.72,
#   'Current Weather': 'overcast clouds',
#   'Country': 'IN'},
#  {'City': 'Corinto',
#   'Lat': 37.94,
#   'Lng': 22.96,
#   'Max Temp': 52,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Current Weather': 'clear sky',
#   'Country': 'GR'},
#  {'City': 'Lingao',
#   'Lat': 19.91,
#   'Lng': 109.69,
#   'Max Temp': 77.58,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 20.36,
#   'Current Weather': 'scattered clouds',
#   'Country': 'CN'},
#  {'City': 'Santiago',
#   'Lat': -33.46,
#   'Lng': -70.65,
#   'Max Temp': 63,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Weather': 'clear sky',
#   'Country': 'CL'},
#  {'City': 'Meulaboh',
#   'Lat': 4.14,
#   'Lng': 96.13,
#   'Max Temp': 84.69,
#   'Humidity': 66,
#   'Cloudiness': 73,
#   'Wind Speed': 3.09,
#   'Current Weather': 'broken clouds',
#   'Country': 'ID'},
#  {'City': 'Great Yarmouth',
#   'Lat': 52.61,
#   'Lng': 1.73,
#   'Max Temp': 46.4,
#   'Humidity': 87,
#   'Cloudiness': 8,
#   'Wind Speed': 10.29,
#   'Current Weather': 'clear sky',
#   'Country': 'GB'},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 64,
#   'Humidity': 61,
#   'Cloudiness': 22,
#   'Wind Speed': 7,
#   'Current Weather': 'light rain',
#   'Country': 'ZA'},
#  {'City': 'Khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 0.93,
#   'Humidity': 94,
#   'Cloudiness': 94,
#   'Wind Speed': 6.22,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Aklavik',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 8.6,
#   'Humidity': 84,
#   'Cloudiness': 60,
#   'Wind Speed': 6.93,
#   'Current Weather': 'broken clouds',
#   'Country': 'CA'},
#  {'City': 'Bijie',
#   'Lat': 27.31,
#   'Lng': 105.29,
#   'Max Temp': 51.48,
#   'Humidity': 69,
#   'Cloudiness': 85,
#   'Wind Speed': 4.76,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CN'},
#  {'City': 'Batagay-Alyta',
#   'Lat': 67.8,
#   'Lng': 130.41,
#   'Max Temp': 3.25,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.66,
#   'Current Weather': 'light snow',
#   'Country': 'RU'},
#  {'City': 'Olafsvik',
#   'Lat': 64.89,
#   'Lng': -23.71,
#   'Max Temp': 37,
#   'Humidity': 80,
#   'Cloudiness': 65,
#   'Wind Speed': 21.65,
#   'Current Weather': 'broken clouds',
#   'Country': 'IS'},
#  {'City': 'Sol-Iletsk',
#   'Lat': 51.16,
#   'Lng': 54.99,
#   'Max Temp': 23.02,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 11.03,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Kamaishi',
#   'Lat': 39.27,
#   'Lng': 141.88,
#   'Max Temp': 46.4,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Weather': 'broken clouds',
#   'Country': 'JP'},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 35.01,
#   'Humidity': 73,
#   'Cloudiness': 4,
#   'Wind Speed': 4,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Moron',
#   'Lat': -34.65,
#   'Lng': -58.62,
#   'Max Temp': 79,
#   'Humidity': 46,
#   'Cloudiness': 24,
#   'Wind Speed': 8.01,
#   'Current Weather': 'few clouds',
#   'Country': 'AR'},
#  {'City': 'Upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 16.32,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 7.65,
#   'Current Weather': 'overcast clouds',
#   'Country': 'GL'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 88,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 17.52,
#   'Current Weather': 'clear sky',
#   'Country': 'AU'},
#  {'City': 'Gloucester',
#   'Lat': 51.87,
#   'Lng': -2.24,
#   'Max Temp': 51.01,
#   'Humidity': 83,
#   'Cloudiness': 88,
#   'Wind Speed': 18.01,
#   'Current Weather': 'overcast clouds',
#   'Country': 'GB'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 78.8,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Weather': 'clear sky',
#   'Country': 'RE'},
#  {'City': 'Bodden Town',
#   'Lat': 19.28,
#   'Lng': -81.25,
#   'Max Temp': 80.01,
#   'Humidity': 80,
#   'Cloudiness': 23,
#   'Wind Speed': 20,
#   'Current Weather': 'few clouds',
#   'Country': 'KY'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.53,
#   'Lng': 72.93,
#   'Max Temp': 82.44,
#   'Humidity': 75,
#   'Cloudiness': 46,
#   'Wind Speed': 10.47,
#   'Current Weather': 'light rain',
#   'Country': 'MV'},
#  {'City': 'Vanimo',
#   'Lat': -2.67,
#   'Lng': 141.3,
#   'Max Temp': 78.91,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.91,
#   'Current Weather': 'light rain',
#   'Country': 'PG'},
#  {'City': 'Mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Weather': 'shower rain',
#   'Country': 'MU'},
#  {'City': 'Rochefort',
#   'Lat': 45.92,
#   'Lng': -1,
#   'Max Temp': 39.2,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Weather': 'overcast clouds',
#   'Country': 'FR'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 61.02,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 20.67,
#   'Current Weather': 'overcast clouds',
#   'Country': 'PT'},
#  {'City': 'Port Moresby',
#   'Lat': -9.44,
#   'Lng': 147.18,
#   'Max Temp': 89.6,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Weather': 'haze',
#   'Country': 'PG'},
#  {'City': 'Nemuro',
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Max Temp': 39.2,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Current Weather': 'few clouds',
#   'Country': 'JP'},
#  {'City': 'Vardo',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 30.2,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Weather': 'scattered clouds',
#   'Country': 'NO'},
#  {'City': 'Gillette',
#   'Lat': 44.29,
#   'Lng': -105.5,
#   'Max Temp': 27,
#   'Humidity': 52,
#   'Cloudiness': 1,
#   'Wind Speed': 7.4,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Ahipara',
#   'Lat': -35.17,
#   'Lng': 173.17,
#   'Max Temp': 61.81,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 12.59,
#   'Current Weather': 'overcast clouds',
#   'Country': 'NZ'},
#  {'City': 'Lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 49.8,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 3.53,
#   'Current Weather': 'clear sky',
#   'Country': 'CL'},
#  {'City': 'Sakakah',
#   'Lat': 29.97,
#   'Lng': 40.21,
#   'Max Temp': 50,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Weather': 'clear sky',
#   'Country': 'SA'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 30.92,
#   'Humidity': 90,
#   'Cloudiness': 97,
#   'Wind Speed': 21.45,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 80.01,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Weather': 'shower rain',
#   'Country': 'MU'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.46,
#   'Lng': -71.14,
#   'Max Temp': 79.5,
#   'Humidity': 78,
#   'Cloudiness': 59,
#   'Wind Speed': 12.93,
#   'Current Weather': 'broken clouds',
#   'Country': 'TC'},
#  {'City': 'Yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 12.2,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Weather': 'light snow',
#   'Country': 'CA'},
#  {'City': 'Mattru',
#   'Lat': 7.62,
#   'Lng': -11.83,
#   'Max Temp': 73.36,
#   'Humidity': 96,
#   'Cloudiness': 4,
#   'Wind Speed': 1.97,
#   'Current Weather': 'clear sky',
#   'Country': 'SL'},
#  {'City': 'Coquimbo',
#   'Lat': -29.95,
#   'Lng': -71.34,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'CL'},
#  {'City': 'East London',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 62.6,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Weather': 'broken clouds',
#   'Country': 'ZA'},
#  {'City': 'Hasaki',
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 57,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Weather': 'broken clouds',
#   'Country': 'JP'},
#  {'City': 'Rio Grande',
#   'Lat': -32.03,
#   'Lng': -52.1,
#   'Max Temp': 70,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Current Weather': 'clear sky',
#   'Country': 'BR'},
#  {'City': 'Hobyo',
#   'Lat': 5.35,
#   'Lng': 48.53,
#   'Max Temp': 81.32,
#   'Humidity': 74,
#   'Cloudiness': 71,
#   'Wind Speed': 5.03,
#   'Current Weather': 'broken clouds',
#   'Country': 'SO'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 72.77,
#   'Humidity': 84,
#   'Cloudiness': 67,
#   'Wind Speed': 11.92,
#   'Current Weather': 'broken clouds',
#   'Country': 'BR'},
#  {'City': 'Marrakesh',
#   'Lat': 31.63,
#   'Lng': -8.01,
#   'Max Temp': 53.6,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'MA'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.31,
#   'Lng': 121.11,
#   'Max Temp': 90,
#   'Humidity': 49,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Current Weather': 'scattered clouds',
#   'Country': 'PH'},
#  {'City': 'Seoul',
#   'Lat': 37.57,
#   'Lng': 126.98,
#   'Max Temp': 44.6,
#   'Humidity': 39,
#   'Cloudiness': 90,
#   'Wind Speed': 4.54,
#   'Current Weather': 'overcast clouds',
#   'Country': 'KR'},
#  {'City': 'Isla Vista',
#   'Lat': 34.41,
#   'Lng': -119.86,
#   'Max Temp': 62.6,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Povenets',
#   'Lat': 62.85,
#   'Lng': 34.83,
#   'Max Temp': 34.3,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.7,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Malkangiri',
#   'Lat': 18.35,
#   'Lng': 81.9,
#   'Max Temp': 79.41,
#   'Humidity': 55,
#   'Cloudiness': 98,
#   'Wind Speed': 2.98,
#   'Current Weather': 'overcast clouds',
#   'Country': 'IN'},
#  {'City': 'Thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 8.6,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Weather': 'light snow',
#   'Country': 'CA'},
#  {'City': 'Kalmunai',
#   'Lat': 7.42,
#   'Lng': 81.82,
#   'Max Temp': 83.7,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 13.6,
#   'Current Weather': 'light rain',
#   'Country': 'LK'},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 63.01,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 11.36,
#   'Current Weather': 'light rain',
#   'Country': 'UY'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 78.24,
#   'Humidity': 73,
#   'Cloudiness': 24,
#   'Wind Speed': 14.09,
#   'Current Weather': 'few clouds',
#   'Country': 'PF'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.21,
#   'Lng': 57.76,
#   'Max Temp': 80.01,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Weather': 'shower rain',
#   'Country': 'MU'},
#  {'City': 'Fairbanks',
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Max Temp': 7,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 1.12,
#   'Current Weather': 'scattered clouds',
#   'Country': 'US'},
#  {'City': 'Walvis Bay',
#   'Lat': -22.96,
#   'Lng': 14.51,
#   'Max Temp': 57,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'NA'},
#  {'City': 'Goundam',
#   'Lat': 16.41,
#   'Lng': -3.67,
#   'Max Temp': 62.53,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 13.02,
#   'Current Weather': 'clear sky',
#   'Country': 'ML'},
#  {'City': 'Fallon',
#   'Lat': 39.47,
#   'Lng': -118.78,
#   'Max Temp': 35.01,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Weather': 'scattered clouds',
#   'Country': 'US'},
#  {'City': 'Gornopravdinsk',
#   'Lat': 60.05,
#   'Lng': 69.9,
#   'Max Temp': 20.07,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 9.71,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Bemidji',
#   'Lat': 47.47,
#   'Lng': -94.88,
#   'Max Temp': 25,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 13.87,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.34,
#   'Lng': 55.48,
#   'Max Temp': 78.8,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Weather': 'clear sky',
#   'Country': 'RE'},
#  {'City': 'Rajgarh',
#   'Lat': 28.63,
#   'Lng': 75.38,
#   'Max Temp': 71.31,
#   'Humidity': 22,
#   'Cloudiness': 89,
#   'Wind Speed': 4.54,
#   'Current Weather': 'overcast clouds',
#   'Country': 'IN'},
#  {'City': 'Paraiso',
#   'Lat': 9.84,
#   'Lng': -83.87,
#   'Max Temp': 70,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Weather': 'mist',
#   'Country': 'CR'},
#  {'City': 'Prainha',
#   'Lat': -1.8,
#   'Lng': -53.48,
#   'Max Temp': 73.92,
#   'Humidity': 94,
#   'Cloudiness': 34,
#   'Wind Speed': 3.09,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BR'},
#  {'City': 'Morgan City',
#   'Lat': 29.7,
#   'Lng': -91.21,
#   'Max Temp': 59,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Nuuk',
#   'Lat': 64.18,
#   'Lng': -51.72,
#   'Max Temp': 26.6,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 12.75,
#   'Current Weather': 'light shower snow',
#   'Country': 'GL'},
#  {'City': 'Ulaanbaatar',
#   'Lat': 47.91,
#   'Lng': 106.88,
#   'Max Temp': 15.8,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 4.05,
#   'Current Weather': 'snow',
#   'Country': 'MN'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 77.36,
#   'Humidity': 77,
#   'Cloudiness': 71,
#   'Wind Speed': 3.56,
#   'Current Weather': 'broken clouds',
#   'Country': 'CV'},
#  {'City': 'Skibbereen',
#   'Lat': 51.55,
#   'Lng': -9.27,
#   'Max Temp': 50,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Current Weather': 'broken clouds',
#   'Country': 'IE'},
#  {'City': 'Karpogory',
#   'Lat': 64,
#   'Lng': 44.45,
#   'Max Temp': 27.75,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.8,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Ust-Kalmanka',
#   'Lat': 52.12,
#   'Lng': 83.31,
#   'Max Temp': 22.17,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Current Weather': 'light snow',
#   'Country': 'RU'},
#  {'City': 'Kalevala',
#   'Lat': 65.2,
#   'Lng': 31.17,
#   'Max Temp': 32.63,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.3,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.81,
#   'Lng': -122.7,
#   'Max Temp': -2.2,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Weather': 'broken clouds',
#   'Country': 'CA'},
#  {'City': 'Le Port',
#   'Lat': -20.94,
#   'Lng': 55.29,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 23.04,
#   'Current Weather': 'clear sky',
#   'Country': 'RE'},
#  {'City': 'Salalah',
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Weather': 'clear sky',
#   'Country': 'OM'},
#  {'City': 'Anderson',
#   'Lat': 34.53,
#   'Lng': -82.65,
#   'Max Temp': 45,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Mezen',
#   'Lat': 65.85,
#   'Lng': 44.24,
#   'Max Temp': 27.39,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 10.69,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Imeni Zhelyabova',
#   'Lat': 58.95,
#   'Lng': 36.6,
#   'Max Temp': 34.56,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 7.05,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Barra Do Garcas',
#   'Lat': -15.89,
#   'Lng': -52.26,
#   'Max Temp': 71.01,
#   'Humidity': 91,
#   'Cloudiness': 9,
#   'Wind Speed': 2.93,
#   'Current Weather': 'clear sky',
#   'Country': 'BR'},
#  {'City': 'Ca Mau',
#   'Lat': 9.18,
#   'Lng': 105.15,
#   'Max Temp': 87.62,
#   'Humidity': 61,
#   'Cloudiness': 76,
#   'Wind Speed': 7.99,
#   'Current Weather': 'broken clouds',
#   'Country': 'VN'},
#  {'City': 'Port-Cartier',
#   'Lat': 50.03,
#   'Lng': -66.87,
#   'Max Temp': 32,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 15.39,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CA'},
#  {'City': 'Saint-Georges',
#   'Lat': 12.06,
#   'Lng': -61.75,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 20.8,
#   'Current Weather': 'few clouds',
#   'Country': 'GD'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 78.1,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 6.58,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ID'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 30.06,
#   'Humidity': 95,
#   'Cloudiness': 21,
#   'Wind Speed': 18.79,
#   'Current Weather': 'few clouds',
#   'Country': 'RU'},
#  {'City': 'Yulara',
#   'Lat': -25.24,
#   'Lng': 130.99,
#   'Max Temp': 91.4,
#   'Humidity': 16,
#   'Cloudiness': 98,
#   'Wind Speed': 8.05,
#   'Current Weather': 'overcast clouds',
#   'Country': 'AU'},
#  {'City': 'Dengzhou',
#   'Lat': 37.81,
#   'Lng': 120.75,
#   'Max Temp': 45.36,
#   'Humidity': 58,
#   'Cloudiness': 34,
#   'Wind Speed': 14.18,
#   'Current Weather': 'scattered clouds',
#   'Country': 'CN'},
#  {'City': 'Carora',
#   'Lat': 10.18,
#   'Lng': -70.08,
#   'Max Temp': 73.36,
#   'Humidity': 85,
#   'Cloudiness': 86,
#   'Wind Speed': 5.75,
#   'Current Weather': 'overcast clouds',
#   'Country': 'VE'},
#  {'City': 'Petropavlovka',
#   'Lat': 50.61,
#   'Lng': 105.32,
#   'Max Temp': 26.94,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.89,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Weather': 'broken clouds',
#   'Country': 'TO'},
#  {'City': 'Ejby',
#   'Lat': 55.49,
#   'Lng': 12.08,
#   'Max Temp': 45,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Current Weather': 'overcast clouds',
#   'Country': 'DK'},
#  {'City': 'Beian',
#   'Lat': 63.66,
#   'Lng': 9.57,
#   'Max Temp': 41,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 18.34,
#   'Current Weather': 'light rain',
#   'Country': 'NO'},
#  {'City': 'Baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 6.75,
#   'Humidity': 91,
#   'Cloudiness': 71,
#   'Wind Speed': 1.52,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Boyabat',
#   'Lat': 41.47,
#   'Lng': 34.77,
#   'Max Temp': 36.25,
#   'Humidity': 77,
#   'Cloudiness': 84,
#   'Wind Speed': 1.79,
#   'Current Weather': 'broken clouds',
#   'Country': 'TR'},
#  {'City': 'Nanortalik',
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 22.14,
#   'Humidity': 86,
#   'Cloudiness': 9,
#   'Wind Speed': 8.59,
#   'Current Weather': 'clear sky',
#   'Country': 'GL'},
#  {'City': 'Bathsheba',
#   'Lat': 13.22,
#   'Lng': -59.52,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 21.92,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BB'},
#  {'City': 'Shingu',
#   'Lat': 33.73,
#   'Lng': 135.98,
#   'Max Temp': 64.4,
#   'Humidity': 42,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Weather': 'few clouds',
#   'Country': 'JP'},
#  {'City': 'Evensk',
#   'Lat': 61.95,
#   'Lng': 159.23,
#   'Max Temp': -1.77,
#   'Humidity': 84,
#   'Cloudiness': 17,
#   'Wind Speed': 7.27,
#   'Current Weather': 'few clouds',
#   'Country': 'RU'},
#  {'City': 'Sherbakul',
#   'Lat': 54.63,
#   'Lng': 72.4,
#   'Max Temp': 17.6,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 5.19,
#   'Current Weather': 'mist',
#   'Country': 'RU'},
#  {'City': 'Puerto Del Rosario',
#   'Lat': 28.5,
#   'Lng': -13.86,
#   'Max Temp': 69.8,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Weather': 'clear sky',
#   'Country': 'ES'},
#  {'City': 'Hirara',
#   'Lat': 24.8,
#   'Lng': 125.28,
#   'Max Temp': 77,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 14.99,
#   'Current Weather': 'scattered clouds',
#   'Country': 'JP'},
#  {'City': 'Danjiangkou',
#   'Lat': 32.54,
#   'Lng': 111.51,
#   'Max Temp': 39.87,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 1.9,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CN'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 79,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 2.26,
#   'Current Weather': 'few clouds',
#   'Country': 'MX'},
#  {'City': 'Port Blair',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 83.98,
#   'Humidity': 74,
#   'Cloudiness': 38,
#   'Wind Speed': 13.35,
#   'Current Weather': 'scattered clouds',
#   'Country': 'IN'},
#  {'City': 'La Tuque',
#   'Lat': 47.43,
#   'Lng': -72.78,
#   'Max Temp': 26.6,
#   'Humidity': 79,
#   'Cloudiness': 92,
#   'Wind Speed': 9.17,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CA'},
#  {'City': 'Ambilobe',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 83.62,
#   'Humidity': 47,
#   'Cloudiness': 3,
#   'Wind Speed': 5.48,
#   'Current Weather': 'clear sky',
#   'Country': 'MG'},
#  {'City': 'Thurso',
#   'Lat': 58.59,
#   'Lng': -3.53,
#   'Max Temp': 46.4,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93,
#   'Current Weather': 'overcast clouds',
#   'Country': 'GB'},
#  {'City': 'Natchitoches',
#   'Lat': 31.77,
#   'Lng': -93.13,
#   'Max Temp': 48.2,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 6.26,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Port Hardy',
#   'Lat': 50.7,
#   'Lng': -127.42,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 19.46,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CA'},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Weather': 'light rain',
#   'Country': 'US'},
#  {'City': 'Grants',
#   'Lat': 35.15,
#   'Lng': -107.85,
#   'Max Temp': 48.2,
#   'Humidity': 45,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Gijon',
#   'Lat': 43.54,
#   'Lng': -5.66,
#   'Max Temp': 54,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ES'},
#  {'City': 'Castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 53.55,
#   'Humidity': 95,
#   'Cloudiness': 17,
#   'Wind Speed': 8.08,
#   'Current Weather': 'few clouds',
#   'Country': 'BR'},
#  {'City': 'Bintulu',
#   'Lat': 3.17,
#   'Lng': 113.03,
#   'Max Temp': 86,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Weather': 'scattered clouds',
#   'Country': 'MY'},
#  {'City': 'Ahuimanu',
#   'Lat': 21.44,
#   'Lng': -157.84,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Miranda',
#   'Lat': 3.25,
#   'Lng': -76.23,
#   'Max Temp': 73.4,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Weather': 'scattered clouds',
#   'Country': 'CO'},
#  {'City': 'Chitungwiza',
#   'Lat': -18.01,
#   'Lng': 31.08,
#   'Max Temp': 73,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 8.01,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ZW'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.73,
#   'Lng': -27.07,
#   'Max Temp': 59,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 20.27,
#   'Current Weather': 'overcast clouds',
#   'Country': 'PT'},
#  {'City': 'Bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 35.01,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 5.35,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Abu Samrah',
#   'Lat': 35.3,
#   'Lng': 37.18,
#   'Max Temp': 51.8,
#   'Humidity': 48,
#   'Cloudiness': 2,
#   'Wind Speed': 7.25,
#   'Current Weather': 'clear sky',
#   'Country': 'SY'},
#  {'City': 'Samarai',
#   'Lat': -10.62,
#   'Lng': 150.67,
#   'Max Temp': 84.72,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 15.57,
#   'Current Weather': 'overcast clouds',
#   'Country': 'PG'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 38.88,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Weather': 'overcast clouds',
#   'Country': 'IS'},
#  {'City': 'Fortuna',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 48.99,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Qasigiannguit',
#   'Lat': 68.82,
#   'Lng': -51.19,
#   'Max Temp': 15.8,
#   'Humidity': 47,
#   'Cloudiness': 99,
#   'Wind Speed': 20.8,
#   'Current Weather': 'light shower snow',
#   'Country': 'GL'},
#  {'City': 'Talnakh',
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Max Temp': 19.4,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 17.9,
#   'Current Weather': 'light shower snow',
#   'Country': 'RU'},
#  {'City': 'Caravelas',
#   'Lat': -17.71,
#   'Lng': -39.25,
#   'Max Temp': 73.24,
#   'Humidity': 85,
#   'Cloudiness': 35,
#   'Wind Speed': 6.46,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BR'},
#  {'City': 'Sabzevar',
#   'Lat': 36.21,
#   'Lng': 57.68,
#   'Max Temp': 39.2,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Weather': 'scattered clouds',
#   'Country': 'IR'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.56,
#   'Lng': 95.32,
#   'Max Temp': 85.05,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 6.6,
#   'Current Weather': 'broken clouds',
#   'Country': 'ID'},
#  {'City': 'Oranjestad',
#   'Lat': 12.52,
#   'Lng': -70.03,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 14.99,
#   'Current Weather': 'few clouds',
#   'Country': 'AW'},
#  {'City': 'Kutum',
#   'Lat': 14.2,
#   'Lng': 24.67,
#   'Max Temp': 58.86,
#   'Humidity': 34,
#   'Cloudiness': 2,
#   'Wind Speed': 3.74,
#   'Current Weather': 'clear sky',
#   'Country': 'SD'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 23,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Current Weather': 'overcast clouds',
#   'Country': 'GL'},
#  {'City': 'Zemio',
#   'Lat': 5.03,
#   'Lng': 25.14,
#   'Max Temp': 69.84,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 2.21,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CF'},
#  {'City': 'Teguldet',
#   'Lat': 57.31,
#   'Lng': 88.17,
#   'Max Temp': 15.26,
#   'Humidity': 95,
#   'Cloudiness': 42,
#   'Wind Speed': 2.06,
#   'Current Weather': 'scattered clouds',
#   'Country': 'RU'},
#  {'City': 'Charters Towers',
#   'Lat': -20.1,
#   'Lng': 146.27,
#   'Max Temp': 98.58,
#   'Humidity': 19,
#   'Cloudiness': 22,
#   'Wind Speed': 11.95,
#   'Current Weather': 'few clouds',
#   'Country': 'AU'},
#  {'City': 'Lompoc',
#   'Lat': 34.64,
#   'Lng': -120.46,
#   'Max Temp': 51.01,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Kahramanmaras',
#   'Lat': 38,
#   'Lng': 37,
#   'Max Temp': 33.8,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Weather': 'clear sky',
#   'Country': 'TR'},
#  {'City': 'Chapais',
#   'Lat': 49.78,
#   'Lng': -74.85,
#   'Max Temp': 15.8,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Current Weather': 'light snow',
#   'Country': 'CA'},
#  {'City': 'Necochea',
#   'Lat': -38.55,
#   'Lng': -58.74,
#   'Max Temp': 64.99,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Current Weather': 'moderate rain',
#   'Country': 'AR'},
#  {'City': 'Poum',
#   'Lat': -20.23,
#   'Lng': 164.02,
#   'Max Temp': 77.58,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 17.25,
#   'Current Weather': 'clear sky',
#   'Country': 'NC'},
#  {'City': 'San Patricio',
#   'Lat': 28.02,
#   'Lng': -97.52,
#   'Max Temp': 73,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Weather': 'broken clouds',
#   'Country': 'US'},
#  {'City': 'Varadero',
#   'Lat': 23.15,
#   'Lng': -81.25,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Weather': 'scattered clouds',
#   'Country': 'CU'},
#  {'City': 'Kavaratti',
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Weather': 'few clouds',
#   'Country': 'IN'},
#  {'City': 'Makakilo City',
#   'Lat': 21.35,
#   'Lng': -158.09,
#   'Max Temp': 78.8,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Vorukh',
#   'Lat': 39.85,
#   'Lng': 70.58,
#   'Max Temp': 34.18,
#   'Humidity': 70,
#   'Cloudiness': 38,
#   'Wind Speed': 2.91,
#   'Current Weather': 'scattered clouds',
#   'Country': 'TJ'},
#  {'City': 'Kangalassy',
#   'Lat': 62.35,
#   'Lng': 129.96,
#   'Max Temp': -8.88,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.18,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Puerto Palomas',
#   'Lat': 31.77,
#   'Lng': -107.62,
#   'Max Temp': 59,
#   'Humidity': 26,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'MX'},
#  {'City': 'Darby',
#   'Lat': 39.92,
#   'Lng': -75.26,
#   'Max Temp': 43,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 11.21,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 32.09,
#   'Humidity': 96,
#   'Cloudiness': 96,
#   'Wind Speed': 8.14,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Asau',
#   'Lat': 46.43,
#   'Lng': 26.4,
#   'Max Temp': 36,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.36,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RO'},
#  {'City': 'San Joaquin',
#   'Lat': 37.93,
#   'Lng': -121.3,
#   'Max Temp': 53.01,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Meadow Lake',
#   'Lat': 34.8,
#   'Lng': -106.54,
#   'Max Temp': 57.2,
#   'Humidity': 41,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Weather': 'broken clouds',
#   'Country': 'US'},
#  {'City': 'Rovaniemi',
#   'Lat': 66.5,
#   'Lng': 25.72,
#   'Max Temp': 26.6,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Current Weather': 'broken clouds',
#   'Country': 'FI'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 28.4,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Weather': 'broken clouds',
#   'Country': 'SJ'},
#  {'City': 'Saldanha',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Max Temp': 59,
#   'Humidity': 82,
#   'Cloudiness': 24,
#   'Wind Speed': 4.7,
#   'Current Weather': 'few clouds',
#   'Country': 'ZA'},
#  {'City': 'Tuatapere',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 63,
#   'Humidity': 59,
#   'Cloudiness': 88,
#   'Wind Speed': 7,
#   'Current Weather': 'overcast clouds',
#   'Country': 'NZ'},
#  {'City': 'Meiganga',
#   'Lat': 6.52,
#   'Lng': 14.3,
#   'Max Temp': 64.74,
#   'Humidity': 39,
#   'Cloudiness': 100,
#   'Wind Speed': 2.89,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CM'},
#  {'City': 'Banga',
#   'Lat': 6.42,
#   'Lng': 124.78,
#   'Max Temp': 87.8,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Current Weather': 'light rain',
#   'Country': 'PH'},
#  {'City': 'Kununurra',
#   'Lat': -15.77,
#   'Lng': 128.73,
#   'Max Temp': 104,
#   'Humidity': 28,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Weather': 'scattered clouds',
#   'Country': 'AU'},
#  {'City': 'Burnie',
#   'Lat': -41.07,
#   'Lng': 145.92,
#   'Max Temp': 60.73,
#   'Humidity': 74,
#   'Cloudiness': 92,
#   'Wind Speed': 12.15,
#   'Current Weather': 'overcast clouds',
#   'Country': 'AU'},
#  {'City': 'Thongwa',
#   'Lat': 16.76,
#   'Lng': 96.53,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 10,
#   'Wind Speed': 3.36,
#   'Current Weather': 'clear sky',
#   'Country': 'MM'},
#  {'City': 'Majene',
#   'Lat': -3.54,
#   'Lng': 118.97,
#   'Max Temp': 87.15,
#   'Humidity': 64,
#   'Cloudiness': 98,
#   'Wind Speed': 6.22,
#   'Current Weather': 'light rain',
#   'Country': 'ID'},
#  {'City': 'Husavik',
#   'Lat': 66.04,
#   'Lng': -17.34,
#   'Max Temp': 32,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Weather': 'overcast clouds',
#   'Country': 'IS'},
#  {'City': 'Son La',
#   'Lat': 21.32,
#   'Lng': 103.9,
#   'Max Temp': 78.82,
#   'Humidity': 60,
#   'Cloudiness': 42,
#   'Wind Speed': 4.09,
#   'Current Weather': 'scattered clouds',
#   'Country': 'VN'},
#  {'City': 'Kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 55,
#   'Humidity': 81,
#   'Cloudiness': 93,
#   'Wind Speed': 10,
#   'Current Weather': 'overcast clouds',
#   'Country': 'NZ'},
#  {'City': 'Grindavik',
#   'Lat': 63.84,
#   'Lng': -22.43,
#   'Max Temp': 32,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 14.99,
#   'Current Weather': 'clear sky',
#   'Country': 'IS'},
#  {'City': 'Biak',
#   'Lat': -0.91,
#   'Lng': 122.88,
#   'Max Temp': 84.25,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 1.7,
#   'Current Weather': 'moderate rain',
#   'Country': 'ID'},
#  {'City': 'Gorontalo',
#   'Lat': 0.54,
#   'Lng': 123.06,
#   'Max Temp': 84.47,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.19,
#   'Current Weather': 'overcast clouds',
#   'Country': 'ID'},
#  {'City': 'Ulladulla',
#   'Lat': -35.35,
#   'Lng': 150.47,
#   'Max Temp': 73.4,
#   'Humidity': 53,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Weather': 'scattered clouds',
#   'Country': 'AU'},
#  {'City': 'Sao Mateus',
#   'Lat': -18.72,
#   'Lng': -39.86,
#   'Max Temp': 67.98,
#   'Humidity': 96,
#   'Cloudiness': 81,
#   'Wind Speed': 4.99,
#   'Current Weather': 'broken clouds',
#   'Country': 'BR'},
#  {'City': 'Aberystwyth',
#   'Lat': 52.42,
#   'Lng': -4.08,
#   'Max Temp': 50,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 1.01,
#   'Current Weather': 'overcast clouds',
#   'Country': 'GB'},
#  {'City': 'Leh',
#   'Lat': 34.17,
#   'Lng': 77.58,
# ...
#   'Wind Speed': 5.82,
#   'Current Weather': 'scattered clouds',
#   'Country': 'US'},
#  {'City': 'Marysville',
#   'Lat': 48.05,
#   'Lng': -122.18,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 3.47,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Erenhot',
#   'Lat': 43.65,
#   'Lng': 111.98,
#   'Max Temp': 16.84,
#   'Humidity': 88,
#   'Cloudiness': 52,
#   'Wind Speed': 5.95,
#   'Current Weather': 'broken clouds',
#   'Country': 'CN'},
#  {'City': 'Syedove',
#   'Lat': 47.08,
#   'Lng': 38.16,
#   'Max Temp': 37.99,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 8.99,
#   'Current Weather': 'overcast clouds',
#   'Country': 'UA'},
#  {'City': 'Le Tampon',
#   'Lat': -21.27,
#   'Lng': 55.52,
#   'Max Temp': 78.8,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Weather': 'clear sky',
#   'Country': 'RE'},
#  {'City': 'Sokolo',
#   'Lat': 14.73,
#   'Lng': -6.12,
#   'Max Temp': 65.41,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 12.3,
#   'Current Weather': 'clear sky',
#   'Country': 'ML'},
#  {'City': 'San Pedro Del Parana',
#   'Lat': -26.83,
#   'Lng': -56.2,
#   'Max Temp': 72.63,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 5.73,
#   'Current Weather': 'clear sky',
#   'Country': 'PY'},
#  {'City': 'Xining',
#   'Lat': 36.62,
#   'Lng': 101.77,
#   'Max Temp': 33.39,
#   'Humidity': 79,
#   'Cloudiness': 26,
#   'Wind Speed': 1.48,
#   'Current Weather': 'scattered clouds',
#   'Country': 'CN'},
#  {'City': 'Male',
#   'Lat': 4.17,
#   'Lng': 73.51,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Current Weather': 'broken clouds',
#   'Country': 'MV'},
#  {'City': 'Sharjah',
#   'Lat': 25.36,
#   'Lng': 55.4,
#   'Max Temp': 80.6,
#   'Humidity': 42,
#   'Cloudiness': 40,
#   'Wind Speed': 14.99,
#   'Current Weather': 'scattered clouds',
#   'Country': 'AE'},
#  {'City': 'Dunmore Town',
#   'Lat': 25.5,
#   'Lng': -76.65,
#   'Max Temp': 77.13,
#   'Humidity': 77,
#   'Cloudiness': 6,
#   'Wind Speed': 14.54,
#   'Current Weather': 'clear sky',
#   'Country': 'BS'},
#  {'City': 'Black River',
#   'Lat': 18.03,
#   'Lng': -77.85,
#   'Max Temp': 75.99,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Current Weather': 'scattered clouds',
#   'Country': 'JM'},
#  {'City': 'Altamira',
#   'Lat': -3.2,
#   'Lng': -52.21,
#   'Max Temp': 72.54,
#   'Humidity': 94,
#   'Cloudiness': 50,
#   'Wind Speed': 2.8,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BR'},
#  {'City': 'Ruza',
#   'Lat': 55.7,
#   'Lng': 36.2,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Ketchikan',
#   'Lat': 55.34,
#   'Lng': -131.65,
#   'Max Temp': 41,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Weather': 'light rain',
#   'Country': 'US'},
#  {'City': 'Dudinka',
#   'Lat': 69.41,
#   'Lng': 86.18,
#   'Max Temp': 19.4,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 17.9,
#   'Current Weather': 'light shower snow',
#   'Country': 'RU'},
#  {'City': 'George',
#   'Lat': -33.96,
#   'Lng': 22.46,
#   'Max Temp': 59,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 3.85,
#   'Current Weather': 'clear sky',
#   'Country': 'ZA'},
#  {'City': 'Buraydah',
#   'Lat': 26.33,
#   'Lng': 43.98,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 5.08,
#   'Current Weather': 'clear sky',
#   'Country': 'SA'},
#  {'City': 'Dolinsk',
#   'Lat': 47.35,
#   'Lng': 142.8,
#   'Max Temp': 30.2,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 15.66,
#   'Current Weather': 'scattered clouds',
#   'Country': 'RU'},
#  {'City': 'Saint-Francois',
#   'Lat': 46.42,
#   'Lng': 3.91,
#   'Max Temp': 27,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 1.12,
#   'Current Weather': 'mist',
#   'Country': 'FR'},
#  {'City': 'Camana',
#   'Lat': -16.62,
#   'Lng': -72.71,
#   'Max Temp': 62.8,
#   'Humidity': 78,
#   'Cloudiness': 80,
#   'Wind Speed': 8.68,
#   'Current Weather': 'broken clouds',
#   'Country': 'PE'},
#  {'City': 'Andenes',
#   'Lat': 69.31,
#   'Lng': 16.12,
#   'Max Temp': 34,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Weather': 'scattered clouds',
#   'Country': 'NO'},
#  {'City': 'Kerrville',
#   'Lat': 30.05,
#   'Lng': -99.14,
#   'Max Temp': 63,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 17.22,
#   'Current Weather': 'overcast clouds',
#   'Country': 'US'},
#  {'City': 'Kasempa',
#   'Lat': -13.46,
#   'Lng': 25.83,
#   'Max Temp': 67.8,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 0.81,
#   'Current Weather': 'moderate rain',
#   'Country': 'ZM'},
#  {'City': 'Cururupu',
#   'Lat': -1.83,
#   'Lng': -44.87,
#   'Max Temp': 75.34,
#   'Humidity': 93,
#   'Cloudiness': 56,
#   'Wind Speed': 3.04,
#   'Current Weather': 'broken clouds',
#   'Country': 'BR'},
#  {'City': 'Mari',
#   'Lat': -7.06,
#   'Lng': -35.32,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Weather': 'broken clouds',
#   'Country': 'BR'},
#  {'City': 'Lima',
#   'Lat': -12.04,
#   'Lng': -77.03,
#   'Max Temp': 62.6,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Current Weather': 'clear sky',
#   'Country': 'PE'},
#  {'City': 'Lazaro Cardenas',
#   'Lat': 17.96,
#   'Lng': -102.2,
#   'Max Temp': 76.14,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Current Weather': 'clear sky',
#   'Country': 'MX'},
#  {'City': 'Tabou',
#   'Lat': 4.42,
#   'Lng': -7.35,
#   'Max Temp': 77.74,
#   'Humidity': 88,
#   'Cloudiness': 52,
#   'Wind Speed': 8.9,
#   'Current Weather': 'light rain',
#   'Country': 'CI'},
#  {'City': 'Avera',
#   'Lat': 33.19,
#   'Lng': -82.53,
#   'Max Temp': 42.8,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Redmond',
#   'Lat': 47.67,
#   'Lng': -122.12,
#   'Max Temp': 45,
#   'Humidity': 95,
#   'Cloudiness': 67,
#   'Wind Speed': 3.47,
#   'Current Weather': 'broken clouds',
#   'Country': 'US'},
#  {'City': 'Innisfail',
#   'Lat': -17.53,
#   'Lng': 146.03,
#   'Max Temp': 90,
#   'Humidity': 33,
#   'Cloudiness': 24,
#   'Wind Speed': 10,
#   'Current Weather': 'few clouds',
#   'Country': 'AU'},
#  {'City': 'Talas',
#   'Lat': 38.69,
#   'Lng': 35.55,
#   'Max Temp': 14,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 0.94,
#   'Current Weather': 'clear sky',
#   'Country': 'TR'},
#  {'City': 'Thomaston',
#   'Lat': 32.89,
#   'Lng': -84.33,
#   'Max Temp': 44.6,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Talcahuano',
#   'Lat': -36.72,
#   'Lng': -73.12,
#   'Max Temp': 55.4,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Current Weather': 'clear sky',
#   'Country': 'CL'},
#  {'City': 'Kirovsk',
#   'Lat': 48.64,
#   'Lng': 38.64,
#   'Max Temp': 32.22,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 11.01,
#   'Current Weather': 'overcast clouds',
#   'Country': 'UA'},
#  {'City': 'Tahe',
#   'Lat': 52.33,
#   'Lng': 124.73,
#   'Max Temp': 23.31,
#   'Humidity': 84,
#   'Cloudiness': 34,
#   'Wind Speed': 4.52,
#   'Current Weather': 'scattered clouds',
#   'Country': 'CN'},
#  {'City': 'Mandalgovi',
#   'Lat': 45.76,
#   'Lng': 106.27,
#   'Max Temp': 16.57,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 7.85,
#   'Current Weather': 'clear sky',
#   'Country': 'MN'},
#  {'City': 'Slonim',
#   'Lat': 53.09,
#   'Lng': 25.32,
#   'Max Temp': 38.59,
#   'Humidity': 88,
#   'Cloudiness': 34,
#   'Wind Speed': 13.56,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BY'},
#  {'City': 'Durango',
#   'Lat': 24.83,
#   'Lng': -104.83,
#   'Max Temp': 54.73,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 7.16,
#   'Current Weather': 'clear sky',
#   'Country': 'MX'},
#  {'City': 'Kempsey',
#   'Lat': -31.08,
#   'Lng': 152.83,
#   'Max Temp': 75.99,
#   'Humidity': 57,
#   'Cloudiness': 73,
#   'Wind Speed': 17.22,
#   'Current Weather': 'broken clouds',
#   'Country': 'AU'},
#  {'City': 'Nanchong',
#   'Lat': 30.8,
#   'Lng': 106.08,
#   'Max Temp': 53.37,
#   'Humidity': 64,
#   'Cloudiness': 81,
#   'Wind Speed': 3.67,
#   'Current Weather': 'broken clouds',
#   'Country': 'CN'},
#  {'City': 'Buala',
#   'Lat': -8.14,
#   'Lng': 159.59,
#   'Max Temp': 83.95,
#   'Humidity': 73,
#   'Cloudiness': 97,
#   'Wind Speed': 3.02,
#   'Current Weather': 'moderate rain',
#   'Country': 'SB'},
#  {'City': 'Bam',
#   'Lat': 29.11,
#   'Lng': 58.36,
#   'Max Temp': 50.11,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Current Weather': 'light rain',
#   'Country': 'IR'},
#  {'City': 'Nadym',
#   'Lat': 65.53,
#   'Lng': 72.52,
#   'Max Temp': 9.54,
#   'Humidity': 95,
#   'Cloudiness': 83,
#   'Wind Speed': 13.13,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'La Ronge',
#   'Lat': 55.1,
#   'Lng': -105.28,
#   'Max Temp': 12.2,
#   'Humidity': 85,
#   'Cloudiness': 85,
#   'Wind Speed': 1.12,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CA'},
#  {'City': 'Shimoda',
#   'Lat': 34.67,
#   'Lng': 138.95,
#   'Max Temp': 55.4,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Current Weather': 'broken clouds',
#   'Country': 'JP'},
#  {'City': 'Miandrivazo',
#   'Lat': -19.52,
#   'Lng': 45.47,
#   'Max Temp': 87.13,
#   'Humidity': 52,
#   'Cloudiness': 99,
#   'Wind Speed': 2.51,
#   'Current Weather': 'overcast clouds',
#   'Country': 'MG'},
#  {'City': 'Petresti',
#   'Lat': 44.65,
#   'Lng': 25.33,
#   'Max Temp': 41,
#   'Humidity': 93,
#   'Cloudiness': 87,
#   'Wind Speed': 3.36,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RO'},
#  {'City': 'San Juan',
#   'Lat': -31.54,
#   'Lng': -68.54,
#   'Max Temp': 80.91,
#   'Humidity': 41,
#   'Cloudiness': 16,
#   'Wind Speed': 16.49,
#   'Current Weather': 'few clouds',
#   'Country': 'AR'},
#  {'City': 'Elhovo',
#   'Lat': 42.17,
#   'Lng': 26.57,
#   'Max Temp': 24.8,
#   'Humidity': 92,
#   'Cloudiness': 5,
#   'Wind Speed': 4.5,
#   'Current Weather': 'clear sky',
#   'Country': 'BG'},
#  {'City': 'Lixourion',
#   'Lat': 38.2,
#   'Lng': 20.43,
#   'Max Temp': 57.42,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind Speed': 2.68,
#   'Current Weather': 'overcast clouds',
#   'Country': 'GR'},
#  {'City': 'Troitsko-Pechorsk',
#   'Lat': 62.71,
#   'Lng': 56.2,
#   'Max Temp': 21.27,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 9.44,
#   'Current Weather': 'light snow',
#   'Country': 'RU'},
#  {'City': 'Mastic Beach',
#   'Lat': 40.77,
#   'Lng': -72.85,
#   'Max Temp': 42.8,
#   'Humidity': 52,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Weather': 'clear sky',
#   'Country': 'US'},
#  {'City': 'Omboue',
#   'Lat': -1.57,
#   'Lng': 9.26,
#   'Max Temp': 74.93,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.51,
#   'Current Weather': 'light rain',
#   'Country': 'GA'},
#  {'City': 'Nador',
#   'Lat': 35.17,
#   'Lng': -2.93,
#   'Max Temp': 53.6,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Weather': 'clear sky',
#   'Country': 'MA'},
#  {'City': 'Mecca',
#   'Lat': 21.43,
#   'Lng': 39.83,
#   'Max Temp': 76.39,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 1.41,
#   'Current Weather': 'clear sky',
#   'Country': 'SA'},
#  {'City': 'Mtsensk',
#   'Lat': 53.28,
#   'Lng': 36.57,
#   'Max Temp': 34.74,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.28,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Kangaba',
#   'Lat': 11.93,
#   'Lng': -8.42,
#   'Max Temp': 66.7,
#   'Humidity': 27,
#   'Cloudiness': 2,
#   'Wind Speed': 5.99,
#   'Current Weather': 'clear sky',
#   'Country': 'ML'},
#  {'City': 'Mad',
#   'Lat': 48.2,
#   'Lng': 21.28,
#   'Max Temp': 32,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Weather': 'mist',
#   'Country': 'HU'},
#  {'City': 'Baiyin',
#   'Lat': 36.56,
#   'Lng': 104.21,
#   'Max Temp': 30.2,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Weather': 'haze',
#   'Country': 'CN'},
#  {'City': 'Katsuura',
#   'Lat': 35.13,
#   'Lng': 140.3,
#   'Max Temp': 55.99,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Weather': 'broken clouds',
#   'Country': 'JP'},
#  {'City': 'Entre Rios',
#   'Lat': -11.94,
#   'Lng': -38.08,
#   'Max Temp': 69.13,
#   'Humidity': 98,
#   'Cloudiness': 18,
#   'Wind Speed': 3.6,
#   'Current Weather': 'few clouds',
#   'Country': 'BR'},
#  {'City': 'Payo',
#   'Lat': -3.75,
#   'Lng': 103.64,
#   'Max Temp': 90.34,
#   'Humidity': 53,
#   'Cloudiness': 64,
#   'Wind Speed': 3.15,
#   'Current Weather': 'broken clouds',
#   'Country': 'ID'},
#  {'City': 'Waipawa',
#   'Lat': -41.41,
#   'Lng': 175.52,
#   'Max Temp': 61,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Weather': 'moderate rain',
#   'Country': 'NZ'},
#  {'City': 'Ordynskoye',
#   'Lat': 54.37,
#   'Lng': 81.9,
#   'Max Temp': 16.79,
#   'Humidity': 96,
#   'Cloudiness': 93,
#   'Wind Speed': 4.94,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'},
#  {'City': 'Touros',
#   'Lat': -5.2,
#   'Lng': -35.46,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BR'},
#  {'City': 'Mutoko',
#   'Lat': -17.4,
#   'Lng': 32.23,
#   'Max Temp': 76.62,
#   'Humidity': 52,
#   'Cloudiness': 77,
#   'Wind Speed': 6.24,
#   'Current Weather': 'broken clouds',
#   'Country': 'ZW'},
#  {'City': 'Kouroussa',
#   'Lat': 10.65,
#   'Lng': -9.88,
#   'Max Temp': 66.15,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 1.59,
#   'Current Weather': 'clear sky',
#   'Country': 'GN'},
#  {'City': 'Popondetta',
#   'Lat': -8.75,
#   'Lng': 148.25,
#   'Max Temp': 77.41,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 3.42,
#   'Current Weather': 'moderate rain',
#   'Country': 'PG'},
#  {'City': 'Yumen',
#   'Lat': 40.28,
#   'Lng': 97.2,
#   'Max Temp': 21.72,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 17.49,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CN'},
#  {'City': 'Phek',
#   'Lat': 25.67,
#   'Lng': 94.5,
#   'Max Temp': 66.2,
#   'Humidity': 46,
#   'Cloudiness': 55,
#   'Wind Speed': 0.67,
#   'Current Weather': 'broken clouds',
#   'Country': 'IN'},
#  {'City': 'Itoman',
#   'Lat': 26.12,
#   'Lng': 127.67,
#   'Max Temp': 73.4,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Current Weather': 'broken clouds',
#   'Country': 'JP'},
#  {'City': 'Ossora',
#   'Lat': 59.24,
#   'Lng': 163.07,
#   'Max Temp': 16.29,
#   'Humidity': 85,
#   'Cloudiness': 83,
#   'Wind Speed': 6.06,
#   'Current Weather': 'broken clouds',
#   'Country': 'RU'},
#  {'City': 'Doka',
#   'Lat': 13.52,
#   'Lng': 35.77,
#   'Max Temp': 72.48,
#   'Humidity': 43,
#   'Cloudiness': 14,
#   'Wind Speed': 9.48,
#   'Current Weather': 'few clouds',
#   'Country': 'SD'},
#  {'City': 'Verkhoyansk',
#   'Lat': 67.54,
#   'Lng': 133.38,
#   'Max Temp': -7.74,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.53,
#   'Current Weather': 'light snow',
#   'Country': 'RU'},
#  {'City': 'Fuerte Olimpo',
#   'Lat': -21.04,
#   'Lng': -57.87,
#   'Max Temp': 75.45,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 4.92,
#   'Current Weather': 'clear sky',
#   'Country': 'PY'},
#  {'City': 'Plouzane',
#   'Lat': 48.38,
#   'Lng': -4.62,
#   'Max Temp': 50,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Current Weather': 'clear sky',
#   'Country': 'FR'},
#  {'City': 'Abapo',
#   'Lat': -18.83,
#   'Lng': -63.47,
#   'Max Temp': 69.46,
#   'Humidity': 63,
#   'Cloudiness': 60,
#   'Wind Speed': 2.26,
#   'Current Weather': 'broken clouds',
#   'Country': 'BO'},
#  {'City': 'Puerto Leguizamo',
#   'Lat': -0.19,
#   'Lng': -74.78,
#   'Max Temp': 70.75,
#   'Humidity': 99,
#   'Cloudiness': 76,
#   'Wind Speed': 1.57,
#   'Current Weather': 'broken clouds',
#   'Country': 'CO'},
#  {'City': 'Gambo',
#   'Lat': 4.65,
#   'Lng': 22.26,
#   'Max Temp': 69.49,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 1.19,
#   'Current Weather': 'overcast clouds',
#   'Country': 'CF'},
#  {'City': 'Sao Felix Do Xingu',
#   'Lat': -6.64,
#   'Lng': -51.99,
#   'Max Temp': 70.97,
#   'Humidity': 91,
#   'Cloudiness': 29,
#   'Wind Speed': 1.61,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BR'},
#  {'City': 'Conceicao Do Araguaia',
#   'Lat': -8.26,
#   'Lng': -49.26,
#   'Max Temp': 72.81,
#   'Humidity': 91,
#   'Cloudiness': 25,
#   'Wind Speed': 3.24,
#   'Current Weather': 'scattered clouds',
#   'Country': 'BR'},
#  {'City': 'Kargasok',
#   'Lat': 59.06,
#   'Lng': 80.86,
#   'Max Temp': 14.49,
#   'Humidity': 95,
#   'Cloudiness': 85,
#   'Wind Speed': 5.77,
#   'Current Weather': 'overcast clouds',
#   'Country': 'RU'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Georgetown   5.41  100.34     84.20        78          20        5.82
# 1         Frome  51.23   -2.32     51.01        91          25        3.00
# 2  Isla Mujeres  21.23  -86.73     81.00        78          40        5.82
# 3      Lopatino  52.62   45.81     30.45        98         100       10.16
# 4      Sisimiut  66.94  -53.67     18.63        91         100       21.61
# 5       Mataura -46.19  168.86     63.00        59          85        7.00
# 6     Jamestown  42.10  -79.24     36.00        64          90       11.41
# 7       Okhotsk  59.38  143.30      0.72        85          23       18.34
# 8     Esperance -33.87  121.90     96.80        14           0       18.34
# 9          Kade  52.38   12.27     37.00        83          69        1.01
#
#     Current Weather Country
# 0        few clouds      MY
# 1  scattered clouds      GB
# 2        light rain      MX
# 3   overcast clouds      RU
# 4   overcast clouds      GL
# 5   overcast clouds      NZ
# 6   overcast clouds      US
# 7        few clouds      RU
# 8         clear sky      AU
# 9     broken clouds      DE

# %%
column_names = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Weather"]
city_data_df = city_data_df.reindex(columns=column_names)

# %%
city_data_df
# Out:
#                       City Country    Lat     Lng  Max Temp  Humidity  \
# 0               Georgetown      MY   5.41  100.34     84.20        78
# 1                    Frome      GB  51.23   -2.32     51.01        91
# 2             Isla Mujeres      MX  21.23  -86.73     81.00        78
# 3                 Lopatino      RU  52.62   45.81     30.45        98
# 4                 Sisimiut      GL  66.94  -53.67     18.63        91
# ..                     ...     ...    ...     ...       ...       ...
# 718       Puerto Leguizamo      CO  -0.19  -74.78     70.75        99
# 719                  Gambo      CF   4.65   22.26     69.49        64
# 720     Sao Felix Do Xingu      BR  -6.64  -51.99     70.97        91
# 721  Conceicao Do Araguaia      BR  -8.26  -49.26     72.81        91
# 722               Kargasok      RU  59.06   80.86     14.49        95
#
#      Cloudiness  Wind Speed   Current Weather
# 0            20        5.82        few clouds
# 1            25        3.00  scattered clouds
# 2            40        5.82        light rain
# 3           100       10.16   overcast clouds
# 4           100       21.61   overcast clouds
# ..          ...         ...               ...
# 718          76        1.57     broken clouds
# 719         100        1.19   overcast clouds
# 720          29        1.61  scattered clouds
# 721          25        3.24  scattered clouds
# 722          85        5.77   overcast clouds
#
# [723 rows x 9 columns]

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
